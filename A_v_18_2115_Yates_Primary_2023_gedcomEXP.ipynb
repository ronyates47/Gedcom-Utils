# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/A_v_18_2115_Yates_Primary_2023_gedcomEXP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import glob
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class GedcomDataset:
    def __init__(self, gen_person):
        self.gen_person = gen_person
        self.extractable_detail = {}
        self.anchor_gen1 = None  # Initialize anchor_gen1 here

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        name = self.extractable_detail.get('NAME', '')
        parts = name.split('/', 1)
        first_name = parts[0].split(' ')[0]
        last_name = parts[1].rstrip('/') if len(parts) > 1 else ""
        self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
        return self.gen_person.strip('@')

    def get_anchor_gen1(self):
        return self.anchor_gen1

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

# Function definitions
def extract_id(record):
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10] # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/') # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

# Global dictionary to hold name to ID mapping
name_to_id = {}

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_datasets = []
        self.filter_pool = []

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_datasets = []
        self.filter_pool = []

    def parse_gedcom(self):
        global name_to_id  # Declare name_to_id as global to modify it
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()
        current_dataset = None
        npfx_count = 0
        total_count = 0

        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                total_count += 1
                current_dataset = GedcomDataset(tag)
                self.gedcom_datasets.append(current_dataset)

                # Populate name_to_id
                individual_name = current_dataset.get_anchor_gen1()
                individual_id = current_dataset.get_gen_person()
                name_to_id[individual_name] = individual_id

            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_key = tag
                    current_dataset.add_extractable_detail(current_key, value)

                elif level == 2 and tag == 'NPFX':
                    npfx_count += 1
                    current_dataset.add_extractable_detail(tag, value)

        print(f'GEDCOM contained {total_count} total records')
        print(f'Records tagged and filtered by NPFX: {npfx_count}')

        # First level of filtering: Filter those with NPFX
        for dataset in self.gedcom_datasets:
            if dataset.get_extractable_NPFX():
                self.filter_pool.append(dataset)

        # Check if manual filtering should be applied
        manual_filter_activated = True  # or False depending on your situation

        # Second level of filtering: Apply manual filter from Excel sheet
        if manual_filter_activated:
            import pandas as pd  # Assuming you haven't imported it yet
            try:
                df = pd.read_excel('filtered_ids.xlsx')
            except FileNotFoundError:
                print("filtered_ids.xlsx not found. Skipping second-level manual filter.")
            else:
                manual_filtered_ids = set(df['ID'])
                print(f"Manual filter IDs loaded: {len(manual_filtered_ids) - 1}")

                self.filter_pool = [dataset for dataset in self.filter_pool if dataset.get_gen_person() in manual_filtered_ids]
                print(f"After manual filter, total records: {len(self.filter_pool)}")

def input_prime_surname(last_prime_surname=None):
    if last_prime_surname:
        last_name = input(f"Enter prime_surname (default: {last_prime_surname}): ")
        if not last_name:
            last_name = last_prime_surname
    else:
        last_name = input("Enter prime_surname: ")
    return last_name

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

    while True:
        try:
            selected_num = int(input("Enter the number of the GEDCOM file you want to use: "))
            if 1 <= selected_num <= len(gedcom_files):
                return gedcom_files[selected_num - 1]
            else:
                print("Invalid number. Please enter a valid number from the list.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

gedcom_file_path = select_gedcom_file() # Call the function to let the user select the GEDCOM file
if gedcom_file_path:
    # Use the selected GEDCOM file path to create an instance of the Gedcom class
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    individuals = []  # Initialize the list of individuals

    for dataset in gedcom_instance.filter_pool:    # Iterate over the filter_pool list,add each last name and ID to list
        individual_id = dataset.get_gen_person()
        last_name = dataset.get_anchor_gen1()
        individuals.append((last_name, individual_id))

#    print(f'Records tagged and filtered by NPFX: {len(individuals)}')

    with open(gedcom_file_path, 'r') as file:    # Read the GEDCOM file and split it into individual and family records
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

def has_both_parents(records, mother_id, father_id):
    return mother_id in records and father_id in records

visited_pairs = set()
generation_table = []

def find_parents(individual_id, generation, records):
    # ... (same code, but store individual IDs in visited_pairs and generation_table)
    if individual_id not in records:
        return
    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]
    if famc_id not in records:
        return

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if mother_id and mother_id in records and father_id and father_id in records:
        parent_pair = (father_id, mother_id)
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            generation_table.append((generation, parent_pair))

#        print(f"229-Added to generation_table: {parent_pair} at generation {generation}")

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)

#    print(f"237-Visited pairs so far: {visited_pairs}")


def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]
    last_name = last_name[:10].rstrip('/')
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def find_distant_ancestors(individual_id, records, path=None):
    path = path if path is not None else []
    if path is None:
        path = [individual_id]
    else:
        path.append(individual_id)

    if individual_id not in records:
        return []

    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]

    if famc_id not in records:
        return [path]

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if father_id is None and mother_id is None:
        return [path]

    paths = []
    if father_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(father_id, records, new_path))

    if mother_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(mother_id, records, new_path))

#    print(f"Distant ancestors paths for {individual_id}: {paths}")

    return paths
filtered_datasets = gedcom_instance.filter_pool

# Additional Function to isolate score calculation logic
def calculate_score(distant_ancestors_paths, records):
    # ... (same code, but works with individual IDs)
    name_paths = []
    for path in distant_ancestors_paths:
        name_path = [extract_name(records.get(id, '')) for id in path]
        name_paths.append(name_path)

    path_scores = {}
    for idx, name_path in enumerate(name_paths):
        score = 0
        for generation, name in enumerate(name_path):
            if 'Yates' in name:
                score += 1 * (generation + 1)
        path_scores[idx] = score

    if path_scores:
        winning_path_index = max(path_scores, key=path_scores.get)
        winning_path_score = path_scores[winning_path_index]
        winning_path_names = name_paths[winning_path_index]
        winning_path_ids = distant_ancestors_paths[winning_path_index]  # Get the IDs of the winning path
#        print(f"314-Debug - winning_path_ids: {winning_path_ids}")  # Print the IDs of the winning path
    else:
        winning_path_index = None
        winning_path_score = 0
        winning_path_names = []
        print("319Debug - winning_path_ids: None")  # Print None if no winning path found

    return winning_path_score, winning_path_names


def filter_ancestral_line(dna_line_ids, name_to_id_map, generation_table):

#    print(f"Debug - generation_table: {generation_table}")
#    print(f"Debug - winning_path_ids: {winning_path_ids}")  # Print the IDs of the winning path

    # Initialize an empty table to store matching pairs
    matching_table = []

    # Loop through the generation table to find matching IDs
    for generation, pair in generation_table:
        id1, id2 = pair
        if id1 in winning_path_ids or id2 in winning_path_ids:
#            print(f"336 Found ID in generation {generation}: {id1 if id1 in winning_path_ids else id2}")
            matching_table.append((generation, pair))

    # Print the matching_table
#    print("340-Matching Pairs-Gens:", matching_table)

    return matching_table

# Call the function
filtered_ancestral_line = filter_ancestral_line(winning_dna_line_ids, name_to_id, generation_table)


# Main Loop
for dataset in filtered_datasets:
    individual_id = dataset.get_gen_person()

    # Reset global variables for each new individual
    visited_pairs = set()
    generation_table = []

    # Find full ancestral line and distant ancestors
    find_parents(individual_id, 1, records)
    distant_ancestors_paths = find_distant_ancestors(individual_id, records)

    # Calculate score and get DNA line
    winning_path_score, winning_dna_line_ids = calculate_score(distant_ancestors_paths, records)

    # Filter the full ancestral line based on the DNA line, keeping the generation info
# This is where you call the filter_ancestral_line function
    filtered_ancestral_line = filter_ancestral_line(winning_dna_line_ids, name_to_id, generation_table)


    # Sort the filtered ancestral line by generation
    filtered_ancestral_line.sort(key=lambda x: x[0])

    # Convert IDs to Names and Format them
    filtered_ancestral_line_names = []
    for generation, pair in filtered_ancestral_line:
        name_pair = [extract_name(records.get(id, '')) for id in pair]
        formatted_name_pair = f"{name_pair[0]}&{name_pair[1]}"
        filtered_ancestral_line_names.append(formatted_name_pair)

#    Final formatted output
    filtered_ancestral_line_names.reverse()  # Reversing the list in-place
    filtered_ancestral_line_str = "|".join(filtered_ancestral_line_names)
    print(f"384-Filtered Ancestral Line for {individual_id}: {filtered_ancestral_line_str}")




# Main Loop
# Assuming name_to_id is populated elsewhere in your code
name_to_id = {}  # Placeholder, populate this after reading the GEDCOM file

def process_individual(individual_id, gedcom_instance, records):
    global generation_table
    global visited_pairs

    # Resetting the variables for each individual
    generation_table = []
    visited_pairs = set()

    # Finding parents and distant ancestors
    find_parents(individual_id, 1, records)
    distant_ancestors_paths = find_distant_ancestors(individual_id, records)

    # Calculate the winning path
    winning_path_score, winning_path_names = calculate_score(distant_ancestors_paths, records)

    # Identify the winning IDs based on the winning names
    winning_path_ids = {name_to_id[name] for name in winning_path_names if name in name_to_id}

    # Filter the parent pairs based on the winning path
    filtered_parent_pairs = {}
    for generation, parent_pair_tuple in generation_table:
        parent1, parent2 = parent_pair_tuple  # Unpack the tuple
        if parent1 in winning_path_ids or parent2 in winning_path_ids:
            filtered_parent_pairs[generation] = f"{parent1}&{parent2}"  # Reconstruct the parent_pair string

    # Sort the filtered_parent_pairs by the generation numbers (keys)
    sorted_parent_pairs = sorted(filtered_parent_pairs.items())

    # Extract just the parent pairs, discarding the generation numbers
    sorted_parent_pairs_str_list = [pair for generation, pair in sorted_parent_pairs]

    # Concatenate into the final string using '|' as separator
    filtered_parent_pairs_str = '|'.join(sorted_parent_pairs_str_list)

    # Extract other information for this individual
    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            cm_value = dataset.get_extractable_cm()
            sort_value = dataset.get_extractable_sort()
            break
    else:
        cm_value = 'N/A'
        sort_value = 'N/A'

    # Create and populate the individual_data dictionary
    individual_data = {
        'cM': cm_value,
        'Sort': sort_value,
        'Filtered Ancestral Line': filtered_parent_pairs_str
    }

#    print(f"390-Debug - individual_id: {individual_id}")
#    print(f"391-Debug - distant_ancestors_paths: {distant_ancestors_paths}")
#    print(f"433-Debug - winning_path_names: {winning_path_names}")
#    print(f"434-Dbug - filtered_parent_pairs before sorting: {filtered_parent_pairs}")
    return individual_data, filtered_parent_pairs_str

# This is where you call the filter_ancestral_line function
filtered_ancestral_line = filter_ancestral_line(winning_dna_line_ids, name_to_id, generation_table)


# Initialize your empty combined_df_rows list here, before the main loop
combined_df_rows = []

# Main Loop
for dataset in filtered_datasets:
    individual_id = dataset.get_gen_person()

    # Reset global variables for each new individual
    visited_pairs = set()
    generation_table = []

    # Call the refactored process_individual function
    individual_data, filtered_parent_pairs_str = process_individual(individual_id, gedcom_instance, records)

    cm = individual_data['cM']
    sort = individual_data['Sort']

    # No need for final_output, we'll use filtered_parent_pairs_str directly
    combined_df_rows.append([individual_id, sort, individual_name, cm, filtered_parent_pairs_str])
    # Removed the second call to process_individual

import pandas as pd

# Global variables
visited_pairs = set()
combined_df_rows = []  # Initialize your empty combined_df_rows list

# Main Loop
for dataset in gedcom_instance.filter_pool:  # Assuming filter_pool is iterable
    individual_id = dataset.get_gen_person()

    # Reset global variables for each new individual
    visited_pairs.clear()
    generation_table = []

    # Process Individual and Get Data
    individual_data, filtered_ancestral_line_str = process_individual(individual_id, gedcom_instance, records)
    cm = individual_data['cM']
    sort = individual_data['Sort']
    individual_name = extract_name(records.get(individual_id, ''))
    # Append to DataFrame Rows
    combined_df_rows.append([individual_id, sort, individual_name, cm, filtered_ancestral_line_str])



# Create DataFrame
columns = ['ID#', 'Match to', 'Name', 'cM', 'Yates DNA Ancestral Line']
combined_df = pd.DataFrame(combined_df_rows, columns=columns)

# Add hotlinks
USE_HOTLINK = True

def create_hotlink(row):
    if USE_HOTLINK:
        url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
        additional_params = "&tree=tree1&parentset=0&display=vertical&generations=15"
        return f'<a href="{url_base}{row["ID#"]}{additional_params}">{row["ID#"]}</a>'
    return row['ID#']

combined_df['LUN#'] = combined_df.apply(create_hotlink, axis=1)

# Reorder Columns
ordered_columns = ['ID#', 'Match to', 'Name', 'cM', 'LUN#', 'Yates DNA Ancestral Line']
combined_df = combined_df[ordered_columns]

# Update index and sort
combined_df.index += 1
combined_df.sort_values(by=['Match to', 'Yates DNA Ancestral Line'], ascending=[False, True], inplace=True)

# Print and Save DataFrame
print(combined_df)
combined_df.to_excel('/content/output.xlsx', index=False)
# Out:
# Automatically selecting the first GEDCOM file.
# GEDCOM contained 51006 total records
# Records tagged and filtered by NPFX: 405
# filtered_ids.xlsx not found. Skipping second-level manual filter.
# 384-Filtered Ancestral Line for I73: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I80: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I82: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I84: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I615: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I687: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I808: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I836: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I837: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I869: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I5323: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I6670: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I13817:
# 384-Filtered Ancestral Line for I17239: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I20317: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I21743: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I23678: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I24692: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I26925:
# 384-Filtered Ancestral Line for I31861: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I39890: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I40190: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I41645: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I41955: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I42193: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I42202: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I42207: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I42478:
# 384-Filtered Ancestral Line for I42881: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I44219: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I44570: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I44883:
# 384-Filtered Ancestral Line for I44894:
# 384-Filtered Ancestral Line for I44935: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45040: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45059: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45072: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I45084: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45104: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45119: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45133:
# 384-Filtered Ancestral Line for I45149: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45150: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I45201: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I45394: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45417:
# 384-Filtered Ancestral Line for I45439:
# 384-Filtered Ancestral Line for I45462: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45467:
# 384-Filtered Ancestral Line for I45499:
# 384-Filtered Ancestral Line for I45520: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah|YatesJoshua&BoydstonMehitable
# 384-Filtered Ancestral Line for I45534:
# 384-Filtered Ancestral Line for I45552: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45591: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45612:
# 384-Filtered Ancestral Line for I45632: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I45636: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45665: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45670: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I45672: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I45690:
# 384-Filtered Ancestral Line for I45700: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45722:
# 384-Filtered Ancestral Line for I45741:
# 384-Filtered Ancestral Line for I45809:
# 384-Filtered Ancestral Line for I45823: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45833: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45864:
# 384-Filtered Ancestral Line for I45897:
# 384-Filtered Ancestral Line for I45907: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I45924: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I45932:
# 384-Filtered Ancestral Line for I45949: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I45980:
# 384-Filtered Ancestral Line for I46008: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46034: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46054:
# 384-Filtered Ancestral Line for I46068: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46085: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46102: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46119: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46129:
# 384-Filtered Ancestral Line for I46144: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46154: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46168: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46175:
# 384-Filtered Ancestral Line for I46197: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46207: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46214:
# 384-Filtered Ancestral Line for I46231: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46243: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46269: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46285: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46303: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46317:
# 384-Filtered Ancestral Line for I46330: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I46346: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I46370:
# 384-Filtered Ancestral Line for I46390: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46402: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46403: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46415: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46423: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46430: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46448:
# 384-Filtered Ancestral Line for I46457: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46470: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46495: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I46502:
# 384-Filtered Ancestral Line for I46508:
# 384-Filtered Ancestral Line for I46516:
# 384-Filtered Ancestral Line for I46528:
# 384-Filtered Ancestral Line for I46538:
# 384-Filtered Ancestral Line for I46550: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46562: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46572:
# 384-Filtered Ancestral Line for I46584: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46593:
# 384-Filtered Ancestral Line for I46603: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46628: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46641: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46655: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46667: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46681: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I46706: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46721:
# 384-Filtered Ancestral Line for I46750: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46764: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46792:
# 384-Filtered Ancestral Line for I46811: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46826: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46836: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46847: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I46861: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46872: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46881:
# 384-Filtered Ancestral Line for I46894: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46903: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah|YatesJoshua&BoydstonMehitable|YatesWilliam&HigginsSusannah
# 384-Filtered Ancestral Line for I46917: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I46924: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I46934: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46954: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I46965: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46985: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I46996: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47009:
# 384-Filtered Ancestral Line for I47026: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47039: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47054: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47076: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47088: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47098: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I47110:
# 384-Filtered Ancestral Line for I47123: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47131:
# 384-Filtered Ancestral Line for I47142: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47156: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47163: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47172: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47182: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47193: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47205: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47216: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47228: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47241:
# 384-Filtered Ancestral Line for I47250: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47257: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47270: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47279: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47306: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47318: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47327: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47338: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47350: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47365: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47379: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47393: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47406: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47416: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47427: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47435: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47447: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47466:
# 384-Filtered Ancestral Line for I47497: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47510: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47528: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47542: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I47691: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane
# 384-Filtered Ancestral Line for I47698: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47711: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47733: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47798: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47806: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I47881:
# 384-Filtered Ancestral Line for I47891: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47906: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I47918: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47929: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I47948: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I47958: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I47971: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I47979: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48125: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48151: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48162:
# 384-Filtered Ancestral Line for I48171: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48182:
# 384-Filtered Ancestral Line for I48195:
# 384-Filtered Ancestral Line for I48210: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48217: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48228: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48240: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48247: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I48257: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48274: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48278: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48292: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48304: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48314: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48331: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48337: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48354: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48375: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48384: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48391: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48403: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48415: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48420: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I48430: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48438: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48452: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48471: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48481: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48489: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48503: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I48516: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48525: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48538: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48552: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48560: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48573: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah|YatesJoshua&BoydstonMehitable
# 384-Filtered Ancestral Line for I48581: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48593:
# 384-Filtered Ancestral Line for I48605: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48614:
# 384-Filtered Ancestral Line for I48627: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48628:
# 384-Filtered Ancestral Line for I48642: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48652:
# 384-Filtered Ancestral Line for I48664:
# 384-Filtered Ancestral Line for I48670: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48674:
# 384-Filtered Ancestral Line for I48686: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48697:
# 384-Filtered Ancestral Line for I48706: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48710: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48721:
# 384-Filtered Ancestral Line for I48728:
# 384-Filtered Ancestral Line for I48737: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48744: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48752: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48765: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48767:
# 384-Filtered Ancestral Line for I48784:
# 384-Filtered Ancestral Line for I48792: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48799: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48812: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48821: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I48830:
# 384-Filtered Ancestral Line for I48837:
# 384-Filtered Ancestral Line for I48843:
# 384-Filtered Ancestral Line for I48857: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I48868: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I48887: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I48898:
# 384-Filtered Ancestral Line for I48901:
# 384-Filtered Ancestral Line for I48919:
# 384-Filtered Ancestral Line for I48935: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48945:
# 384-Filtered Ancestral Line for I48954: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48965: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I48970:
# ...
# 384-Filtered Ancestral Line for I49615: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49636: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I49652: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49657: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I49673: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I49682: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49693: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I49699: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49708: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I49717: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49730: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49755: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49784: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I49799: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I49813: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I49833: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49847: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49862: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz
# 384-Filtered Ancestral Line for I49876: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49896: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I49905:
# 384-Filtered Ancestral Line for I49917: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49955: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I49982: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I49996: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I50006: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50013: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50024: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50033: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50046: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah
# 384-Filtered Ancestral Line for I50309: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50326:
# 384-Filtered Ancestral Line for I50355: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50364: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50369:
# 384-Filtered Ancestral Line for I50375:
# 384-Filtered Ancestral Line for I50391: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I50405:
# 384-Filtered Ancestral Line for I50416:
# 384-Filtered Ancestral Line for I50429: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50440: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50449: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I50459: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50472: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I50482:
# 384-Filtered Ancestral Line for I50494: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50511: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I50522: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael|YatesSamuel&GouldJohannah|YatesJoshua&BoydstonMehitable|YatesWilliam&HigginsSusannah|YatesSimeon&MayCharlotte|YatesWilliam&BaileyMary|RictorGeorgeW&YatesJuliaAnn|BennettMartinOl&RictorInez|SwinsonOmerMars&BennettHazelBen|SwinsonPaulRoss&TaylorBetty|FehrenbachRichardW&SwinsonRita
# 384-Filtered Ancestral Line for I50535: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50551: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50778: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I50781: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I50789: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I50801: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances
# 384-Filtered Ancestral Line for I50806: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50809: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy
# 384-Filtered Ancestral Line for I50820: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50833: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50869: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50894: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50898: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50903: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50914: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50916: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50923: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50929: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50932: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50935: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50938: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary|YatesGeorge&WarfieldRachael
# 384-Filtered Ancestral Line for I50939:
# 384-Filtered Ancestral Line for I50975: YatesRichard&AshendonJoan|YatesJohn&HydeAlice|YatesThomas&WhiteFrances|YatesFrancis&TichborneJane|YatesThomas&StephensDorothy|YatesJohn&TettershalMaryEliz|YatesGeorge&WellsMary
# 384-Filtered Ancestral Line for I50986:
# 384-Filtered Ancestral Line for I50993:
# 384-Filtered Ancestral Line for I51005:
#         ID#       Match to              Name  cM  \
# 163  I47216  yatesjamesrob    BrysonMildredE  16
# 164  I47228  yatesjamesrob  FlemingTlcjones1  16
# 165  I47241  yatesjamesrob   StanleyMiltonTh  16
# 166  I47250  yatesjamesrob    HelsleyNathanR  15
# 167  I47257  yatesjamesrob  ViolettaLawrence  14
# ..      ...            ...               ...  ..
# 366  I50369  addison,david    MillerMyraBell  13
# 367  I50375  addison,david      MyersRichard  15
# 368  I50391  addison,david    WilsonDeborahJ  14
# 369  I50405  addison,david   HarndenScottHar  13
# 370  I50416  addison,david           GoreSon  13
#
#                                                   LUN#  \
# 163  <a href="https://yates.one-name.net/tng/vertic...
# 164  <a href="https://yates.one-name.net/tng/vertic...
# 165  <a href="https://yates.one-name.net/tng/vertic...
# 166  <a href="https://yates.one-name.net/tng/vertic...
# 167  <a href="https://yates.one-name.net/tng/vertic...
# ..                                                 ...
# 366  <a href="https://yates.one-name.net/tng/vertic...
# 367  <a href="https://yates.one-name.net/tng/vertic...
# 368  <a href="https://yates.one-name.net/tng/vertic...
# 369  <a href="https://yates.one-name.net/tng/vertic...
# 370  <a href="https://yates.one-name.net/tng/vertic...
#
#     Yates DNA Ancestral Line
# 163
# 164
# 165
# 166
# 167
# ..                       ...
# 366
# 367
# 368
# 369
# 370
#
# [405 rows x 6 columns]

# %%
# !pip install pandas
# !pip install python-gedcom
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: python-gedcom in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
