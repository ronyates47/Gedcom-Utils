# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/2023_0929_2030_hrs_Yates_final_formatting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import glob
import os
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.records = {}  # Initialize records attribute here
        self.gedcom_datasets = []  # Keep this if other parts of your code depend on it

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

    def parse_gedcom(self):
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()

        current_dataset = None
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                current_dataset = GedcomDataset(tag)
                self.records[tag] = current_dataset
                self.gedcom_datasets.append(current_dataset)  # Add to the list of datasets
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_dataset.add_extractable_detail(tag, value)
                elif level == 2 and tag == 'NPFX':
                    current_dataset.add_extractable_detail(tag, value)

#        print(f"47-GEDCOM contained {len(self.records)} total records")

    def apply_csv_filter(self, csv_file_path):  # BACKWARDS CONVERSION TO EASE CSV MAUNUAL FILTER OF ID"s
        if not os.path.exists(csv_file_path):
            print("CSV file not found. Proceeding without filtering by CSV.")
            return

        df = pd.read_csv(csv_file_path)
        # Add '@' to the beginning and end of each ID to match the GEDCOM format
        filtered_ids = set(f"@{x}@" for x in df['ID'])

        self.records = {k: v for k, v in self.records.items() if k in filtered_ids}

        print(f'Records manually CSV filtered: {len(self.records)}')

    def apply_npfx_filter(self):
        filtered_records = {k: v for k, v in self.records.items() if v.get_extractable_NPFX()}

        # Update self.records to only contain the filtered records
        self.records = filtered_records
        print(f'66-Records tagged and filtered by NPFX: {len(self.records)}')
        print(f"64-'self.records' contains {len(self.records)} total records")

def extract_id(record):  # Moved outside of the class so it's a standalone function
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(gedcom_dataset_instance):# Moved outside of the class so it's a standalone function
    record = gedcom_dataset_instance.extractable_detail.get('NAME', '')
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]

    if '/' not in name:
        print(f"Invalid name format for record: {record[:50]}...")  # Print the first 100 characters of the problematic record for debugging
        return None  # or you could return a default value like "UnknownUnknown"

    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]  # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/')  # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def has_both_parents(records, mother_id, father_id):   # Moved outside of the class so it's a standalone function
    return mother_id in records and father_id in records

class GedcomDataset:
    def __init__(self, individual_id):
        self.individual_id = individual_id
        self.extractable_detail = {}
        self.anchor_gen1 = None

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        return self.individual_id.strip('@')

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

    def get_extractable_FAMS(self):
        return self.extractable_detail.get('FAMS', '').strip('@')

    def get_extractable_WIFE(self):
        return self.extractable_detail.get('WIFE', '').strip('@')

    def get_extractable_HUSB(self):
        return self.extractable_detail.get('HUSB', '').strip('@')


    def get_anchor_gen1(self):
        name = self.extractable_detail.get('NAME', '')
        if '/' in name:
            first_name, last_name = name.split('/', 1)
            first_name = first_name.split(' ')[0]
            last_name = last_name.rstrip('/')
            self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
            return self.anchor_gen1
        else:
            print(f"Warning: No '/' found in NAME tag for individual {self.get_gen_person()}")
            return ''

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

gedcom_file_path = select_gedcom_file()

if gedcom_file_path:
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    # Apply manual CSV filter
    gedcom_instance.apply_csv_filter("/content/filtered_ids.csv")  # Replace with your actual CSV file path

    # Apply NPFX filter
    gedcom_instance.apply_npfx_filter()

    # Initialize the list of individuals
    individuals = []

    # Reading the GEDCOM file and parsing records
    with open(gedcom_file_path, 'r') as file:
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

    # Create the filtered_records dictionary after self.records has been populated
    filtered_records = {dataset.get_gen_person(): records.get(dataset.get_gen_person(), "") for dataset in gedcom_instance.records.values()}

def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record_instance = records[individual_id]
    famc_id = record_instance.get_extractable_FAMC()  # Retrieve FAMC from the GedcomDataset instance
    if famc_id not in records:
        return

    fam_record_instance = records[famc_id]
    mother_id = fam_record_instance.get_extractable_WIFE()  # Retrieve WIFE from the GedcomDataset instance
    father_id = fam_record_instance.get_extractable_HUSB()  # Retrieve HUSB from the GedcomDataset instance

    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)


def get_formatted_name(male_individual_id, female_individual_id, records):
    male_record = records.get(male_individual_id, "")
    female_record = records.get(female_individual_id, "")

    male_name = extract_name(male_record)
    female_name = extract_name(female_record)

    if male_name is None or female_name is None:
        print(f"Could not extract name for either male ID: {male_individual_id} or female ID: {female_individual_id}")
        return None  # or return a default value

    return male_name + "&" + female_name


most_distant_ancestors = []  # New list to collect most distant ancestors

# This function now expects records to be a dictionary where each key is a unique identifier,
# and each value is an instance of the GedcomDataset class.
def find_distant_ancestors(individual_id, records, path=None, spouses=None, most_distant_ancestors=None):
#    print(f"Searching for distant ancestors of {individual_id}")

    if path is None:
        path = [individual_id]

    if spouses is None:
        spouses = {}

    if most_distant_ancestors is None:
        most_distant_ancestors = []

    record = records.get(individual_id, None)
#    print(f"256-Type of record: {type(record)}, Content: {record}")

    if not record:
        print(f"Record not found for {individual_id}")
        return [], spouses, most_distant_ancestors

    paths = []
    famc_id = extract_famc_id(record)

    if famc_id in records:
        mother_id, father_id = extract_parent_ids(records[famc_id])

        if father_id:
            father_name = father_id
            new_path = list(path) + [father_name]
            paths.extend(find_distant_ancestors(father_id, records, new_path, spouses, most_distant_ancestors)[0])

        if mother_id:
            mother_name = mother_id
            new_path = list(path) + [mother_name]
            paths.extend(find_distant_ancestors(mother_id, records, new_path, spouses, most_distant_ancestors)[0])

    return paths, spouses, most_distant_ancestors


def extract_famc_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()


def extract_fams_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMS()


def extract_parent_ids(gedcom_dataset_instance):
    mother_id = gedcom_dataset_instance.get_extractable_WIFE()
    father_id = gedcom_dataset_instance.get_extractable_HUSB()
    return mother_id, father_id

    record = gedcom_instance.records.get(individual_id, "")
    print(f"299-Type of record: {type(record)}, Content: {record}")


def extract_famc_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_fam_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_parent_ids(fam_record):
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    return mother_id, father_id

def extract_spouse_id(fam_record, individual_record):
    if '1 HUSB @' in individual_record:
        spouse_start = fam_record.find('1 WIFE @') + 8
    else:
        spouse_start = fam_record.find('1 HUSB @') + 8
    spouse_end = fam_record.find('@', spouse_start)
    return fam_record[spouse_start:spouse_end]

# Loop through the filtered IDs.
for individual_id in gedcom_instance.records.keys():
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(
        individual_id, gedcom_instance.records
    )
#    print(f"344-Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")


individual_and_spouse = {}  # Create a dictionary to track individual and their spouse.






# Instead of using individual_id_to_search, loop through the filtered IDs.
for individual_id in gedcom_instance.records.keys():
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(individual_id, gedcom_instance.records)
#    print(f"352-Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")
#    print(f"353-Most Distant Ancestors for {individual_id}: {most_distant_ancestors}")

indexed_paths = {i: path for i, path in enumerate(distant_ancestors_paths)}

# Assuming `spouses` is a dictionary where the key is the individual ID and the value is the spouse ID
spouses = {}  # Populate this based on your function that finds distant ancestors

name_paths = []

for path in distant_ancestors_paths:
    name_path_with_spouse = []
    for id in path:  # This should be a single ID, not a list
        individual_name = extract_name(records.get(id, ''))
        spouse_id = spouses.get(id, None)
        spouse_name = extract_name(records.get(spouse_id, '')) if spouse_id else "unknown"
        name_path_with_spouse.append(f"{individual_name}&{spouse_name}")
    name_paths.append(name_path_with_spouse)

for idx, name_path in enumerate(name_paths):  # Check for the surname 'Yates' in the paths
    has_yates = any("Yates" in name for name in name_path)
    if has_yates:
        print(f"Path index: {idx}, Contains Yates: {has_yates}, Names: {name_path}")

path_scores = {}  # Initialize an empty dictionary to store the scores of each path

for idx, name_path in enumerate(name_paths): # Loop through the paths and apply the scoring scheme
    score = 0
    for generation, name in enumerate(name_path):
        if 'Yates' in name:
            score += 1 * (generation + 1)  # Add 1 to generation because index starts at 0
    path_scores[idx] = score     # Store the score of this path

# Find the index of the path with the highest score
#winning_path_index = max(path_scores, key=path_scores.get)
#winning_path_score = path_scores[winning_path_index]
#winning_path_names = name_paths[winning_path_index]

# Print the winning path to the console
#print(f"High Branch score was {winning_path_score}.")    #The winning path is at index {winning_path_index}
#print(f"Names in the winning path: {winning_path_names}")

#winning_path_names.reverse() # Reversing the list for highest generation first

# Adding spouses (Replace 'unknown' with actual spouse names if you have them)
#spouse_names = ['unknown'] * len(winning_path_names)  # Replace with real names or keep as 'unknown'

# Combine names and spouses in your specified format
#formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)]

#final_output = "|".join(formatted_names)# Join all the formatted names with '|'

#print("Selected DNA Branch:", final_output)

visited_pairs = set()

def process_individual(individual_id, gedcom_instance):
    global generation_table
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    global visited_pairs
    visited_pairs = set()

    find_parents(individual_id, 1, gedcom_instance.records)  # Changed to get records from gedcom_instance

    for dataset in gedcom_instance.records.values():  # Changed to get records from gedcom_instance
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    generation_table = generation_table.sort_values('Generation', ascending=False).reset_index(drop=True)

    individual_data = {}
    for dataset in gedcom_instance.records.values():  # Changed to get records from gedcom_instance
        if dataset.get_gen_person() == individual_id:
            individual_data['cM'] = dataset.get_extractable_cm()
            individual_data['Sort'] = dataset.get_extractable_sort()
            break

    individual_data['Parent Pairs A10'] = '|'.join([f"{row['Parent Pair']}" for index, row in generation_table[:10].iterrows()])

    print(f"Returning data for {individual_id}: {individual_data}")  # Debug print
    return individual_data


import pandas as pd

# Global variables
generation_table = None
visited_pairs = set()

# Run the process_individual function for each individual in the filtered_individuals list and create a combined DataFrame
combined_df_rows = []
for individual_id, dataset in gedcom_instance.records.items():
    name = extract_name(dataset)  # Corrected line
    individual_data = process_individual(individual_id, gedcom_instance)
    print("Debugging individual_data:", individual_data)  # This will print out the contents
    cm = individual_data.get('cM', 'Default Value')  # This will prevent KeyError
    sort = individual_data.get('Sort', 'Default Sort')
    parent_pairs_a10 = individual_data.get('Parent Pairs A10', 'Default Parent Pairs A10')
    # most_distant_ancestor = generation_table.iloc[0]['Parent Pair']  # Get the most distant ancestor from the last row of generation_table
    combined_df_rows.append([individual_id, name, sort, cm, parent_pairs_a10]) #, most_distant_ancestor

combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Name', 'Match to', 'cM', 'Ancestral Line A10'])


def create_hotlink(row):# Function to create hotlinks
    url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
    person_id = row['ID#']
    hotlink = f'<a href="{url_base}{person_id}&tree=tree1&parentset=0&display=vertical&generations=8" target="_blank">{person_id}</a>'
    return hotlink

combined_df['LUN#'] = combined_df.apply(lambda row: create_hotlink(row), axis=1) # Apply the hotlink function to create the 'LUN#' column
# Change the order of the columns
combined_df = combined_df[['ID#', 'Name', 'Match to', 'cM', 'LUN#', 'Ancestral Line A10']] # 'Most Distant Ancestor',
# Adjust index to start from 1 instead of 0
combined_df.index = combined_df.index + 1
# Print all records from the DataFrame
print(combined_df)
# Export the combined_df DataFrame to an Excel file
combined_df.to_excel('/content/output.xlsx', index=False)
# Out:
# Automatically selecting the first GEDCOM file.
# CSV file not found. Proceeding without filtering by CSV.
# 66-Records tagged and filtered by NPFX: 375
# 64-'self.records' contains 375 total records
# Returning data for @I13817@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I21743@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I23678@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: JL /Hudson/...
# Returning data for @I26925@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I31861@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I40190@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I42478@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I44570@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I44883@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I44894@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I44935@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45040@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45059@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45072@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45084@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45104@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45119@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45133@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45149@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45150@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45201@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45394@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45417@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45439@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45462@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45467@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45499@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45520@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45534@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45552@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45591@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45612@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45632@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45636@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45665@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45670@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45672@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45690@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45700@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45722@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45741@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: J /Young/...
# Returning data for @I45809@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45823@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: G /Shepard/...
# Returning data for @I45833@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45864@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45897@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45907@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45932@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45937@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45949@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I45980@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46008@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46034@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46054@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46068@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46085@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46102@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46119@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46129@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46144@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46154@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46168@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46175@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46186@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46197@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46207@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46214@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46231@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46243@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46269@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46285@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46303@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46317@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46330@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46346@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46370@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46390@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46402@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46403@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46415@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46423@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46430@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46448@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46457@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46470@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46495@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46502@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46508@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46516@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46528@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46538@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46550@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46562@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46572@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46584@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46593@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46603@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46628@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46641@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46655@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46667@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46681@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46706@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46721@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46750@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46764@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46792@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46811@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46826@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46836@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46847@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46861@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46872@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46881@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46894@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46903@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46917@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46924@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46934@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46945@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46954@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46965@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46985@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I46996@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47009@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: /Tullis-Taylor/...
# Returning data for @I47026@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47039@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47054@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47076@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47088@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47098@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47110@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47123@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47131@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47142@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47156@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47163@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47172@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47182@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47193@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47205@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47216@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47228@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47241@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47250@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47257@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47270@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47279@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47292@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47306@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47318@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47327@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47338@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47350@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47365@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47379@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47393@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47406@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47416@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47427@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47435@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47447@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47466@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47497@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47510@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47528@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47542@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47691@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47698@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47711@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47733@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47798@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47806@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47881@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47891@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47906@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: S /England/...
# Returning data for @I47918@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47929@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47948@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47958@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47971@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I47979@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48125@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48151@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48162@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48171@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48182@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48195@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48210@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48217@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48228@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48240@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48247@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48257@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48274@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48278@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48292@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48304@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48314@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48331@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48337@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48354@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48375@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48384@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48391@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48403@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48415@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48420@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48430@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48438@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48452@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48471@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48481@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48489@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48503@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48516@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48525@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48538@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48552@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48560@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48573@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48581@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48593@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48605@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48614@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48627@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48628@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48642@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48652@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48664@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48670@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48674@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48686@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48697@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48706@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48710@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48721@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48728@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48737@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48744@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48752@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48765@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48767@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48784@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48792@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48799@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48812@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48821@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48830@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48837@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48843@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48857@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48868@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48887@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48898@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48901@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48919@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48935@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48945@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48954@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48965@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48970@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I48983@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: BB /Smith/...
# Returning data for @I48998@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49006@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49020@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49027@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49039@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49061@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49076@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49085@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49095@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49101@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49115@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49132@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49140@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49152@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49165@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49178@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49189@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49197@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49206@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49220@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49230@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49240@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49250@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49276@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49289@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49316@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49326@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49337@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49369@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49380@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49396@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49402@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49409@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49427@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: Jed /Hadley/...
# Returning data for @I49442@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49444@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49459@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49465@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: D /Harrington/...
# Returning data for @I49471@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49476@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49491@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49502@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49511@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49520@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49565@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49570@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49580@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49593@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49607@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49615@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49636@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49652@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49657@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49673@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49682@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49693@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49699@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49708@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49717@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49730@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49755@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49784@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49799@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49813@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49833@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49847@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49862@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49876@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49896@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49905@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49917@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49955@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: KN /Hollingsworth/...
# Returning data for @I49982@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I49996@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50006@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50013@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50024@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50033@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50046@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50057@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50069@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50098@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50111@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50124@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50144@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50164@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50184@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50191@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50225@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50249@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: J /Bailey/...
# Returning data for @I50264@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50275@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50309@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50326@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50355@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50364@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50369@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50375@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50391@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50405@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Invalid name format for record: Son /Gore/...
# Returning data for @I50416@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50429@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50440@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50449@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50459@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50472@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50482@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50494@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50511@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50522@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50535@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
# Returning data for @I50551@: {'Parent Pairs A10': ''}
# Debugging individual_data: {'Parent Pairs A10': ''}
#           ID#             Name      Match to             cM  \
# 1    @I13817@     YatesamHenry  Default Sort  Default Value
# 2    @I21743@           HuntyA  Default Sort  Default Value
# 3    @I23678@    JohnsondBrett  Default Sort  Default Value
# 4    @I26925@             None  Default Sort  Default Value
# 5    @I31861@        ChurchSue  Default Sort  Default Value
# ..        ...              ...           ...            ...
# 371  @I50494@         Beaversl  Default Sort  Default Value
# 372  @I50511@         Stiverse  Default Sort  Default Value
# 373  @I50522@   FehrenbachaDea  Default Sort  Default Value
# 374  @I50535@   PetersonhJewel  Default Sort  Default Value
# 375  @I50551@  NicholssaColeen  Default Sort  Default Value
#
#                                                   LUN# Ancestral Line A10
# 1    <a href="https://yates.one-name.net/tng/vertic...
# 2    <a href="https://yates.one-name.net/tng/vertic...
# 3    <a href="https://yates.one-name.net/tng/vertic...
# 4    <a href="https://yates.one-name.net/tng/vertic...
# 5    <a href="https://yates.one-name.net/tng/vertic...
# ..                                                 ...                ...
# 371  <a href="https://yates.one-name.net/tng/vertic...
# 372  <a href="https://yates.one-name.net/tng/vertic...
# 373  <a href="https://yates.one-name.net/tng/vertic...
# 374  <a href="https://yates.one-name.net/tng/vertic...
# 375  <a href="https://yates.one-name.net/tng/vertic...
#
# [375 rows x 6 columns]

# %%
# !pip install pandas
# !pip install python-gedcom
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting python-gedcom
#   Downloading python_gedcom-1.0.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
