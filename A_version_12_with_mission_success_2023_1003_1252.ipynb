# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/A_version_12_with_mission_success_2023_1003_1252.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import glob
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class GedcomDataset:
    def __init__(self, gen_person):
        self.gen_person = gen_person
        self.extractable_detail = {}

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        name = self.extractable_detail.get('NAME', '')
        first_name, last_name = name.split('/', 1)
        first_name = first_name.split(' ')[0]
        last_name = last_name.rstrip('/')
        self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
        return self.gen_person.strip('@')

    def get_anchor_gen1(self):
        return self.anchor_gen1

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

# Function definitions
def extract_id(record):
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10] # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/') # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_datasets = []
        self.filter_pool = []

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

    def parse_gedcom(self):  # Note the correct indentation here
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()2
        current_dataset = None
        npfx_count = 0
        total_count = 0
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                total_count += 1
                current_dataset = GedcomDataset(tag)
                self.gedcom_datasets.append(current_dataset)
#                print(f"New individual dataset created with tag {tag}")
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_key = tag
                    current_dataset.add_extractable_detail(current_key, value)
#                    print(f"Added detail: {current_key} = {value}")
                elif level == 2 and tag == 'NPFX':
                    npfx_count += 1
                    current_dataset.add_extractable_detail(tag, value)
#                    print(f"Added NPFX: {value}")

#        print(f'GEDCOM contained {total_count} total records')
        print(f'Records tagged and filtered by NPFX: {npfx_count}')

        # First level of filtering: Filter those with NPFX
        for dataset in self.gedcom_datasets:
            if dataset.get_extractable_NPFX():
                self.filter_pool.append(dataset)

        # Check if manual filtering should be applied
        manual_filter_activated = True  # or False depending on your situation

        # Second level of filtering: Apply manual filter from Excel sheet
        if manual_filter_activated:
            import pandas as pd  # Assuming you haven't imported it yet
            try:
                df = pd.read_excel('filtered_ids.xlsx')
            except FileNotFoundError:
                print("filtered_ids.xlsx not found. Skipping second-level manual filter.")
            else:
                manual_filtered_ids = set(df['ID'])
                print(f"Manual filter IDs loaded: {len(manual_filtered_ids) - 1}")

                self.filter_pool = [dataset for dataset in self.filter_pool if dataset.get_gen_person() in manual_filtered_ids]
                print(f"After manual filter, total records: {len(self.filter_pool)}")



def input_prime_surname(last_prime_surname=None):
    if last_prime_surname:
        last_name = input(f"Enter prime_surname (default: {last_prime_surname}): ")
        if not last_name:
            last_name = last_prime_surname
    else:
        last_name = input("Enter prime_surname: ")
    return last_name

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

    while True:
        try:
            selected_num = int(input("Enter the number of the GEDCOM file you want to use: "))
            if 1 <= selected_num <= len(gedcom_files):
                return gedcom_files[selected_num - 1]
            else:
                print("Invalid number. Please enter a valid number from the list.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

gedcom_file_path = select_gedcom_file() # Call the function to let the user select the GEDCOM file
if gedcom_file_path:
    # Use the selected GEDCOM file path to create an instance of the Gedcom class
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    individuals = []  # Initialize the list of individuals

    for dataset in gedcom_instance.filter_pool:    # Iterate over the filter_pool list,add each last name and ID to list
        individual_id = dataset.get_gen_person()
        last_name = dataset.get_anchor_gen1()
        individuals.append((last_name, individual_id))
#*******************************************************************start loop to reset all variables
# Existing code above ...

#for dataset in gedcom_instance.filter_pool:  # Start of the loop
#    individual_id = dataset.get_gen_person()
#    last_name = dataset.get_anchor_gen1()
#    individuals.append((last_name, individual_id))

    # Your individual-specific processing code goes here

# Existing code below ...
#***************************************************************************************************END

#    print(f'Records tagged and filtered by NPFX: {len(individuals)}')

    with open(gedcom_file_path, 'r') as file:    # Read the GEDCOM file and split it into individual and family records
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

def has_both_parents(records, mother_id, father_id):
    return mother_id in records and father_id in records

def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]
    if famc_id not in records:
        return

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)

def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]
    last_name = last_name[:10].rstrip('/')
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def find_distant_ancestors(individual_id, records, path=None):
    if path is None:
        path = [individual_id]
    else:
        path.append(individual_id)

    if individual_id not in records:
        return []

    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]

    if famc_id not in records:
        return [path]

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if father_id is None and mother_id is None:
        return [path]

    paths = []
    if father_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(father_id, records, new_path))

    if mother_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(mother_id, records, new_path))

    return paths

#********************************************************************LINE FINDING BELOW?
filtered_datasets = gedcom_instance.filter_pool

for dataset in filtered_datasets:
    individual_id = dataset.get_gen_person()
    print(f"283-Processing individual with ID: {individual_id}")   #(KEEP)

    distant_ancestors_paths = find_distant_ancestors(individual_id, records)
#    print("286-Distant Ancestors Paths:", distant_ancestors_paths)

indexed_paths = {i: path for i, path in enumerate(distant_ancestors_paths)}

#name_paths = []
#for path in distant_ancestors_paths:
#    name_path = [extract_name(records.get(id, '')) for id in path]
#    name_paths.append(name_path)

for idx, name_path in enumerate(name_paths):# Check for the surname 'Yates' in the paths
    has_yates = any("Yates" in name for name in name_path)
    if has_yates:
        print(f"Path index: {idx}, Contains Yates: {has_yates}, Names: {name_path}")

name_paths = []
for path in distant_ancestors_paths:
    name_path = [extract_name(records.get(id, '')) for id in path]
    name_paths.append(name_path)

for idx, name_path in enumerate(name_paths):# Check for the surname 'Yates' in the paths
    has_yates = any("Yates" in name for name in name_path)
    if has_yates:
        pass  # Do nothing, but satisfies Python's requirement for an indented block

# Inside your main loop where individual_id is processed

# Resetting or recalculating path_scores
path_scores = {}

# Loop through the paths and apply the scoring scheme
for idx, name_path in enumerate(name_paths):
    score = 0
    for generation, name in enumerate(name_path):
        if 'Yates' in name:
            score += 1 * (generation + 1)
    path_scores[idx] = score

# Checking if path_scores is empty
if path_scores:
    # Re-calculating winning_path_index and winning_path_score
    winning_path_index = max(path_scores, key=path_scores.get)
    winning_path_score = path_scores[winning_path_index]
    winning_path_names = name_paths[winning_path_index]

    print(f"337-High Branch score was {winning_path_score}.")
    print(f"338-Names in the winning path: {winning_path_names}")

    # Add additional code here to update DataFrame or perform other tasks for this individual
else:
    winning_path_index = None
    winning_path_score = 0  # or some other default value
    winning_path_names = []  # or some other default value

    print("337-No paths to score.")
    print("338-No winning path.")

    # Add additional code here for the case where there are no paths to score


winning_path_names.reverse()  # Reversing the list for highest generation first

spouse_names = ['unknown'] * len(winning_path_names)  # Replace with real names or keep as 'unknown'

formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)] # Combine names and spouses

final_output = "|".join(formatted_names) # Join all the formatted names with '|'

print("352-Selected DNA Branch:", final_output)

#visited_pairs = set()

def process_individual(individual_id, gedcom_instance):
    global generation_table
    global visited_pairs

    # Resetting the variables for each individual
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    visited_pairs = set()

    find_parents(individual_id, 1, records)

    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    generation_table = generation_table.sort_values('Generation', ascending=False).reset_index(drop=True)

    individual_data = {}
    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            individual_data['cM'] = dataset.get_extractable_cm()
            individual_data['Sort'] = dataset.get_extractable_sort()
            break  # Update for multiple records. The score and filtered line do not come from here...


    filtered_parent_pairs = [row['Parent Pair'] for index, row in generation_table.iterrows() if any(parent in final_output for parent in row['Parent Pair'].split())]

    selected_dna_branch_parents = set(parent.split('&')[0] for parent in final_output.split('|'))

    filtered_parent_pairs = {}
    for index, row in generation_table.iterrows():
        generation = row['Generation']
        parent_pair = row['Parent Pair']
        for parent in parent_pair.split('&'):
            if parent in selected_dna_branch_parents:
                filtered_parent_pairs[generation] = parent_pair
                break

    # Convert filtered_parent_pairs to a string format, omitting generation numbers
    filtered_parent_pairs_str = '|'.join(filtered_parent_pairs.values())

    individual_data['Filtered Ancestral Line'] = filtered_parent_pairs_str    # Add it to individual_data

    return individual_data
#********************************************************
#print(generation_table)
#print(final_output)
#filtered_parent_pairs = [row['370-Parent Pair'] for index, row in generation_table.iterrows() if any(parent in final_output for parent in row['Parent Pair'].split())]
#print(filtered_parent_pairs)
#for index, row in generation_table.iterrows():
#    print("373-Parent Pair in generation_table:", row['Parent Pair'].split())
#    print("374-Parent in final_output:", [parent for parent in row['Parent Pair'].split() if parent in final_output])
#********************************************************
import pandas as pd

# Global variables
generation_table = None
visited_pairs = set()

# Assuming gedcom_instance and path_scores variables are already defined
filtered_individuals = [(dataset.get_anchor_gen1(), dataset.get_gen_person()) for dataset in gedcom_instance.filter_pool]

combined_df_rows = []   # Initialize your empty combined_df_rows list

# Loop through each individual in the filtered_individuals list
for name, individual_id in filtered_individuals:
    individual_data = process_individual(individual_id, gedcom_instance)
    cm = individual_data['cM']
    sort = individual_data['Sort']
    winning_path_score = path_scores[winning_path_index]
    filtered_parent_pairs_str = individual_data['Filtered Ancestral Line']
    combined_df_rows.append([individual_id, name, sort, cm, winning_path_score, filtered_parent_pairs_str])

# Create the DataFrame
combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Name', 'Match to', 'cM', 'Score', 'Filtered Ancestral Line'])

# Print the DataFrame
print(combined_df)

# Export to Excel
combined_df.to_excel('/content/output.xlsx', index=False)

#def create_hotlink(row):  # Function to create hotlinks
#    url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
#    person_id = row['ID#']
#    hotlink = f'{person_id}'
#    return hotlink
# Create hotlinks
#combined_df['LUN#'] = combined_df.apply(lambda row: create_hotlink(row), axis=1)

#******************************************************************(KEEP!!!!!!!!!!!!!!!!!)

# Initialize an empty dictionary to hold the filtered parent pairs
#filtered_parent_pairs = {}

# Assuming that selected_dna_branch_parents is a set containing individual parent names from 'Selected DNA Branch'
# Create the set from your actual 'Selected DNA Branch' string
#selected_dna_branch_parents = set(parent.split('&')[0] for parent in final_output.split('|'))

# Loop through the DataFrame to filter parent pairs
#for index, row in generation_table.iterrows():
#    generation = row['Generation']
#    parent_pair = row['Parent Pair']
#    for parent in parent_pair.split('&'):
#        if parent in selected_dna_branch_parents:
#            filtered_parent_pairs[generation] = parent_pair
#            break  # Once a match is found, no need to continue looking in this pair

# Display the filtered parent pairs
#print(filtered_parent_pairs)
#*****************************************************************************************KEEP!!!!!!!!!!!
# Out:
# Automatically selecting the first GEDCOM file.
# Records tagged and filtered by NPFX: 375
# filtered_ids.xlsx not found. Skipping second-level manual filter.
# 283-Processing individual with ID: I13817
# 283-Processing individual with ID: I21743
# 283-Processing individual with ID: I23678
# 283-Processing individual with ID: I26925
# 283-Processing individual with ID: I31861
# 283-Processing individual with ID: I40190
# 283-Processing individual with ID: I42478
# 283-Processing individual with ID: I44570
# 283-Processing individual with ID: I44883
# 283-Processing individual with ID: I44894
# 283-Processing individual with ID: I44935
# 283-Processing individual with ID: I45040
# 283-Processing individual with ID: I45059
# 283-Processing individual with ID: I45072
# 283-Processing individual with ID: I45084
# 283-Processing individual with ID: I45104
# 283-Processing individual with ID: I45119
# 283-Processing individual with ID: I45133
# 283-Processing individual with ID: I45149
# 283-Processing individual with ID: I45150
# 283-Processing individual with ID: I45201
# 283-Processing individual with ID: I45394
# 283-Processing individual with ID: I45417
# 283-Processing individual with ID: I45439
# 283-Processing individual with ID: I45462
# 283-Processing individual with ID: I45467
# 283-Processing individual with ID: I45499
# 283-Processing individual with ID: I45520
# 283-Processing individual with ID: I45534
# 283-Processing individual with ID: I45552
# 283-Processing individual with ID: I45591
# 283-Processing individual with ID: I45612
# 283-Processing individual with ID: I45632
# 283-Processing individual with ID: I45636
# 283-Processing individual with ID: I45665
# 283-Processing individual with ID: I45670
# 283-Processing individual with ID: I45672
# 283-Processing individual with ID: I45690
# 283-Processing individual with ID: I45700
# 283-Processing individual with ID: I45722
# 283-Processing individual with ID: I45741
# 283-Processing individual with ID: I45809
# 283-Processing individual with ID: I45823
# 283-Processing individual with ID: I45833
# 283-Processing individual with ID: I45864
# 283-Processing individual with ID: I45897
# 283-Processing individual with ID: I45907
# 283-Processing individual with ID: I45932
# 283-Processing individual with ID: I45937
# 283-Processing individual with ID: I45949
# 283-Processing individual with ID: I45980
# 283-Processing individual with ID: I46008
# 283-Processing individual with ID: I46034
# 283-Processing individual with ID: I46054
# 283-Processing individual with ID: I46068
# 283-Processing individual with ID: I46085
# 283-Processing individual with ID: I46102
# 283-Processing individual with ID: I46119
# 283-Processing individual with ID: I46129
# 283-Processing individual with ID: I46144
# 283-Processing individual with ID: I46154
# 283-Processing individual with ID: I46168
# 283-Processing individual with ID: I46175
# 283-Processing individual with ID: I46186
# 283-Processing individual with ID: I46197
# 283-Processing individual with ID: I46207
# 283-Processing individual with ID: I46214
# 283-Processing individual with ID: I46231
# 283-Processing individual with ID: I46243
# 283-Processing individual with ID: I46269
# 283-Processing individual with ID: I46285
# 283-Processing individual with ID: I46303
# 283-Processing individual with ID: I46317
# 283-Processing individual with ID: I46330
# 283-Processing individual with ID: I46346
# 283-Processing individual with ID: I46370
# 283-Processing individual with ID: I46390
# 283-Processing individual with ID: I46402
# 283-Processing individual with ID: I46403
# 283-Processing individual with ID: I46415
# 283-Processing individual with ID: I46423
# 283-Processing individual with ID: I46430
# 283-Processing individual with ID: I46448
# 283-Processing individual with ID: I46457
# 283-Processing individual with ID: I46470
# 283-Processing individual with ID: I46495
# 283-Processing individual with ID: I46502
# 283-Processing individual with ID: I46508
# 283-Processing individual with ID: I46516
# 283-Processing individual with ID: I46528
# 283-Processing individual with ID: I46538
# 283-Processing individual with ID: I46550
# 283-Processing individual with ID: I46562
# 283-Processing individual with ID: I46572
# 283-Processing individual with ID: I46584
# 283-Processing individual with ID: I46593
# 283-Processing individual with ID: I46603
# 283-Processing individual with ID: I46628
# 283-Processing individual with ID: I46641
# 283-Processing individual with ID: I46655
# 283-Processing individual with ID: I46667
# 283-Processing individual with ID: I46681
# 283-Processing individual with ID: I46706
# 283-Processing individual with ID: I46721
# 283-Processing individual with ID: I46750
# 283-Processing individual with ID: I46764
# 283-Processing individual with ID: I46792
# 283-Processing individual with ID: I46811
# 283-Processing individual with ID: I46826
# 283-Processing individual with ID: I46836
# 283-Processing individual with ID: I46847
# 283-Processing individual with ID: I46861
# 283-Processing individual with ID: I46872
# 283-Processing individual with ID: I46881
# 283-Processing individual with ID: I46894
# 283-Processing individual with ID: I46903
# 283-Processing individual with ID: I46917
# 283-Processing individual with ID: I46924
# 283-Processing individual with ID: I46934
# 283-Processing individual with ID: I46945
# 283-Processing individual with ID: I46954
# 283-Processing individual with ID: I46965
# 283-Processing individual with ID: I46985
# 283-Processing individual with ID: I46996
# 283-Processing individual with ID: I47009
# 283-Processing individual with ID: I47026
# 283-Processing individual with ID: I47039
# 283-Processing individual with ID: I47054
# 283-Processing individual with ID: I47076
# 283-Processing individual with ID: I47088
# 283-Processing individual with ID: I47098
# 283-Processing individual with ID: I47110
# 283-Processing individual with ID: I47123
# 283-Processing individual with ID: I47131
# 283-Processing individual with ID: I47142
# 283-Processing individual with ID: I47156
# 283-Processing individual with ID: I47163
# 283-Processing individual with ID: I47172
# 283-Processing individual with ID: I47182
# 283-Processing individual with ID: I47193
# 283-Processing individual with ID: I47205
# 283-Processing individual with ID: I47216
# 283-Processing individual with ID: I47228
# 283-Processing individual with ID: I47241
# 283-Processing individual with ID: I47250
# 283-Processing individual with ID: I47257
# 283-Processing individual with ID: I47270
# 283-Processing individual with ID: I47279
# 283-Processing individual with ID: I47292
# 283-Processing individual with ID: I47306
# 283-Processing individual with ID: I47318
# 283-Processing individual with ID: I47327
# 283-Processing individual with ID: I47338
# 283-Processing individual with ID: I47350
# 283-Processing individual with ID: I47365
# 283-Processing individual with ID: I47379
# 283-Processing individual with ID: I47393
# 283-Processing individual with ID: I47406
# 283-Processing individual with ID: I47416
# 283-Processing individual with ID: I47427
# 283-Processing individual with ID: I47435
# 283-Processing individual with ID: I47447
# 283-Processing individual with ID: I47466
# 283-Processing individual with ID: I47497
# 283-Processing individual with ID: I47510
# 283-Processing individual with ID: I47528
# 283-Processing individual with ID: I47542
# 283-Processing individual with ID: I47691
# 283-Processing individual with ID: I47698
# 283-Processing individual with ID: I47711
# 283-Processing individual with ID: I47733
# 283-Processing individual with ID: I47798
# 283-Processing individual with ID: I47806
# 283-Processing individual with ID: I47881
# 283-Processing individual with ID: I47891
# 283-Processing individual with ID: I47906
# 283-Processing individual with ID: I47918
# 283-Processing individual with ID: I47929
# 283-Processing individual with ID: I47948
# 283-Processing individual with ID: I47958
# 283-Processing individual with ID: I47971
# 283-Processing individual with ID: I47979
# 283-Processing individual with ID: I48125
# 283-Processing individual with ID: I48151
# 283-Processing individual with ID: I48162
# 283-Processing individual with ID: I48171
# 283-Processing individual with ID: I48182
# 283-Processing individual with ID: I48195
# 283-Processing individual with ID: I48210
# 283-Processing individual with ID: I48217
# 283-Processing individual with ID: I48228
# 283-Processing individual with ID: I48240
# 283-Processing individual with ID: I48247
# 283-Processing individual with ID: I48257
# 283-Processing individual with ID: I48274
# 283-Processing individual with ID: I48278
# 283-Processing individual with ID: I48292
# 283-Processing individual with ID: I48304
# 283-Processing individual with ID: I48314
# 283-Processing individual with ID: I48331
# 283-Processing individual with ID: I48337
# 283-Processing individual with ID: I48354
# 283-Processing individual with ID: I48375
# 283-Processing individual with ID: I48384
# 283-Processing individual with ID: I48391
# 283-Processing individual with ID: I48403
# 283-Processing individual with ID: I48415
# 283-Processing individual with ID: I48420
# 283-Processing individual with ID: I48430
# 283-Processing individual with ID: I48438
# 283-Processing individual with ID: I48452
# 283-Processing individual with ID: I48471
# 283-Processing individual with ID: I48481
# 283-Processing individual with ID: I48489
# 283-Processing individual with ID: I48503
# 283-Processing individual with ID: I48516
# 283-Processing individual with ID: I48525
# 283-Processing individual with ID: I48538
# 283-Processing individual with ID: I48552
# 283-Processing individual with ID: I48560
# 283-Processing individual with ID: I48573
# 283-Processing individual with ID: I48581
# 283-Processing individual with ID: I48593
# 283-Processing individual with ID: I48605
# 283-Processing individual with ID: I48614
# 283-Processing individual with ID: I48627
# 283-Processing individual with ID: I48628
# 283-Processing individual with ID: I48642
# 283-Processing individual with ID: I48652
# 283-Processing individual with ID: I48664
# 283-Processing individual with ID: I48670
# 283-Processing individual with ID: I48674
# 283-Processing individual with ID: I48686
# 283-Processing individual with ID: I48697
# 283-Processing individual with ID: I48706
# 283-Processing individual with ID: I48710
# 283-Processing individual with ID: I48721
# 283-Processing individual with ID: I48728
# 283-Processing individual with ID: I48737
# 283-Processing individual with ID: I48744
# 283-Processing individual with ID: I48752
# 283-Processing individual with ID: I48765
# 283-Processing individual with ID: I48767
# 283-Processing individual with ID: I48784
# 283-Processing individual with ID: I48792
# 283-Processing individual with ID: I48799
# 283-Processing individual with ID: I48812
# 283-Processing individual with ID: I48821
# 283-Processing individual with ID: I48830
# 283-Processing individual with ID: I48837
# 283-Processing individual with ID: I48843
# 283-Processing individual with ID: I48857
# 283-Processing individual with ID: I48868
# 283-Processing individual with ID: I48887
# 283-Processing individual with ID: I48898
# 283-Processing individual with ID: I48901
# 283-Processing individual with ID: I48919
# 283-Processing individual with ID: I48935
# 283-Processing individual with ID: I48945
# 283-Processing individual with ID: I48954
# 283-Processing individual with ID: I48965
# 283-Processing individual with ID: I48970
# 283-Processing individual with ID: I48983
# 283-Processing individual with ID: I48998
# 283-Processing individual with ID: I49006
# 283-Processing individual with ID: I49020
# 283-Processing individual with ID: I49027
# 283-Processing individual with ID: I49039
# 283-Processing individual with ID: I49061
# 283-Processing individual with ID: I49076
# 283-Processing individual with ID: I49085
# 283-Processing individual with ID: I49095
# 283-Processing individual with ID: I49101
# 283-Processing individual with ID: I49115
# 283-Processing individual with ID: I49132
# 283-Processing individual with ID: I49140
# 283-Processing individual with ID: I49152
# 283-Processing individual with ID: I49165
# 283-Processing individual with ID: I49178
# 283-Processing individual with ID: I49189
# 283-Processing individual with ID: I49197
# 283-Processing individual with ID: I49206
# 283-Processing individual with ID: I49220
# 283-Processing individual with ID: I49230
# 283-Processing individual with ID: I49240
# 283-Processing individual with ID: I49250
# 283-Processing individual with ID: I49276
# 283-Processing individual with ID: I49289
# 283-Processing individual with ID: I49316
# 283-Processing individual with ID: I49326
# 283-Processing individual with ID: I49337
# 283-Processing individual with ID: I49369
# 283-Processing individual with ID: I49380
# 283-Processing individual with ID: I49396
# 283-Processing individual with ID: I49402
# 283-Processing individual with ID: I49409
# 283-Processing individual with ID: I49427
# 283-Processing individual with ID: I49442
# 283-Processing individual with ID: I49444
# 283-Processing individual with ID: I49459
# 283-Processing individual with ID: I49465
# 283-Processing individual with ID: I49471
# 283-Processing individual with ID: I49476
# 283-Processing individual with ID: I49491
# 283-Processing individual with ID: I49502
# 283-Processing individual with ID: I49511
# 283-Processing individual with ID: I49520
# 283-Processing individual with ID: I49565
# 283-Processing individual with ID: I49570
# 283-Processing individual with ID: I49580
# 283-Processing individual with ID: I49593
# 283-Processing individual with ID: I49607
# 283-Processing individual with ID: I49615
# 283-Processing individual with ID: I49636
# 283-Processing individual with ID: I49652
# 283-Processing individual with ID: I49657
# 283-Processing individual with ID: I49673
# 283-Processing individual with ID: I49682
# 283-Processing individual with ID: I49693
# 283-Processing individual with ID: I49699
# 283-Processing individual with ID: I49708
# 283-Processing individual with ID: I49717
# 283-Processing individual with ID: I49730
# 283-Processing individual with ID: I49755
# 283-Processing individual with ID: I49784
# 283-Processing individual with ID: I49799
# 283-Processing individual with ID: I49813
# 283-Processing individual with ID: I49833
# 283-Processing individual with ID: I49847
# 283-Processing individual with ID: I49862
# 283-Processing individual with ID: I49876
# 283-Processing individual with ID: I49896
# 283-Processing individual with ID: I49905
# 283-Processing individual with ID: I49917
# 283-Processing individual with ID: I49955
# 283-Processing individual with ID: I49982
# 283-Processing individual with ID: I49996
# 283-Processing individual with ID: I50006
# 283-Processing individual with ID: I50013
# 283-Processing individual with ID: I50024
# 283-Processing individual with ID: I50033
# 283-Processing individual with ID: I50046
# 283-Processing individual with ID: I50057
# 283-Processing individual with ID: I50069
# 283-Processing individual with ID: I50098
# 283-Processing individual with ID: I50111
# 283-Processing individual with ID: I50124
# 283-Processing individual with ID: I50144
# 283-Processing individual with ID: I50164
# 283-Processing individual with ID: I50184
# 283-Processing individual with ID: I50191
# 283-Processing individual with ID: I50225
# 283-Processing individual with ID: I50249
# 283-Processing individual with ID: I50264
# 283-Processing individual with ID: I50275
# 283-Processing individual with ID: I50309
# 283-Processing individual with ID: I50326
# 283-Processing individual with ID: I50355
# 283-Processing individual with ID: I50364
# 283-Processing individual with ID: I50369
# 283-Processing individual with ID: I50375
# 283-Processing individual with ID: I50391
# 283-Processing individual with ID: I50405
# 283-Processing individual with ID: I50416
# 283-Processing individual with ID: I50429
# 283-Processing individual with ID: I50440
# 283-Processing individual with ID: I50449
# 283-Processing individual with ID: I50459
# 283-Processing individual with ID: I50472
# 283-Processing individual with ID: I50482
# 283-Processing individual with ID: I50494
# 283-Processing individual with ID: I50511
# 283-Processing individual with ID: I50522
# 283-Processing individual with ID: I50535
# 283-Processing individual with ID: I50551
# Path index: 2, Contains Yates: True, Names: ['YatesThomas', 'YatesWilliam', 'YatesThomas', 'YatesJonathan', 'YatesThomasJe', 'YatesRachelNe', 'WestermanDeborahE', 'NewtonJasonWes', 'NewtonFrankEdw', 'NewtonMarkGarn']
# Path index: 3, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'YatesThomasJe', 'YatesJonathan', 'YatesThomas', 'IszardSarah', 'IszardMichael']
# Path index: 4, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'YatesThomasJe', 'YatesJonathan', 'YatesThomas', 'IszardSarah', 'ReevesSarah']
# Path index: 5, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'YatesThomasJe', 'YatesJonathan', 'SwainPhebe', 'SwainNezer']
# Path index: 6, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'YatesThomasJe', 'FrazeeMary', 'FrazeeMoses']
# Path index: 7, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'YatesThomasJe', 'FrazeeMary', 'MorrisPriscilla']
# Path index: 8, Contains Yates: True, Names: ['NewtonMarkGarn', 'NewtonFrankEdw', 'NewtonJasonWes', 'WestermanDeborahE', 'YatesRachelNe', 'RossNancyDra']
# 337-High Branch score was 169.
# 338-Names in the winning path: ['NicholsTheresaC', 'NicholsNormanWa', 'RosamondInaMae', 'OverturfFloraEdi', 'OverturfEliBenja', 'OverturfFrancisM', 'YatesRachelAn', 'YatesBenjamin', 'YatesBenjamin', 'YatesWilliam', 'YatesGeorge', 'YatesGeorge', 'YatesGeorge', 'YatesJohn', 'YatesThomas', 'YatesFrancis', 'YatesThomas', 'YatesJohn', 'YatesRichard']
# 352-Selected DNA Branch: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesBenjamin&unknown|YatesBenjamin&unknown|YatesRachelAn&unknown|OverturfFrancisM&unknown|OverturfEliBenja&unknown|OverturfFloraEdi&unknown|RosamondInaMae&unknown|NicholsNormanWa&unknown|NicholsTheresaC&unknown
#         ID#                Name         Match to  cM  Score  \
# 0    I13817        YatesWilliam      yates,johnh  11    169
# 1    I21743          HuntKelsey    yates,robertd  15    169
# 2    I23678       JohnsonDonald    yates,andreal  53    169
# 3    I26925            HudsonJL    yates,andreal  27    169
# 4    I31861         ChurchDebra  yates,patricial  19    169
# ..      ...                 ...              ...  ..    ...
# 370  I50494       BeaversLaNell     yates,ronald  16    169
# 371  I50511       StiversKaylee      yatesronald  14    169
# 372  I50522  FehrenbacherAngela      yatesronald  17    169
# 373  I50535      PetersonHannah     yates,ronald  14    169
# 374  I50551      NicholsTheresa     yates,ronald   8    169
#
#                                Filtered Ancestral Line
# 0                                         YatesWilliam
# 1    YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 2    YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 3
# 4    YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# ..                                                 ...
# 370  YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 371  YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 372  YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 373  YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
# 374  YatesRichard&AshendonJoan|YatesJohn&HydeAlice|...
#
# [375 rows x 6 columns]

# %%
# !pip install pandas
# !pip install python-gedcom
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting python-gedcom
#   Downloading python_gedcom-1.0.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
