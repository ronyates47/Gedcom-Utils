# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/gedcomscript_v_230730_1035_hrs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !pip install python-gedcom
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting python-gedcom
#   Downloading python_gedcom-1.0.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0

# %%
# Keep as baseline
class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_datasets = []
        self.filter_pool = []

    def parse_gedcom(self):
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()

        current_dataset = None
        npfx_count = 0
        total_count = 0
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                total_count += 1
                current_dataset = GedcomDataset(tag)
                self.gedcom_datasets.append(current_dataset)
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_key = tag
                    current_dataset.add_extractable_detail(current_key, value)
                elif level == 2 and tag == 'NPFX':
                    npfx_count += 1
                    current_dataset.add_extractable_detail(tag, value)

        print(f'Found {total_count} total records')
        print(f'Found {npfx_count} NPFX tags')

        # Filter datasets based on presence of NPFX tag
        for dataset in self.gedcom_datasets:
            if dataset.get_extractable_NPFX():
                self.filter_pool.append(dataset)

    def print_extractable_details(self):
        headers = ['ID#', 'Anchor_gen1', 'cM', 'Sort', 'Parents']
        col_widths = [max(len(header), 20) for header in headers]
        header_row = ''.join(header.center(col_widths[i]) for i, header in enumerate(headers))
        print(header_row)
        for i, dataset in enumerate(self.filter_pool):
            if i >= 500:
                break
            row = []
            row.append(dataset.get_gen_person())
            row.append(dataset.get_anchor_gen1())
            row.append(dataset.get_extractable_cm())
            row.append(dataset.get_extractable_sort())
            row.append(dataset.get_extractable_FAMC())
            data_row = ''.join(str(data).center(col_widths[i]) for i, data in enumerate(row))
            print(data_row)

class GedcomDataset:
    def __init__(self, gen_person):
        self.gen_person = gen_person
        self.extractable_detail = {}

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        # Extract and return the gen_person value from the gedcom_dataset
        name = self.extractable_detail.get('NAME', '')
        first_name, last_name = name.split('/', 1)
        first_name = first_name.split(' ')[0]
        last_name = last_name.rstrip('/')
        self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
        return self.gen_person.strip('@')

    def get_anchor_gen1(self):
        # Return the anchor_gen1 value from the gedcom_dataset
        return self.anchor_gen1

    def get_extractable_NPFX(self):
        # Extract and return the extractable_NPFX (prefix of extractable_name) from the gedcom_dataset
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        # Extract and return the extractable_cm (left side of NPFX split at "&") from the gedcom_dataset
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        # Extract and return the extractable_sort (right side of NPFX split at "&") from the gedcom_dataset
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        # Extract and return the extractable_FAMC (paired parents of extractable_name) from the gedcom_dataset
        return self.extractable_detail.get('FAMC', '').strip('@')

dna_generations = Gedcom('dna_generations.ged')
dna_generations.parse_gedcom()
dna_generations.print_extractable_details()
# Out:
# Found 50775 total records
# Found 155 NPFX tags
#         ID#             Anchor_gen1              cM                 Sort              Parents
#         I335            MorganMorgan           error                                    F274
#         I353           PrickettJacob           error
#         I360            MorganJames            error                                    F258
#        I1193            MorganMorgan           error
#        I1706             YatesJohn             error                                    F403
#        I3670            EminentJames           error
#        I4352             GlennJames            error                                   F2337
#        I5620             YatesAnne             error                                   F8412
#        I6966           GillilandRalph          error                                   F3469
#        I6967          GillilandCharles         error                                   F3469
#        I7790            BurtonRiley            error
#        I8982              WestJohn             error
#        I8996            MorganDavid            error                                    F286
#        I9916           StockettThomas          error
#        I10130          MorganAchilles          error                                   F2166
#        I10663         RobinsonCharles          error                                   F4491
#        I10844           YatesRichard           error                                   F4334
#        I10845           YatesRichard           error                                   F4614
#        I10860            YatesHenry            error                                   F4619
#        I10863           MarshallJohn           error                                   F4626
#        I11177           YatesElwood            error                                   F9919
#        I11548         YatesChristopher         error                                   F4871
#        I11550           YatesJoseph            error                                   F4870
#        I11669           YatesRobert            error                                   F4934
#        I11671         YatesBartholomew         error                                   F4936
#        I11710           YatesJasper            error                                   F4955
#        I11783         ClevelandRobert          error
#        I11914           YatesGeorge            error                                   F4330
#        I11918           YatesWilliam           error                                   F4330
#        I12053           YatesWilliam           error                                   F4934
#        I12068            YatesPeter            error                                   F4482
#        I12107           YatesRobert            error                                   F5091
#        I12179          BaileyWilliam           error
#        I12710             YatesM.              error
#        I12873           BuckmanJulia           error                                   F13024
#        I13206            WilderPaul            error
#        I13344         WarnerAugustine          error                                   F5531
#        I13421           MorganDaniel           error
#        I13817           YatesWilliam             11                                    F5668
#        I13860            YatesJohn             error                                   F5686
#        I13932           YatesCharles           error                                   F5705
#        I14239           SeacatWalter           error                                   F5788
#        I15047         WashingtonGeorge         error                                    F672
#        I15130           SmithCharles           error                                   F5976
#        I15178         WarnerAugustine          error                                   F5530
#        I15194        WashingtonLawrence        error
#        I15237            SmithJohn             error                                   F5976
#        I15264          SmithLawrence           error
#        I17226          BuckmanTeresa           error                                   F13024
#        I18593            YatesJohn             error                                   F13378
#        I18639            YatesJames            error                                   F6883
#        I18727           GirdnerIsaac           error                                   F6960
#        I19052          StirlingYates           error                                   F7051
#        I20223           YatesFrancis           error                                   F4936
#        I20390          RobersonJames           error                                   F7424
#        I20784           BootheJames            error                                   F4348
#        I21177           RandolphJohn           error                                   F1064
#        I21187            HenryJohn             error
#        I21215           MontagueJohn           error
#        I21220          MontagueJames           error
#        I21743            HuntKelsey              15                                    F17473
#        I23066           MartinJoseph           error
#        I23369         SimpsonForrestt            13                                    F17893
#        I23612           YatesJoseph            error                                   F8224
#        I23678          JohnsonDonald             53                                    F14509
#        I24184          StaatsWilliam           error
#        I24202           FairlieJames           error
#        I24300           YatesCharles           error                                   F4874
#        I24487           YatesFrances           error                                   F8412
#        I24502           YatesThomas            error                                   F16652
#        I24605          YatesJohannes           error                                   F4870
#        I24607          BosworthJoseph          error
#        I24659           YatesArthur            error                                   F8482
#        I24732          BuchananJames           error                                   F5862
#        I25610          LansingGerrit           error                                   F8377
#        I25615           LansingJacob           error                                   F8754
#        I25634           CollinsFred            error                                   F8762
#        I25651          LewisFielding           error                                   F4335
#        I26512            YatesJohn             error                                   F8148
#        I26925             HudsonJL               26                                    F13272
#        I28106            YatesAllen            error                                   F4979
#        I28115          HazelwoodJohn           error
#        I29618           HandJonathan           error                                   F9790
#        I30395         BuckmanKatherine         error                                   F13024
#        I31861           ChurchDebra              19                                    F9370
#        I32037         CarpenterFrancis         error                                   F10462
#        I32048          CarpenterJames          error                                   F10462
#        I32050        TillinghastPardon         error                                   F11176
#        I32054          CarpenterJames          error                                   F10464
#        I32174           WilletsJohn            error
#        I34363           YatesAustin            error                                   F11074
#        I34543         BlackwoodWilliam         error
#        I37053           StithWilliam           error                                   F11935
#        I40084          YatesArchibald          error
#        I40190             DikeBeth               37                                    F13539
#        I42478            RoperHolly              28                                    F14508
#        I44570           HepburnMark              15                                    F15318
#        I44883           YatesRobert              13                                    F15447
#        I44894            YatesCraig              14                                    F15447
#        I44935          PugsleyHarold             11                                    F15467
#        I45040            KeethLaura              8                                     F15498
#        I45059          OstergaardDale            8                                     F15507
#        I45072         JusticeVirginia            8                                     F15509
#        I45084          AndrewsMarvin             8                                     F15515
#        I45104           DaleJuletta              8                                     F15524
#        I45119          KearleyCharles            9                                     F15532
#        I45133         LichtensteinEric           9                                     F15538
#        I46681          LauterLarraine          error                                   F16234
#        I46759           LeVeirFrank            error                                   F16271
#        I47551           GoddardJoan            error                                   F16680
#        I47562           YatesAndrew            error                                   F16651
#        I47569           YatesEdmund            error                                   F16660
#        I47570           YatesWilliam           error                                   F16699
#        I47577           HawkinsJohn            error
#        I47579            HydeRobert            error
#        I47580            YatesPeter            error                                   F16651
#        I47582          BrounckerHenry          error
#        I47586           GiffordJohn            error
#        I47587           YatesThomas            error                                   F16657
#        I47589           YatesRichard           error                                   F16657
#        I47593          YatesElizabeth          error                                   F16657
#        I47601          MartinWilliam           error                                   F16845
#        I47605         BraybrookeJames          error
#        I47609         WelsborneOliver          error
#        I47610            EystonJohn            error
#        I47616           YatesEdward            error                                   F16685
#        I47617            YatesJohn             error                                   F16657
#        I47618        FettiplacePhillip         error
#        I47656           JusticeMary            error                                   F16696
#        I47666           YatesWilliam           error                                   F16693
#        I47721            YatesJane             error                                   F8412
#        I47723           EystonThomas           error
#        I47788          RagsdaleThomas          error                                   F16758
#        I47816          RadcliffEdward          error
#        I47817            StuartMary            error                                   F16768
#        I47818            DavisMoll             error                                   F16769
#        I47820           HowardThomas           error
#        I47827            LattonJohn            error                                   F16858
#        I47829          MorrisPhillip           error
#        I47863        FettiplaceEleanor         error                                   F16669
#        I47864       FettiplaceElizabeth        error                                   F16669
#        I47865          PurefoyEdward           error
#        I47986           WhiteJerome            error                                   F16865
#        I47987           WhiteThomas            error                                   F16843
#        I47989           WhiteRobert            error                                   F16876
#        I47992            MartinJohn            error
#        I48018          GiffardThomas           error
#        I48026           YatesRobert            error
#        I48033            YatesHenry            error
#        I48035         StydolphFrancis          error
#        I48036           WhiteRichard           error
#        I48044           YatesWilliam           error                                   F16868
#        I48045            YatesJohn             error
#        I48069         TichborneRichard         error
#        I49296          YatesLucretia           error                                   F1439
