# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/2023_0930_1320_hrs_Yates_final_formatting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import openpyxl
import glob
import os
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.records = {}  # Initialize records attribute here
        self.gedcom_datasets = []  # Keep this if other parts of your code depend on it

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

    def parse_gedcom(self):
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()

        current_dataset = None
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                current_dataset = GedcomDataset(tag)
                self.records[tag] = current_dataset
                self.gedcom_datasets.append(current_dataset)  # Add to the list of datasets
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_dataset.add_extractable_detail(tag, value)
                elif level == 2 and tag == 'NPFX':
                    current_dataset.add_extractable_detail(tag, value)

#        print(f"47-GEDCOM contained {len(self.records)} total records")

    def apply_xlsx_filter(self, xlsx_file_path):  # BACKWARDS CONVERSION TO EASE xlsx MANUAL FILTER OF ID's
        if not os.path.exists(xlsx_file_path):
            print("xlsx file not found. Proceeding without filtering by xlsx.")
            return

        df = pd.read_excel(xlsx_file_path)  # Corrected this line
        # Add '@' to the beginning and end of each ID to match the GEDCOM format
        filtered_ids = set(f"@{x}@" for x in df['ID'])

        self.records = {k: v for k, v in self.records.items() if k in filtered_ids}

        print(f'Records manually xlsx filtered: {len(self.records)}')

    def apply_npfx_filter(self):
        filtered_records = {k: v for k, v in self.records.items() if v.get_extractable_NPFX()}
        # Update self.records to only contain the filtered records
        self.records = filtered_records
        print(f'66-Records tagged and filtered by NPFX: {len(self.records)}')
        print(f"64-'self.records' contains {len(self.records)} total records")

def extract_id(record):  # Moved outside of the class so it's a standalone function
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(gedcom_dataset_instance):# Moved outside of the class so it's a standalone function
    record = gedcom_dataset_instance.extractable_detail.get('NAME', '')
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]

    if '/' not in name:
#        print(f"78-Invalid name format for record: {record[:50]}...")  # Print the first 100 characters of the problematic record for debugging
        return None  # or you could return a default value like "UnknownUnknown"

    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]  # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/')  # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def has_both_parents(records, mother_id, father_id):   # Moved outside of the class so it's a standalone function
    return mother_id in records and father_id in records

class GedcomDataset:
    def __init__(self, individual_id):
        self.individual_id = individual_id
        self.extractable_detail = {}
        self.anchor_gen1 = None

    def add_extractable_detail(self, key, value):
#        print(f"96-Adding key: {key}, 97-value: {value}")  # This will print out the key and value being added
        self.extractable_detail[key] = value

    def get_gen_person(self):
        return self.individual_id.strip('@')

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

    def get_extractable_FAMS(self):
        return self.extractable_detail.get('FAMS', '').strip('@')

    def get_extractable_WIFE(self):
        return self.extractable_detail.get('WIFE', '').strip('@')

    def get_extractable_HUSB(self):
        return self.extractable_detail.get('HUSB', '').strip('@')

    def get_anchor_gen1(self):
        name = self.extractable_detail.get('NAME', '')
        if '/' in name:
            first_name, last_name = name.split('/', 1)
            first_name = first_name.split(' ')[0]
            last_name = last_name.rstrip('/')
            self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
            return self.anchor_gen1
        else:
            print(f"Warning: No '/' found in NAME tag for individual {self.get_gen_person()}")
            return ''

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

gedcom_file_path = select_gedcom_file()

if gedcom_file_path:
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    # Apply filters
    gedcom_instance.apply_xlsx_filter("/content/filtered_ids.xlsx")  # Replace with your actual xlsx file path
    gedcom_instance.apply_npfx_filter()

    individuals = []    # Initialize the list of individuals

    with open(gedcom_file_path, 'r') as file:    # Reading the GEDCOM file and parsing records
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

    # Create the filtered_records dictionary after self.records has been populated (DO WE STILL NEED THIS)
    filtered_records = {dataset.get_gen_person(): records.get(dataset.get_gen_person(), "") for dataset in gedcom_instance.records.values()}

# Include the sanitize_id function here
def sanitize_id(raw_id):
    return raw_id.replace('@', '')

# Your existing find_parents function
def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record = records[individual_id]

    famc_id = record.get_extractable_FAMC()
    if not famc_id:
        return

    fam_record = records.get(famc_id, None)
    if not fam_record:
        return

    mother_id = fam_record.get_extractable_WIFE()
    father_id = fam_record.get_extractable_HUSB()

    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)


def get_formatted_name(male_individual_id, female_individual_id, records):
    male_record = records.get(male_individual_id, "")
    female_record = records.get(female_individual_id, "")

    male_name = extract_name(male_record)
    female_name = extract_name(female_record)

    if male_name is None or female_name is None:
        print(f"Could not extract name for either male ID: {male_individual_id} or female ID: {female_individual_id}")
        return None  # or return a default value

    return male_name + "&" + female_name

most_distant_ancestors = []  # New list to collect most distant ancestors

def sanitize_id(raw_id):
    return raw_id.replace('@', '')

def find_distant_ancestors(individual_id, records, path=None, spouses=None, most_distant_ancestors=None):
    sanitized_id = sanitize_id(individual_id)  # Sanitize the ID here
    original_id = f"@{sanitized_id}@"  # Create original ID by adding '@' back

    if path is None:
        path = [original_id]  # Use the original ID with '@'

    # ... (rest of your existing code remains the same)

        path = [individual_id]
    if spouses is None:
        spouses = {}
    if most_distant_ancestors is None:
        most_distant_ancestors = []

    record = records.get(individual_id, None)
    if not record:
        print(f"Record not found for {individual_id}")
        return most_distant_ancestors, spouses, []  # Assuming you want an empty list as the third value

    famc_id = extract_famc_id(record)

    # Sanitizing and Checking IDs
    if sanitize_id(famc_id) not in map(sanitize_id, records.keys()):
        print(f"353-Warning: famc_id {famc_id} not found in records")
        return most_distant_ancestors, spouses, []  # Assuming you want an empty list as the third value

    famc_id = extract_famc_id(record)
    print(f"Debug: famc_id for {individual_id} is {famc_id}")  # Debug print

    if famc_id in records:
        mother_id, father_id = extract_parent_ids(records[famc_id])
        print(f"Debug: mother_id = {mother_id}, father_id = {father_id}")  # Debug print


    if famc_id in records:
        mother_id, father_id = extract_parent_ids(records[famc_id])

        if not mother_id and not father_id:
            most_distant_ancestors.append(path)

        if father_id:
            new_path = list(path) + [father_id]
            find_distant_ancestors(father_id, records, new_path, spouses, most_distant_ancestors)

        if mother_id:
            new_path = list(path) + [mother_id]
            find_distant_ancestors(mother_id, records, new_path, spouses, most_distant_ancestors)

    else:
        most_distant_ancestors.append(path)

    return most_distant_ancestors, spouses, []  # Assuming you want an empty list as the third value

def extract_famc_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_fams_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMS()

def extract_parent_ids(gedcom_dataset_instance):
    mother_id = gedcom_dataset_instance.get_extractable_WIFE()
    father_id = gedcom_dataset_instance.get_extractable_HUSB()
    return mother_id, father_id

#for individual_id in gedcom_instance.records.keys():  # Loop through the filtered IDs.
#    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(
#        individual_id, gedcom_instance.records
#    )
#    print(f"291-Most Distant Ancestors for {individual_id}: {most_distant_ancestors}")

#for individual_id, dataset in gedcom_instance.records.items():
#    print("286-Before accessing record")  # Debug print
#    record = gedcom_instance.records.get(individual_id, "")
#    print("288-After accessing record")  # Debug print
#    print(f"281-Type of record: {type(record)}, Content: {record}")

def extract_fam_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_parent_ids(fam_record):
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    return mother_id, father_id

def extract_spouse_id(fam_record, individual_record):
    if '1 HUSB @' in individual_record:
        spouse_start = fam_record.find('1 WIFE @') + 8
    else:
        spouse_start = fam_record.find('1 HUSB @') + 8
    spouse_end = fam_record.find('@', spouse_start)
    return fam_record[spouse_start:spouse_end]

# Your existing for loops
for individual_id in gedcom_instance.records.keys():  # Loop through the filtered IDs.
    sanitized_id = sanitize_id(individual_id)  # Sanitize ID
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(
        sanitized_id, gedcom_instance.records  # Use sanitized ID
    )
    print(f"319-Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")


individual_and_spouse = {}  # Create a dictionary to track individual and their spouse.


# Instead of using individual_id_to_search, loop through the filtered IDs.
for individual_id in gedcom_instance.records.keys():
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(individual_id, gedcom_instance.records)
#    print(f"352-Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")
    print(f"353-Most Distant Ancestors for {individual_id}: {most_distant_ancestors}")

indexed_paths = {i: path for i, path in enumerate(distant_ancestors_paths)}

# Assuming `spouses` is a dictionary where the key is the individual ID and the value is the spouse ID
spouses = {}  # Populate this based on your function that finds distant ancestors

name_paths = []

for path in distant_ancestors_paths:
    name_path_with_spouse = []
    for id in path:  # This should be a single ID, not a list
        individual_name = extract_name(records.get(id, GedcomDataset('')))
        spouse_id = spouses.get(id, None)
        spouse_name = extract_name(records.get(spouse_id, '')) if spouse_id else "unknown"
        name_path_with_spouse.append(f"{individual_name}&{spouse_name}")
    name_paths.append(name_path_with_spouse)

for idx, name_path in enumerate(name_paths):  # Check for the surname 'Yates' in the paths
    has_yates = any("Yates" in name for name in name_path)
    if has_yates:
        print(f"Path index: {idx}, Contains Yates: {has_yates}, Names: {name_path}")

path_scores = {}  # Initialize an empty dictionary to store the scores of each path

for idx, name_path in enumerate(name_paths): # Loop through the paths and apply the scoring scheme
    score = 0
    for generation, name in enumerate(name_path):
        if 'Yates' in name:
            score += 1 * (generation + 1)  # Add 1 to generation because index starts at 0
    path_scores[idx] = score     # Store the score of this path

# Find the index of the path with the highest score
#winning_path_index = max(path_scores, key=path_scores.get)
#winning_path_score = path_scores[winning_path_index]
#winning_path_names = name_paths[winning_path_index]

# Print the winning path to the console
#print(f"High Branch score was {winning_path_score}.")    #The winning path is at index {winning_path_index}
#print(f"Names in the winning path: {winning_path_names}")

#winning_path_names.reverse() # Reversing the list for highest generation first

# Adding spouses (Replace 'unknown' with actual spouse names if you have them)
#spouse_names = ['unknown'] * len(winning_path_names)  # Replace with real names or keep as 'unknown'

# Combine names and spouses in your specified format
#formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)]

#final_output = "|".join(formatted_names)# Join all the formatted names with '|'

#print("Selected DNA Branch:", final_output)

visited_pairs = set()

def process_individual(individual_id, gedcom_instance):
    global generation_table
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    global visited_pairs
    visited_pairs = set()

    find_parents(individual_id, 1, gedcom_instance.records)  # Changed to get records from gedcom_instance

    for dataset in gedcom_instance.records.values():  # Changed to get records from gedcom_instance
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    generation_table = generation_table.sort_values('Generation', ascending=False).reset_index(drop=True)

    individual_data = {}
    for dataset in gedcom_instance.records.values():  # Changed to get records from gedcom_instance
        if dataset.get_gen_person() == individual_id:
            individual_data['cM'] = dataset.get_extractable_cm()
            individual_data['Sort'] = dataset.get_extractable_sort()
            break

    individual_data['Parent Pairs A10'] = '|'.join([f"{row['Parent Pair']}" for index, row in generation_table[:10].iterrows()])

#    print(f"Returning data for {individual_id}: {individual_data}")  # Debug print
    return individual_data


import pandas as pd

# Global variables
generation_table = None
visited_pairs = set()

# Run the process_individual function for each individual in the filtered_individuals list and create a combined DataFrame
combined_df_rows = []
for individual_id, dataset in gedcom_instance.records.items():
    name = extract_name(dataset)  # Corrected line
    individual_data = process_individual(individual_id, gedcom_instance)
#    print("Debugging individual_data:", individual_data)  # This will print out the contents
    cm = individual_data.get('cM', 'Default Value')  # This will prevent KeyError
    sort = individual_data.get('Sort', 'Default Sort')
    parent_pairs_a10 = individual_data.get('Parent Pairs A10', 'Default Parent Pairs A10')
    # most_distant_ancestor = generation_table.iloc[0]['Parent Pair']  # Get the most distant ancestor from the last row of generation_table
    combined_df_rows.append([individual_id, name, sort, cm, parent_pairs_a10]) #, most_distant_ancestor

combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Name', 'Match to', 'cM', 'Ancestral Line A10'])


def create_hotlink(row):# Function to create hotlinks
    url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
    person_id = row['ID#']
    hotlink = f'<a href="{url_base}{person_id}&tree=tree1&parentset=0&display=vertical&generations=8" target="_blank">{person_id}</a>'
    return hotlink

combined_df['LUN#'] = combined_df.apply(lambda row: create_hotlink(row), axis=1) # Apply the hotlink function to create the 'LUN#' column
# Change the order of the columns
combined_df = combined_df[['ID#', 'Name', 'Match to', 'cM', 'LUN#', 'Ancestral Line A10']] # 'Most Distant Ancestor',
# Adjust index to start from 1 instead of 0
combined_df.index = combined_df.index + 1
# Print all records from the DataFrame
print(combined_df)
# Export the combined_df DataFrame to an Excel file
combined_df.to_excel('/content/output.xlsx', index=False)
# Out:
# Automatically selecting the first GEDCOM file.
# xlsx file not found. Proceeding without filtering by xlsx.
# 66-Records tagged and filtered by NPFX: 375
# 64-'self.records' contains 375 total records
# Record not found for I13817
# 319-Distant Ancestors Paths for @I13817@: []
# Record not found for I21743
# 319-Distant Ancestors Paths for @I21743@: []
# Record not found for I23678
# 319-Distant Ancestors Paths for @I23678@: []
# Record not found for I26925
# 319-Distant Ancestors Paths for @I26925@: []
# Record not found for I31861
# 319-Distant Ancestors Paths for @I31861@: []
# Record not found for I40190
# 319-Distant Ancestors Paths for @I40190@: []
# Record not found for I42478
# 319-Distant Ancestors Paths for @I42478@: []
# Record not found for I44570
# 319-Distant Ancestors Paths for @I44570@: []
# Record not found for I44883
# 319-Distant Ancestors Paths for @I44883@: []
# Record not found for I44894
# 319-Distant Ancestors Paths for @I44894@: []
# Record not found for I44935
# 319-Distant Ancestors Paths for @I44935@: []
# Record not found for I45040
# 319-Distant Ancestors Paths for @I45040@: []
# Record not found for I45059
# 319-Distant Ancestors Paths for @I45059@: []
# Record not found for I45072
# 319-Distant Ancestors Paths for @I45072@: []
# Record not found for I45084
# 319-Distant Ancestors Paths for @I45084@: []
# Record not found for I45104
# 319-Distant Ancestors Paths for @I45104@: []
# Record not found for I45119
# 319-Distant Ancestors Paths for @I45119@: []
# Record not found for I45133
# 319-Distant Ancestors Paths for @I45133@: []
# Record not found for I45149
# 319-Distant Ancestors Paths for @I45149@: []
# Record not found for I45150
# 319-Distant Ancestors Paths for @I45150@: []
# Record not found for I45201
# 319-Distant Ancestors Paths for @I45201@: []
# Record not found for I45394
# 319-Distant Ancestors Paths for @I45394@: []
# Record not found for I45417
# 319-Distant Ancestors Paths for @I45417@: []
# Record not found for I45439
# 319-Distant Ancestors Paths for @I45439@: []
# Record not found for I45462
# 319-Distant Ancestors Paths for @I45462@: []
# Record not found for I45467
# 319-Distant Ancestors Paths for @I45467@: []
# Record not found for I45499
# 319-Distant Ancestors Paths for @I45499@: []
# Record not found for I45520
# 319-Distant Ancestors Paths for @I45520@: []
# Record not found for I45534
# 319-Distant Ancestors Paths for @I45534@: []
# Record not found for I45552
# 319-Distant Ancestors Paths for @I45552@: []
# Record not found for I45591
# 319-Distant Ancestors Paths for @I45591@: []
# Record not found for I45612
# 319-Distant Ancestors Paths for @I45612@: []
# Record not found for I45632
# 319-Distant Ancestors Paths for @I45632@: []
# Record not found for I45636
# 319-Distant Ancestors Paths for @I45636@: []
# Record not found for I45665
# 319-Distant Ancestors Paths for @I45665@: []
# Record not found for I45670
# 319-Distant Ancestors Paths for @I45670@: []
# Record not found for I45672
# 319-Distant Ancestors Paths for @I45672@: []
# Record not found for I45690
# 319-Distant Ancestors Paths for @I45690@: []
# Record not found for I45700
# 319-Distant Ancestors Paths for @I45700@: []
# Record not found for I45722
# 319-Distant Ancestors Paths for @I45722@: []
# Record not found for I45741
# 319-Distant Ancestors Paths for @I45741@: []
# Record not found for I45809
# 319-Distant Ancestors Paths for @I45809@: []
# Record not found for I45823
# 319-Distant Ancestors Paths for @I45823@: []
# Record not found for I45833
# 319-Distant Ancestors Paths for @I45833@: []
# Record not found for I45864
# 319-Distant Ancestors Paths for @I45864@: []
# Record not found for I45897
# 319-Distant Ancestors Paths for @I45897@: []
# Record not found for I45907
# 319-Distant Ancestors Paths for @I45907@: []
# Record not found for I45932
# 319-Distant Ancestors Paths for @I45932@: []
# Record not found for I45937
# 319-Distant Ancestors Paths for @I45937@: []
# Record not found for I45949
# 319-Distant Ancestors Paths for @I45949@: []
# Record not found for I45980
# 319-Distant Ancestors Paths for @I45980@: []
# Record not found for I46008
# 319-Distant Ancestors Paths for @I46008@: []
# Record not found for I46034
# 319-Distant Ancestors Paths for @I46034@: []
# Record not found for I46054
# 319-Distant Ancestors Paths for @I46054@: []
# Record not found for I46068
# 319-Distant Ancestors Paths for @I46068@: []
# Record not found for I46085
# 319-Distant Ancestors Paths for @I46085@: []
# Record not found for I46102
# 319-Distant Ancestors Paths for @I46102@: []
# Record not found for I46119
# 319-Distant Ancestors Paths for @I46119@: []
# Record not found for I46129
# 319-Distant Ancestors Paths for @I46129@: []
# Record not found for I46144
# 319-Distant Ancestors Paths for @I46144@: []
# Record not found for I46154
# 319-Distant Ancestors Paths for @I46154@: []
# Record not found for I46168
# 319-Distant Ancestors Paths for @I46168@: []
# Record not found for I46175
# 319-Distant Ancestors Paths for @I46175@: []
# Record not found for I46186
# 319-Distant Ancestors Paths for @I46186@: []
# Record not found for I46197
# 319-Distant Ancestors Paths for @I46197@: []
# Record not found for I46207
# 319-Distant Ancestors Paths for @I46207@: []
# Record not found for I46214
# 319-Distant Ancestors Paths for @I46214@: []
# Record not found for I46231
# 319-Distant Ancestors Paths for @I46231@: []
# Record not found for I46243
# 319-Distant Ancestors Paths for @I46243@: []
# Record not found for I46269
# 319-Distant Ancestors Paths for @I46269@: []
# Record not found for I46285
# 319-Distant Ancestors Paths for @I46285@: []
# Record not found for I46303
# 319-Distant Ancestors Paths for @I46303@: []
# Record not found for I46317
# 319-Distant Ancestors Paths for @I46317@: []
# Record not found for I46330
# 319-Distant Ancestors Paths for @I46330@: []
# Record not found for I46346
# 319-Distant Ancestors Paths for @I46346@: []
# Record not found for I46370
# 319-Distant Ancestors Paths for @I46370@: []
# Record not found for I46390
# 319-Distant Ancestors Paths for @I46390@: []
# Record not found for I46402
# 319-Distant Ancestors Paths for @I46402@: []
# Record not found for I46403
# 319-Distant Ancestors Paths for @I46403@: []
# Record not found for I46415
# 319-Distant Ancestors Paths for @I46415@: []
# Record not found for I46423
# 319-Distant Ancestors Paths for @I46423@: []
# Record not found for I46430
# 319-Distant Ancestors Paths for @I46430@: []
# Record not found for I46448
# 319-Distant Ancestors Paths for @I46448@: []
# Record not found for I46457
# 319-Distant Ancestors Paths for @I46457@: []
# Record not found for I46470
# 319-Distant Ancestors Paths for @I46470@: []
# Record not found for I46495
# 319-Distant Ancestors Paths for @I46495@: []
# Record not found for I46502
# 319-Distant Ancestors Paths for @I46502@: []
# Record not found for I46508
# 319-Distant Ancestors Paths for @I46508@: []
# Record not found for I46516
# 319-Distant Ancestors Paths for @I46516@: []
# Record not found for I46528
# 319-Distant Ancestors Paths for @I46528@: []
# Record not found for I46538
# 319-Distant Ancestors Paths for @I46538@: []
# Record not found for I46550
# 319-Distant Ancestors Paths for @I46550@: []
# Record not found for I46562
# 319-Distant Ancestors Paths for @I46562@: []
# Record not found for I46572
# 319-Distant Ancestors Paths for @I46572@: []
# Record not found for I46584
# 319-Distant Ancestors Paths for @I46584@: []
# Record not found for I46593
# 319-Distant Ancestors Paths for @I46593@: []
# Record not found for I46603
# 319-Distant Ancestors Paths for @I46603@: []
# Record not found for I46628
# 319-Distant Ancestors Paths for @I46628@: []
# Record not found for I46641
# 319-Distant Ancestors Paths for @I46641@: []
# Record not found for I46655
# 319-Distant Ancestors Paths for @I46655@: []
# Record not found for I46667
# 319-Distant Ancestors Paths for @I46667@: []
# Record not found for I46681
# 319-Distant Ancestors Paths for @I46681@: []
# Record not found for I46706
# 319-Distant Ancestors Paths for @I46706@: []
# Record not found for I46721
# 319-Distant Ancestors Paths for @I46721@: []
# Record not found for I46750
# 319-Distant Ancestors Paths for @I46750@: []
# Record not found for I46764
# 319-Distant Ancestors Paths for @I46764@: []
# Record not found for I46792
# 319-Distant Ancestors Paths for @I46792@: []
# Record not found for I46811
# 319-Distant Ancestors Paths for @I46811@: []
# Record not found for I46826
# 319-Distant Ancestors Paths for @I46826@: []
# Record not found for I46836
# 319-Distant Ancestors Paths for @I46836@: []
# Record not found for I46847
# 319-Distant Ancestors Paths for @I46847@: []
# Record not found for I46861
# 319-Distant Ancestors Paths for @I46861@: []
# Record not found for I46872
# 319-Distant Ancestors Paths for @I46872@: []
# Record not found for I46881
# 319-Distant Ancestors Paths for @I46881@: []
# Record not found for I46894
# 319-Distant Ancestors Paths for @I46894@: []
# Record not found for I46903
# 319-Distant Ancestors Paths for @I46903@: []
# Record not found for I46917
# 319-Distant Ancestors Paths for @I46917@: []
# Record not found for I46924
# 319-Distant Ancestors Paths for @I46924@: []
# Record not found for I46934
# 319-Distant Ancestors Paths for @I46934@: []
# Record not found for I46945
# 319-Distant Ancestors Paths for @I46945@: []
# Record not found for I46954
# 319-Distant Ancestors Paths for @I46954@: []
# Record not found for I46965
# 319-Distant Ancestors Paths for @I46965@: []
# Record not found for I46985
# 319-Distant Ancestors Paths for @I46985@: []
# Record not found for I46996
# 319-Distant Ancestors Paths for @I46996@: []
# Record not found for I47009
# 319-Distant Ancestors Paths for @I47009@: []
# Record not found for I47026
# 319-Distant Ancestors Paths for @I47026@: []
# Record not found for I47039
# 319-Distant Ancestors Paths for @I47039@: []
# Record not found for I47054
# 319-Distant Ancestors Paths for @I47054@: []
# Record not found for I47076
# 319-Distant Ancestors Paths for @I47076@: []
# Record not found for I47088
# 319-Distant Ancestors Paths for @I47088@: []
# Record not found for I47098
# 319-Distant Ancestors Paths for @I47098@: []
# Record not found for I47110
# 319-Distant Ancestors Paths for @I47110@: []
# Record not found for I47123
# 319-Distant Ancestors Paths for @I47123@: []
# Record not found for I47131
# 319-Distant Ancestors Paths for @I47131@: []
# Record not found for I47142
# 319-Distant Ancestors Paths for @I47142@: []
# Record not found for I47156
# 319-Distant Ancestors Paths for @I47156@: []
# Record not found for I47163
# 319-Distant Ancestors Paths for @I47163@: []
# Record not found for I47172
# 319-Distant Ancestors Paths for @I47172@: []
# Record not found for I47182
# 319-Distant Ancestors Paths for @I47182@: []
# Record not found for I47193
# 319-Distant Ancestors Paths for @I47193@: []
# Record not found for I47205
# 319-Distant Ancestors Paths for @I47205@: []
# Record not found for I47216
# 319-Distant Ancestors Paths for @I47216@: []
# Record not found for I47228
# 319-Distant Ancestors Paths for @I47228@: []
# Record not found for I47241
# 319-Distant Ancestors Paths for @I47241@: []
# Record not found for I47250
# 319-Distant Ancestors Paths for @I47250@: []
# Record not found for I47257
# 319-Distant Ancestors Paths for @I47257@: []
# Record not found for I47270
# 319-Distant Ancestors Paths for @I47270@: []
# Record not found for I47279
# 319-Distant Ancestors Paths for @I47279@: []
# Record not found for I47292
# 319-Distant Ancestors Paths for @I47292@: []
# Record not found for I47306
# 319-Distant Ancestors Paths for @I47306@: []
# Record not found for I47318
# 319-Distant Ancestors Paths for @I47318@: []
# Record not found for I47327
# 319-Distant Ancestors Paths for @I47327@: []
# Record not found for I47338
# 319-Distant Ancestors Paths for @I47338@: []
# Record not found for I47350
# 319-Distant Ancestors Paths for @I47350@: []
# Record not found for I47365
# 319-Distant Ancestors Paths for @I47365@: []
# Record not found for I47379
# 319-Distant Ancestors Paths for @I47379@: []
# Record not found for I47393
# 319-Distant Ancestors Paths for @I47393@: []
# Record not found for I47406
# 319-Distant Ancestors Paths for @I47406@: []
# Record not found for I47416
# 319-Distant Ancestors Paths for @I47416@: []
# Record not found for I47427
# 319-Distant Ancestors Paths for @I47427@: []
# Record not found for I47435
# 319-Distant Ancestors Paths for @I47435@: []
# Record not found for I47447
# 319-Distant Ancestors Paths for @I47447@: []
# Record not found for I47466
# 319-Distant Ancestors Paths for @I47466@: []
# Record not found for I47497
# 319-Distant Ancestors Paths for @I47497@: []
# Record not found for I47510
# 319-Distant Ancestors Paths for @I47510@: []
# Record not found for I47528
# 319-Distant Ancestors Paths for @I47528@: []
# Record not found for I47542
# 319-Distant Ancestors Paths for @I47542@: []
# Record not found for I47691
# 319-Distant Ancestors Paths for @I47691@: []
# Record not found for I47698
# 319-Distant Ancestors Paths for @I47698@: []
# Record not found for I47711
# 319-Distant Ancestors Paths for @I47711@: []
# Record not found for I47733
# 319-Distant Ancestors Paths for @I47733@: []
# Record not found for I47798
# 319-Distant Ancestors Paths for @I47798@: []
# Record not found for I47806
# 319-Distant Ancestors Paths for @I47806@: []
# Record not found for I47881
# 319-Distant Ancestors Paths for @I47881@: []
# Record not found for I47891
# 319-Distant Ancestors Paths for @I47891@: []
# Record not found for I47906
# 319-Distant Ancestors Paths for @I47906@: []
# Record not found for I47918
# 319-Distant Ancestors Paths for @I47918@: []
# Record not found for I47929
# 319-Distant Ancestors Paths for @I47929@: []
# Record not found for I47948
# 319-Distant Ancestors Paths for @I47948@: []
# Record not found for I47958
# 319-Distant Ancestors Paths for @I47958@: []
# Record not found for I47971
# 319-Distant Ancestors Paths for @I47971@: []
# Record not found for I47979
# 319-Distant Ancestors Paths for @I47979@: []
# Record not found for I48125
# 319-Distant Ancestors Paths for @I48125@: []
# Record not found for I48151
# 319-Distant Ancestors Paths for @I48151@: []
# Record not found for I48162
# 319-Distant Ancestors Paths for @I48162@: []
# Record not found for I48171
# 319-Distant Ancestors Paths for @I48171@: []
# Record not found for I48182
# 319-Distant Ancestors Paths for @I48182@: []
# Record not found for I48195
# 319-Distant Ancestors Paths for @I48195@: []
# Record not found for I48210
# 319-Distant Ancestors Paths for @I48210@: []
# Record not found for I48217
# 319-Distant Ancestors Paths for @I48217@: []
# Record not found for I48228
# 319-Distant Ancestors Paths for @I48228@: []
# Record not found for I48240
# 319-Distant Ancestors Paths for @I48240@: []
# Record not found for I48247
# 319-Distant Ancestors Paths for @I48247@: []
# Record not found for I48257
# 319-Distant Ancestors Paths for @I48257@: []
# Record not found for I48274
# 319-Distant Ancestors Paths for @I48274@: []
# Record not found for I48278
# 319-Distant Ancestors Paths for @I48278@: []
# Record not found for I48292
# 319-Distant Ancestors Paths for @I48292@: []
# Record not found for I48304
# 319-Distant Ancestors Paths for @I48304@: []
# Record not found for I48314
# 319-Distant Ancestors Paths for @I48314@: []
# Record not found for I48331
# 319-Distant Ancestors Paths for @I48331@: []
# Record not found for I48337
# 319-Distant Ancestors Paths for @I48337@: []
# Record not found for I48354
# 319-Distant Ancestors Paths for @I48354@: []
# Record not found for I48375
# 319-Distant Ancestors Paths for @I48375@: []
# Record not found for I48384
# 319-Distant Ancestors Paths for @I48384@: []
# Record not found for I48391
# 319-Distant Ancestors Paths for @I48391@: []
# Record not found for I48403
# 319-Distant Ancestors Paths for @I48403@: []
# Record not found for I48415
# 319-Distant Ancestors Paths for @I48415@: []
# Record not found for I48420
# 319-Distant Ancestors Paths for @I48420@: []
# Record not found for I48430
# 319-Distant Ancestors Paths for @I48430@: []
# Record not found for I48438
# 319-Distant Ancestors Paths for @I48438@: []
# Record not found for I48452
# 319-Distant Ancestors Paths for @I48452@: []
# Record not found for I48471
# 319-Distant Ancestors Paths for @I48471@: []
# Record not found for I48481
# 319-Distant Ancestors Paths for @I48481@: []
# Record not found for I48489
# 319-Distant Ancestors Paths for @I48489@: []
# Record not found for I48503
# 319-Distant Ancestors Paths for @I48503@: []
# Record not found for I48516
# 319-Distant Ancestors Paths for @I48516@: []
# Record not found for I48525
# 319-Distant Ancestors Paths for @I48525@: []
# Record not found for I48538
# 319-Distant Ancestors Paths for @I48538@: []
# Record not found for I48552
# 319-Distant Ancestors Paths for @I48552@: []
# Record not found for I48560
# 319-Distant Ancestors Paths for @I48560@: []
# Record not found for I48573
# 319-Distant Ancestors Paths for @I48573@: []
# Record not found for I48581
# 319-Distant Ancestors Paths for @I48581@: []
# Record not found for I48593
# 319-Distant Ancestors Paths for @I48593@: []
# Record not found for I48605
# 319-Distant Ancestors Paths for @I48605@: []
# Record not found for I48614
# 319-Distant Ancestors Paths for @I48614@: []
# Record not found for I48627
# 319-Distant Ancestors Paths for @I48627@: []
# Record not found for I48628
# 319-Distant Ancestors Paths for @I48628@: []
# Record not found for I48642
# 319-Distant Ancestors Paths for @I48642@: []
# Record not found for I48652
# 319-Distant Ancestors Paths for @I48652@: []
# Record not found for I48664
# 319-Distant Ancestors Paths for @I48664@: []
# Record not found for I48670
# 319-Distant Ancestors Paths for @I48670@: []
# Record not found for I48674
# 319-Distant Ancestors Paths for @I48674@: []
# Record not found for I48686
# 319-Distant Ancestors Paths for @I48686@: []
# Record not found for I48697
# 319-Distant Ancestors Paths for @I48697@: []
# Record not found for I48706
# 319-Distant Ancestors Paths for @I48706@: []
# Record not found for I48710
# 319-Distant Ancestors Paths for @I48710@: []
# Record not found for I48721
# 319-Distant Ancestors Paths for @I48721@: []
# Record not found for I48728
# 319-Distant Ancestors Paths for @I48728@: []
# Record not found for I48737
# 319-Distant Ancestors Paths for @I48737@: []
# Record not found for I48744
# 319-Distant Ancestors Paths for @I48744@: []
# Record not found for I48752
# 319-Distant Ancestors Paths for @I48752@: []
# Record not found for I48765
# 319-Distant Ancestors Paths for @I48765@: []
# Record not found for I48767
# 319-Distant Ancestors Paths for @I48767@: []
# Record not found for I48784
# 319-Distant Ancestors Paths for @I48784@: []
# Record not found for I48792
# 319-Distant Ancestors Paths for @I48792@: []
# Record not found for I48799
# 319-Distant Ancestors Paths for @I48799@: []
# Record not found for I48812
# 319-Distant Ancestors Paths for @I48812@: []
# Record not found for I48821
# 319-Distant Ancestors Paths for @I48821@: []
# Record not found for I48830
# 319-Distant Ancestors Paths for @I48830@: []
# Record not found for I48837
# 319-Distant Ancestors Paths for @I48837@: []
# Record not found for I48843
# 319-Distant Ancestors Paths for @I48843@: []
# Record not found for I48857
# 319-Distant Ancestors Paths for @I48857@: []
# Record not found for I48868
# 319-Distant Ancestors Paths for @I48868@: []
# Record not found for I48887
# 319-Distant Ancestors Paths for @I48887@: []
# Record not found for I48898
# 319-Distant Ancestors Paths for @I48898@: []
# Record not found for I48901
# 319-Distant Ancestors Paths for @I48901@: []
# Record not found for I48919
# 319-Distant Ancestors Paths for @I48919@: []
# Record not found for I48935
# 319-Distant Ancestors Paths for @I48935@: []
# Record not found for I48945
# 319-Distant Ancestors Paths for @I48945@: []
# Record not found for I48954
# 319-Distant Ancestors Paths for @I48954@: []
# Record not found for I48965
# 319-Distant Ancestors Paths for @I48965@: []
# Record not found for I48970
# 319-Distant Ancestors Paths for @I48970@: []
# Record not found for I48983
# 319-Distant Ancestors Paths for @I48983@: []
# Record not found for I48998
# 319-Distant Ancestors Paths for @I48998@: []
# Record not found for I49006
# 319-Distant Ancestors Paths for @I49006@: []
# Record not found for I49020
# 319-Distant Ancestors Paths for @I49020@: []
# Record not found for I49027
# 319-Distant Ancestors Paths for @I49027@: []
# Record not found for I49039
# 319-Distant Ancestors Paths for @I49039@: []
# Record not found for I49061
# 319-Distant Ancestors Paths for @I49061@: []
# Record not found for I49076
# 319-Distant Ancestors Paths for @I49076@: []
# Record not found for I49085
# 319-Distant Ancestors Paths for @I49085@: []
# Record not found for I49095
# 319-Distant Ancestors Paths for @I49095@: []
# Record not found for I49101
# 319-Distant Ancestors Paths for @I49101@: []
# Record not found for I49115
# 319-Distant Ancestors Paths for @I49115@: []
# Record not found for I49132
# 319-Distant Ancestors Paths for @I49132@: []
# Record not found for I49140
# 319-Distant Ancestors Paths for @I49140@: []
# Record not found for I49152
# 319-Distant Ancestors Paths for @I49152@: []
# Record not found for I49165
# 319-Distant Ancestors Paths for @I49165@: []
# Record not found for I49178
# 319-Distant Ancestors Paths for @I49178@: []
# Record not found for I49189
# 319-Distant Ancestors Paths for @I49189@: []
# Record not found for I49197
# 319-Distant Ancestors Paths for @I49197@: []
# Record not found for I49206
# 319-Distant Ancestors Paths for @I49206@: []
# Record not found for I49220
# 319-Distant Ancestors Paths for @I49220@: []
# Record not found for I49230
# 319-Distant Ancestors Paths for @I49230@: []
# Record not found for I49240
# 319-Distant Ancestors Paths for @I49240@: []
# Record not found for I49250
# 319-Distant Ancestors Paths for @I49250@: []
# Record not found for I49276
# 319-Distant Ancestors Paths for @I49276@: []
# Record not found for I49289
# 319-Distant Ancestors Paths for @I49289@: []
# Record not found for I49316
# 319-Distant Ancestors Paths for @I49316@: []
# Record not found for I49326
# 319-Distant Ancestors Paths for @I49326@: []
# Record not found for I49337
# 319-Distant Ancestors Paths for @I49337@: []
# Record not found for I49369
# 319-Distant Ancestors Paths for @I49369@: []
# Record not found for I49380
# 319-Distant Ancestors Paths for @I49380@: []
# Record not found for I49396
# 319-Distant Ancestors Paths for @I49396@: []
# Record not found for I49402
# 319-Distant Ancestors Paths for @I49402@: []
# Record not found for I49409
# 319-Distant Ancestors Paths for @I49409@: []
# Record not found for I49427
# 319-Distant Ancestors Paths for @I49427@: []
# Record not found for I49442
# 319-Distant Ancestors Paths for @I49442@: []
# Record not found for I49444
# 319-Distant Ancestors Paths for @I49444@: []
# Record not found for I49459
# 319-Distant Ancestors Paths for @I49459@: []
# Record not found for I49465
# 319-Distant Ancestors Paths for @I49465@: []
# Record not found for I49471
# 319-Distant Ancestors Paths for @I49471@: []
# Record not found for I49476
# 319-Distant Ancestors Paths for @I49476@: []
# Record not found for I49491
# 319-Distant Ancestors Paths for @I49491@: []
# Record not found for I49502
# 319-Distant Ancestors Paths for @I49502@: []
# Record not found for I49511
# 319-Distant Ancestors Paths for @I49511@: []
# Record not found for I49520
# 319-Distant Ancestors Paths for @I49520@: []
# Record not found for I49565
# 319-Distant Ancestors Paths for @I49565@: []
# Record not found for I49570
# 319-Distant Ancestors Paths for @I49570@: []
# Record not found for I49580
# 319-Distant Ancestors Paths for @I49580@: []
# Record not found for I49593
# 319-Distant Ancestors Paths for @I49593@: []
# Record not found for I49607
# 319-Distant Ancestors Paths for @I49607@: []
# Record not found for I49615
# 319-Distant Ancestors Paths for @I49615@: []
# Record not found for I49636
# 319-Distant Ancestors Paths for @I49636@: []
# Record not found for I49652
# 319-Distant Ancestors Paths for @I49652@: []
# Record not found for I49657
# 319-Distant Ancestors Paths for @I49657@: []
# Record not found for I49673
# 319-Distant Ancestors Paths for @I49673@: []
# Record not found for I49682
# 319-Distant Ancestors Paths for @I49682@: []
# Record not found for I49693
# 319-Distant Ancestors Paths for @I49693@: []
# Record not found for I49699
# 319-Distant Ancestors Paths for @I49699@: []
# Record not found for I49708
# 319-Distant Ancestors Paths for @I49708@: []
# Record not found for I49717
# 319-Distant Ancestors Paths for @I49717@: []
# Record not found for I49730
# 319-Distant Ancestors Paths for @I49730@: []
# Record not found for I49755
# 319-Distant Ancestors Paths for @I49755@: []
# Record not found for I49784
# 319-Distant Ancestors Paths for @I49784@: []
# Record not found for I49799
# 319-Distant Ancestors Paths for @I49799@: []
# Record not found for I49813
# 319-Distant Ancestors Paths for @I49813@: []
# Record not found for I49833
# 319-Distant Ancestors Paths for @I49833@: []
# Record not found for I49847
# 319-Distant Ancestors Paths for @I49847@: []
# Record not found for I49862
# 319-Distant Ancestors Paths for @I49862@: []
# Record not found for I49876
# 319-Distant Ancestors Paths for @I49876@: []
# Record not found for I49896
# 319-Distant Ancestors Paths for @I49896@: []
# Record not found for I49905
# 319-Distant Ancestors Paths for @I49905@: []
# Record not found for I49917
# 319-Distant Ancestors Paths for @I49917@: []
# Record not found for I49955
# 319-Distant Ancestors Paths for @I49955@: []
# Record not found for I49982
# 319-Distant Ancestors Paths for @I49982@: []
# Record not found for I49996
# 319-Distant Ancestors Paths for @I49996@: []
# Record not found for I50006
# 319-Distant Ancestors Paths for @I50006@: []
# Record not found for I50013
# 319-Distant Ancestors Paths for @I50013@: []
# Record not found for I50024
# 319-Distant Ancestors Paths for @I50024@: []
# Record not found for I50033
# 319-Distant Ancestors Paths for @I50033@: []
# Record not found for I50046
# 319-Distant Ancestors Paths for @I50046@: []
# Record not found for I50057
# 319-Distant Ancestors Paths for @I50057@: []
# Record not found for I50069
# 319-Distant Ancestors Paths for @I50069@: []
# Record not found for I50098
# 319-Distant Ancestors Paths for @I50098@: []
# Record not found for I50111
# 319-Distant Ancestors Paths for @I50111@: []
# Record not found for I50124
# 319-Distant Ancestors Paths for @I50124@: []
# Record not found for I50144
# 319-Distant Ancestors Paths for @I50144@: []
# Record not found for I50164
# 319-Distant Ancestors Paths for @I50164@: []
# Record not found for I50184
# 319-Distant Ancestors Paths for @I50184@: []
# Record not found for I50191
# 319-Distant Ancestors Paths for @I50191@: []
# Record not found for I50225
# 319-Distant Ancestors Paths for @I50225@: []
# Record not found for I50249
# 319-Distant Ancestors Paths for @I50249@: []
# Record not found for I50264
# 319-Distant Ancestors Paths for @I50264@: []
# Record not found for I50275
# 319-Distant Ancestors Paths for @I50275@: []
# Record not found for I50309
# 319-Distant Ancestors Paths for @I50309@: []
# Record not found for I50326
# 319-Distant Ancestors Paths for @I50326@: []
# Record not found for I50355
# 319-Distant Ancestors Paths for @I50355@: []
# Record not found for I50364
# 319-Distant Ancestors Paths for @I50364@: []
# Record not found for I50369
# 319-Distant Ancestors Paths for @I50369@: []
# Record not found for I50375
# 319-Distant Ancestors Paths for @I50375@: []
# Record not found for I50391
# 319-Distant Ancestors Paths for @I50391@: []
# Record not found for I50405
# 319-Distant Ancestors Paths for @I50405@: []
# Record not found for I50416
# 319-Distant Ancestors Paths for @I50416@: []
# Record not found for I50429
# 319-Distant Ancestors Paths for @I50429@: []
# Record not found for I50440
# 319-Distant Ancestors Paths for @I50440@: []
# Record not found for I50449
# 319-Distant Ancestors Paths for @I50449@: []
# Record not found for I50459
# 319-Distant Ancestors Paths for @I50459@: []
# Record not found for I50472
# 319-Distant Ancestors Paths for @I50472@: []
# Record not found for I50482
# 319-Distant Ancestors Paths for @I50482@: []
# Record not found for I50494
# 319-Distant Ancestors Paths for @I50494@: []
# Record not found for I50511
# 319-Distant Ancestors Paths for @I50511@: []
# Record not found for I50522
# 319-Distant Ancestors Paths for @I50522@: []
# Record not found for I50535
# 319-Distant Ancestors Paths for @I50535@: []
# Record not found for I50551
# 319-Distant Ancestors Paths for @I50551@: []
# 353-Warning: famc_id F5668 not found in records
# 353-Most Distant Ancestors for @I13817@: []
# 353-Warning: famc_id F17473 not found in records
# 353-Most Distant Ancestors for @I21743@: []
# 353-Warning: famc_id F14509 not found in records
# 353-Most Distant Ancestors for @I23678@: []
# 353-Warning: famc_id F13272 not found in records
# 353-Most Distant Ancestors for @I26925@: []
# 353-Warning: famc_id F9370 not found in records
# 353-Most Distant Ancestors for @I31861@: []
# 353-Warning: famc_id F13539 not found in records
# 353-Most Distant Ancestors for @I40190@: []
# 353-Warning: famc_id F14508 not found in records
# 353-Most Distant Ancestors for @I42478@: []
# 353-Warning: famc_id F15318 not found in records
# 353-Most Distant Ancestors for @I44570@: []
# 353-Warning: famc_id F15447 not found in records
# 353-Most Distant Ancestors for @I44883@: []
# 353-Warning: famc_id F15447 not found in records
# 353-Most Distant Ancestors for @I44894@: []
# 353-Warning: famc_id F15467 not found in records
# 353-Most Distant Ancestors for @I44935@: []
# 353-Warning: famc_id F15498 not found in records
# 353-Most Distant Ancestors for @I45040@: []
# 353-Warning: famc_id F15507 not found in records
# 353-Most Distant Ancestors for @I45059@: []
# 353-Warning: famc_id F15509 not found in records
# 353-Most Distant Ancestors for @I45072@: []
# 353-Warning: famc_id F15515 not found in records
# 353-Most Distant Ancestors for @I45084@: []
# 353-Warning: famc_id F15524 not found in records
# 353-Most Distant Ancestors for @I45104@: []
# 353-Warning: famc_id F15532 not found in records
# 353-Most Distant Ancestors for @I45119@: []
# 353-Warning: famc_id F15538 not found in records
# 353-Most Distant Ancestors for @I45133@: []
# 353-Warning: famc_id F15546 not found in records
# 353-Most Distant Ancestors for @I45149@: []
# 353-Warning: famc_id F15547 not found in records
# 353-Most Distant Ancestors for @I45150@: []
# 353-Warning: famc_id F15572 not found in records
# 353-Most Distant Ancestors for @I45201@: []
# 353-Warning: famc_id F15645 not found in records
# 353-Most Distant Ancestors for @I45394@: []
# 353-Warning: famc_id F15659 not found in records
# 353-Most Distant Ancestors for @I45417@: []
# 353-Warning: famc_id F15669 not found in records
# 353-Most Distant Ancestors for @I45439@: []
# 353-Warning: famc_id F15680 not found in records
# 353-Most Distant Ancestors for @I45462@: []
# 353-Warning: famc_id F15682 not found in records
# 353-Most Distant Ancestors for @I45467@: []
# 353-Warning: famc_id F15697 not found in records
# 353-Most Distant Ancestors for @I45499@: []
# 353-Warning: famc_id F15709 not found in records
# 353-Most Distant Ancestors for @I45520@: []
# 353-Warning: famc_id F15716 not found in records
# 353-Most Distant Ancestors for @I45534@: []
# 353-Warning: famc_id F15726 not found in records
# 353-Most Distant Ancestors for @I45552@: []
# 353-Warning: famc_id F15740 not found in records
# 353-Most Distant Ancestors for @I45591@: []
# 353-Warning: famc_id F15747 not found in records
# 353-Most Distant Ancestors for @I45612@: []
# 353-Warning: famc_id F15755 not found in records
# 353-Most Distant Ancestors for @I45632@: []
# 353-Warning: famc_id F15757 not found in records
# 353-Most Distant Ancestors for @I45636@: []
# 353-Warning: famc_id F15770 not found in records
# 353-Most Distant Ancestors for @I45665@: []
# 353-Warning: famc_id F15773 not found in records
# 353-Most Distant Ancestors for @I45670@: []
# 353-Warning: famc_id F15774 not found in records
# 353-Most Distant Ancestors for @I45672@: []
# 353-Warning: famc_id F15780 not found in records
# 353-Most Distant Ancestors for @I45690@: []
# 353-Warning: famc_id F15787 not found in records
# 353-Most Distant Ancestors for @I45700@: []
# 353-Warning: famc_id F15797 not found in records
# 353-Most Distant Ancestors for @I45722@: []
# 353-Warning: famc_id F15806 not found in records
# 353-Most Distant Ancestors for @I45741@: []
# 353-Warning: famc_id F15838 not found in records
# 353-Most Distant Ancestors for @I45809@: []
# 353-Warning: famc_id F15844 not found in records
# 353-Most Distant Ancestors for @I45823@: []
# 353-Warning: famc_id F15848 not found in records
# 353-Most Distant Ancestors for @I45833@: []
# 353-Warning: famc_id F15861 not found in records
# 353-Most Distant Ancestors for @I45864@: []
# 353-Warning: famc_id F15875 not found in records
# 353-Most Distant Ancestors for @I45897@: []
# 353-Warning: famc_id F15880 not found in records
# 353-Most Distant Ancestors for @I45907@: []
# 353-Warning: famc_id F15892 not found in records
# 353-Most Distant Ancestors for @I45932@: []
# 353-Warning: famc_id F15894 not found in records
# 353-Most Distant Ancestors for @I45937@: []
# 353-Warning: famc_id F15900 not found in records
# 353-Most Distant Ancestors for @I45949@: []
# 353-Warning: famc_id F15914 not found in records
# 353-Most Distant Ancestors for @I45980@: []
# 353-Warning: famc_id F15927 not found in records
# 353-Most Distant Ancestors for @I46008@: []
# 353-Warning: famc_id F15937 not found in records
# 353-Most Distant Ancestors for @I46034@: []
# 353-Warning: famc_id F15944 not found in records
# 353-Most Distant Ancestors for @I46054@: []
# 353-Warning: famc_id F15951 not found in records
# 353-Most Distant Ancestors for @I46068@: []
# 353-Warning: famc_id F15958 not found in records
# 353-Most Distant Ancestors for @I46085@: []
# 353-Warning: famc_id F15966 not found in records
# 353-Most Distant Ancestors for @I46102@: []
# 353-Warning: famc_id F15975 not found in records
# 353-Most Distant Ancestors for @I46119@: []
# 353-Warning: famc_id F15979 not found in records
# 353-Most Distant Ancestors for @I46129@: []
# 353-Warning: famc_id F15985 not found in records
# 353-Most Distant Ancestors for @I46144@: []
# 353-Warning: famc_id F15989 not found in records
# 353-Most Distant Ancestors for @I46154@: []
# 353-Warning: famc_id F15996 not found in records
# 353-Most Distant Ancestors for @I46168@: []
# 353-Warning: famc_id F15999 not found in records
# 353-Most Distant Ancestors for @I46175@: []
# 353-Warning: famc_id F16004 not found in records
# 353-Most Distant Ancestors for @I46186@: []
# 353-Warning: famc_id F16010 not found in records
# 353-Most Distant Ancestors for @I46197@: []
# 353-Warning: famc_id F16015 not found in records
# 353-Most Distant Ancestors for @I46207@: []
# 353-Warning: famc_id F16018 not found in records
# 353-Most Distant Ancestors for @I46214@: []
# 353-Warning: famc_id F16022 not found in records
# 353-Most Distant Ancestors for @I46231@: []
# 353-Warning: famc_id F16028 not found in records
# 353-Most Distant Ancestors for @I46243@: []
# 353-Warning: famc_id F16038 not found in records
# 353-Most Distant Ancestors for @I46269@: []
# 353-Warning: famc_id F16046 not found in records
# 353-Most Distant Ancestors for @I46285@: []
# 353-Warning: famc_id F16054 not found in records
# 353-Most Distant Ancestors for @I46303@: []
# 353-Warning: famc_id F16061 not found in records
# 353-Most Distant Ancestors for @I46317@: []
# 353-Warning: famc_id F16067 not found in records
# 353-Most Distant Ancestors for @I46330@: []
# 353-Warning: famc_id F16075 not found in records
# 353-Most Distant Ancestors for @I46346@: []
# 353-Warning: famc_id F16084 not found in records
# 353-Most Distant Ancestors for @I46370@: []
# 353-Warning: famc_id F16095 not found in records
# 353-Most Distant Ancestors for @I46390@: []
# 353-Warning: famc_id F16100 not found in records
# 353-Most Distant Ancestors for @I46402@: []
# 353-Warning: famc_id F16101 not found in records
# 353-Most Distant Ancestors for @I46403@: []
# 353-Warning: famc_id F16106 not found in records
# 353-Most Distant Ancestors for @I46415@: []
# 353-Warning: famc_id F16110 not found in records
# 353-Most Distant Ancestors for @I46423@: []
# 353-Warning: famc_id F16115 not found in records
# 353-Most Distant Ancestors for @I46430@: []
# 353-Warning: famc_id F16125 not found in records
# 353-Most Distant Ancestors for @I46448@: []
# 353-Warning: famc_id F16129 not found in records
# 353-Most Distant Ancestors for @I46457@: []
# 353-Warning: famc_id F16135 not found in records
# 353-Most Distant Ancestors for @I46470@: []
# 353-Warning: famc_id F16146 not found in records
# 353-Most Distant Ancestors for @I46495@: []
# 353-Warning: famc_id F16149 not found in records
# 353-Most Distant Ancestors for @I46502@: []
# 353-Warning: famc_id F16151 not found in records
# 353-Most Distant Ancestors for @I46508@: []
# 353-Warning: famc_id F16155 not found in records
# 353-Most Distant Ancestors for @I46516@: []
# 353-Warning: famc_id F16162 not found in records
# 353-Most Distant Ancestors for @I46528@: []
# 353-Warning: famc_id F16166 not found in records
# 353-Most Distant Ancestors for @I46538@: []
# 353-Warning: famc_id F16172 not found in records
# 353-Most Distant Ancestors for @I46550@: []
# 353-Warning: famc_id F16178 not found in records
# 353-Most Distant Ancestors for @I46562@: []
# 353-Warning: famc_id F16183 not found in records
# 353-Most Distant Ancestors for @I46572@: []
# 353-Warning: famc_id F16189 not found in records
# 353-Most Distant Ancestors for @I46584@: []
# 353-Warning: famc_id F16194 not found in records
# 353-Most Distant Ancestors for @I46593@: []
# 353-Warning: famc_id F16199 not found in records
# 353-Most Distant Ancestors for @I46603@: []
# 353-Warning: famc_id F16211 not found in records
# 353-Most Distant Ancestors for @I46628@: []
# 353-Warning: famc_id F16216 not found in records
# 353-Most Distant Ancestors for @I46641@: []
# 353-Warning: famc_id F16223 not found in records
# 353-Most Distant Ancestors for @I46655@: []
# 353-Warning: famc_id F16228 not found in records
# 353-Most Distant Ancestors for @I46667@: []
# 353-Warning: famc_id F16234 not found in records
# 353-Most Distant Ancestors for @I46681@: []
# 353-Warning: famc_id F16245 not found in records
# 353-Most Distant Ancestors for @I46706@: []
# 353-Warning: famc_id F16252 not found in records
# 353-Most Distant Ancestors for @I46721@: []
# 353-Warning: famc_id F16266 not found in records
# 353-Most Distant Ancestors for @I46750@: []
# 353-Warning: famc_id F16273 not found in records
# 353-Most Distant Ancestors for @I46764@: []
# 353-Warning: famc_id F16287 not found in records
# 353-Most Distant Ancestors for @I46792@: []
# 353-Warning: famc_id F16296 not found in records
# 353-Most Distant Ancestors for @I46811@: []
# 353-Warning: famc_id F16303 not found in records
# 353-Most Distant Ancestors for @I46826@: []
# 353-Warning: famc_id F16308 not found in records
# 353-Most Distant Ancestors for @I46836@: []
# 353-Warning: famc_id F16313 not found in records
# 353-Most Distant Ancestors for @I46847@: []
# 353-Warning: famc_id F16319 not found in records
# 353-Most Distant Ancestors for @I46861@: []
# 353-Warning: famc_id F16324 not found in records
# 353-Most Distant Ancestors for @I46872@: []
# 353-Warning: famc_id F16329 not found in records
# 353-Most Distant Ancestors for @I46881@: []
# 353-Warning: famc_id F16335 not found in records
# 353-Most Distant Ancestors for @I46894@: []
# 353-Warning: famc_id F16340 not found in records
# 353-Most Distant Ancestors for @I46903@: []
# 353-Warning: famc_id F16347 not found in records
# 353-Most Distant Ancestors for @I46917@: []
# 353-Warning: famc_id F16350 not found in records
# 353-Most Distant Ancestors for @I46924@: []
# 353-Warning: famc_id F16355 not found in records
# 353-Most Distant Ancestors for @I46934@: []
# 353-Warning: famc_id F16361 not found in records
# 353-Most Distant Ancestors for @I46945@: []
# 353-Warning: famc_id F16365 not found in records
# 353-Most Distant Ancestors for @I46954@: []
# 353-Warning: famc_id F16371 not found in records
# 353-Most Distant Ancestors for @I46965@: []
# 353-Warning: famc_id F16381 not found in records
# 353-Most Distant Ancestors for @I46985@: []
# 353-Warning: famc_id F16386 not found in records
# 353-Most Distant Ancestors for @I46996@: []
# 353-Warning: famc_id F16392 not found in records
# 353-Most Distant Ancestors for @I47009@: []
# 353-Warning: famc_id F16400 not found in records
# 353-Most Distant Ancestors for @I47026@: []
# 353-Warning: famc_id F16406 not found in records
# 353-Most Distant Ancestors for @I47039@: []
# 353-Warning: famc_id F16413 not found in records
# 353-Most Distant Ancestors for @I47054@: []
# 353-Warning: famc_id F16424 not found in records
# 353-Most Distant Ancestors for @I47076@: []
# 353-Warning: famc_id F16429 not found in records
# 353-Most Distant Ancestors for @I47088@: []
# 353-Warning: famc_id F16434 not found in records
# 353-Most Distant Ancestors for @I47098@: []
# 353-Warning: famc_id F16440 not found in records
# 353-Most Distant Ancestors for @I47110@: []
# 353-Warning: famc_id F16447 not found in records
# 353-Most Distant Ancestors for @I47123@: []
# 353-Warning: famc_id F16451 not found in records
# 353-Most Distant Ancestors for @I47131@: []
# 353-Warning: famc_id F16456 not found in records
# 353-Most Distant Ancestors for @I47142@: []
# 353-Warning: famc_id F16463 not found in records
# 353-Most Distant Ancestors for @I47156@: []
# 353-Warning: famc_id F16466 not found in records
# 353-Most Distant Ancestors for @I47163@: []
# 353-Warning: famc_id F16470 not found in records
# 353-Most Distant Ancestors for @I47172@: []
# 353-Warning: famc_id F16475 not found in records
# 353-Most Distant Ancestors for @I47182@: []
# 353-Warning: famc_id F16480 not found in records
# 353-Most Distant Ancestors for @I47193@: []
# 353-Warning: famc_id F16486 not found in records
# 353-Most Distant Ancestors for @I47205@: []
# 353-Warning: famc_id F16491 not found in records
# 353-Most Distant Ancestors for @I47216@: []
# 353-Warning: famc_id F16497 not found in records
# 353-Most Distant Ancestors for @I47228@: []
# 353-Warning: famc_id F16503 not found in records
# 353-Most Distant Ancestors for @I47241@: []
# 353-Warning: famc_id F16507 not found in records
# 353-Most Distant Ancestors for @I47250@: []
# 353-Warning: famc_id F16510 not found in records
# 353-Most Distant Ancestors for @I47257@: []
# 353-Warning: famc_id F16516 not found in records
# 353-Most Distant Ancestors for @I47270@: []
# 353-Warning: famc_id F16520 not found in records
# 353-Most Distant Ancestors for @I47279@: []
# 353-Warning: famc_id F16526 not found in records
# 353-Most Distant Ancestors for @I47292@: []
# 353-Warning: famc_id F16533 not found in records
# 353-Most Distant Ancestors for @I47306@: []
# 353-Warning: famc_id F16539 not found in records
# 353-Most Distant Ancestors for @I47318@: []
# 353-Warning: famc_id F16544 not found in records
# 353-Most Distant Ancestors for @I47327@: []
# 353-Warning: famc_id F16549 not found in records
# 353-Most Distant Ancestors for @I47338@: []
# 353-Warning: famc_id F16557 not found in records
# 353-Most Distant Ancestors for @I47350@: []
# 353-Warning: famc_id F16563 not found in records
# 353-Most Distant Ancestors for @I47365@: []
# 353-Warning: famc_id F16570 not found in records
# 353-Most Distant Ancestors for @I47379@: []
# 353-Warning: famc_id F16577 not found in records
# 353-Most Distant Ancestors for @I47393@: []
# 353-Warning: famc_id F16583 not found in records
# 353-Most Distant Ancestors for @I47406@: []
# 353-Warning: famc_id F16587 not found in records
# 353-Most Distant Ancestors for @I47416@: []
# 353-Warning: famc_id F16592 not found in records
# 353-Most Distant Ancestors for @I47427@: []
# 353-Warning: famc_id F16596 not found in records
# 353-Most Distant Ancestors for @I47435@: []
# 353-Warning: famc_id F16601 not found in records
# 353-Most Distant Ancestors for @I47447@: []
# 353-Warning: famc_id F16610 not found in records
# 353-Most Distant Ancestors for @I47466@: []
# 353-Warning: famc_id F16624 not found in records
# 353-Most Distant Ancestors for @I47497@: []
# 353-Warning: famc_id F16630 not found in records
# 353-Most Distant Ancestors for @I47510@: []
# 353-Warning: famc_id F16639 not found in records
# 353-Most Distant Ancestors for @I47528@: []
# 353-Warning: famc_id F16646 not found in records
# 353-Most Distant Ancestors for @I47542@: []
# 353-Warning: famc_id F16712 not found in records
# 353-Most Distant Ancestors for @I47691@: []
# 353-Warning: famc_id F16716 not found in records
# 353-Most Distant Ancestors for @I47698@: []
# 353-Warning: famc_id F16723 not found in records
# 353-Most Distant Ancestors for @I47711@: []
# 353-Warning: famc_id F16733 not found in records
# 353-Most Distant Ancestors for @I47733@: []
# 353-Warning: famc_id F16761 not found in records
# 353-Most Distant Ancestors for @I47798@: []
# 353-Warning: famc_id F16765 not found in records
# 353-Most Distant Ancestors for @I47806@: []
# 353-Warning: famc_id F16792 not found in records
# 353-Most Distant Ancestors for @I47881@: []
# 353-Warning: famc_id F16797 not found in records
# 353-Most Distant Ancestors for @I47891@: []
# 353-Warning: famc_id F16804 not found in records
# 353-Most Distant Ancestors for @I47906@: []
# 353-Warning: famc_id F16809 not found in records
# 353-Most Distant Ancestors for @I47918@: []
# 353-Warning: famc_id F16814 not found in records
# 353-Most Distant Ancestors for @I47929@: []
# 353-Warning: famc_id F16822 not found in records
# 353-Most Distant Ancestors for @I47948@: []
# 353-Warning: famc_id F16827 not found in records
# 353-Most Distant Ancestors for @I47958@: []
# 353-Warning: famc_id F16834 not found in records
# 353-Most Distant Ancestors for @I47971@: []
# 353-Warning: famc_id F16838 not found in records
# 353-Most Distant Ancestors for @I47979@: []
# 353-Warning: famc_id F16915 not found in records
# 353-Most Distant Ancestors for @I48125@: []
# 353-Warning: famc_id F16927 not found in records
# 353-Most Distant Ancestors for @I48151@: []
# 353-Warning: famc_id F16931 not found in records
# 353-Most Distant Ancestors for @I48162@: []
# 353-Warning: famc_id F16935 not found in records
# 353-Most Distant Ancestors for @I48171@: []
# 353-Warning: famc_id F16940 not found in records
# 353-Most Distant Ancestors for @I48182@: []
# 353-Warning: famc_id F16947 not found in records
# 353-Most Distant Ancestors for @I48195@: []
# 353-Warning: famc_id F16955 not found in records
# 353-Most Distant Ancestors for @I48210@: []
# 353-Warning: famc_id F16958 not found in records
# 353-Most Distant Ancestors for @I48217@: []
# 353-Warning: famc_id F16964 not found in records
# 353-Most Distant Ancestors for @I48228@: []
# 353-Warning: famc_id F16970 not found in records
# 353-Most Distant Ancestors for @I48240@: []
# 353-Warning: famc_id F16973 not found in records
# 353-Most Distant Ancestors for @I48247@: []
# 353-Warning: famc_id F16979 not found in records
# 353-Most Distant Ancestors for @I48257@: []
# 353-Warning: famc_id F16988 not found in records
# 353-Most Distant Ancestors for @I48274@: []
# 353-Warning: famc_id F16990 not found in records
# 353-Most Distant Ancestors for @I48278@: []
# 353-Warning: famc_id F16997 not found in records
# 353-Most Distant Ancestors for @I48292@: []
# 353-Warning: famc_id F17002 not found in records
# 353-Most Distant Ancestors for @I48304@: []
# 353-Warning: famc_id F17007 not found in records
# 353-Most Distant Ancestors for @I48314@: []
# 353-Warning: famc_id F17015 not found in records
# 353-Most Distant Ancestors for @I48331@: []
# 353-Warning: famc_id F17018 not found in records
# 353-Most Distant Ancestors for @I48337@: []
# 353-Warning: famc_id F17027 not found in records
# 353-Most Distant Ancestors for @I48354@: []
# 353-Warning: famc_id F17037 not found in records
# 353-Most Distant Ancestors for @I48375@: []
# 353-Warning: famc_id F17042 not found in records
# 353-Most Distant Ancestors for @I48384@: []
# 353-Warning: famc_id F17045 not found in records
# 353-Most Distant Ancestors for @I48391@: []
# 353-Warning: famc_id F17050 not found in records
# 353-Most Distant Ancestors for @I48403@: []
# 353-Warning: famc_id F17056 not found in records
# 353-Most Distant Ancestors for @I48415@: []
# 353-Warning: famc_id F17059 not found in records
# 353-Most Distant Ancestors for @I48420@: []
# 353-Warning: famc_id F17064 not found in records
# 353-Most Distant Ancestors for @I48430@: []
# 353-Warning: famc_id F17068 not found in records
# 353-Most Distant Ancestors for @I48438@: []
# 353-Warning: famc_id F17075 not found in records
# 353-Most Distant Ancestors for @I48452@: []
# 353-Warning: famc_id F17084 not found in records
# 353-Most Distant Ancestors for @I48471@: []
# 353-Warning: famc_id F17089 not found in records
# 353-Most Distant Ancestors for @I48481@: []
# 353-Warning: famc_id F17091 not found in records
# 353-Most Distant Ancestors for @I48489@: []
# 353-Warning: famc_id F17098 not found in records
# 353-Most Distant Ancestors for @I48503@: []
# 353-Warning: famc_id F17104 not found in records
# 353-Most Distant Ancestors for @I48516@: []
# 353-Warning: famc_id F17108 not found in records
# 353-Most Distant Ancestors for @I48525@: []
# 353-Warning: famc_id F17114 not found in records
# 353-Most Distant Ancestors for @I48538@: []
# 353-Warning: famc_id F17122 not found in records
# 353-Most Distant Ancestors for @I48552@: []
# 353-Warning: famc_id F17126 not found in records
# ...
# 353-Most Distant Ancestors for @I48581@: []
# 353-Warning: famc_id F17142 not found in records
# 353-Most Distant Ancestors for @I48593@: []
# 353-Warning: famc_id F17148 not found in records
# 353-Most Distant Ancestors for @I48605@: []
# 353-Warning: famc_id F17152 not found in records
# 353-Most Distant Ancestors for @I48614@: []
# 353-Warning: famc_id F17157 not found in records
# 353-Most Distant Ancestors for @I48627@: []
# 353-Warning: famc_id F12064 not found in records
# 353-Most Distant Ancestors for @I48628@: []
# 353-Warning: famc_id F17163 not found in records
# 353-Most Distant Ancestors for @I48642@: []
# 353-Warning: famc_id F17169 not found in records
# 353-Most Distant Ancestors for @I48652@: []
# 353-Warning: famc_id F17174 not found in records
# 353-Most Distant Ancestors for @I48664@: []
# 353-Warning: famc_id F17177 not found in records
# 353-Most Distant Ancestors for @I48670@: []
# 353-Warning: famc_id F17179 not found in records
# 353-Most Distant Ancestors for @I48674@: []
# 353-Warning: famc_id F17185 not found in records
# 353-Most Distant Ancestors for @I48686@: []
# 353-Warning: famc_id F17190 not found in records
# 353-Most Distant Ancestors for @I48697@: []
# 353-Warning: famc_id F17194 not found in records
# 353-Most Distant Ancestors for @I48706@: []
# 353-Warning: famc_id F17196 not found in records
# 353-Most Distant Ancestors for @I48710@: []
# 353-Warning: famc_id F17201 not found in records
# 353-Most Distant Ancestors for @I48721@: []
# 353-Warning: famc_id F17203 not found in records
# 353-Most Distant Ancestors for @I48728@: []
# 353-Warning: famc_id F17208 not found in records
# 353-Most Distant Ancestors for @I48737@: []
# 353-Warning: famc_id F17211 not found in records
# 353-Most Distant Ancestors for @I48744@: []
# 353-Warning: famc_id F17215 not found in records
# 353-Most Distant Ancestors for @I48752@: []
# 353-Warning: famc_id F17221 not found in records
# 353-Most Distant Ancestors for @I48765@: []
# 353-Warning: famc_id F9780 not found in records
# 353-Most Distant Ancestors for @I48767@: []
# 353-Warning: famc_id F17229 not found in records
# 353-Most Distant Ancestors for @I48784@: []
# 353-Warning: famc_id F17233 not found in records
# 353-Most Distant Ancestors for @I48792@: []
# 353-Warning: famc_id F17236 not found in records
# 353-Most Distant Ancestors for @I48799@: []
# 353-Warning: famc_id F17242 not found in records
# 353-Most Distant Ancestors for @I48812@: []
# 353-Warning: famc_id F17246 not found in records
# 353-Most Distant Ancestors for @I48821@: []
# 353-Warning: famc_id F17250 not found in records
# 353-Most Distant Ancestors for @I48830@: []
# 353-Warning: famc_id F17254 not found in records
# 353-Most Distant Ancestors for @I48837@: []
# 353-Warning: famc_id F17257 not found in records
# 353-Most Distant Ancestors for @I48843@: []
# 353-Warning: famc_id F17264 not found in records
# 353-Most Distant Ancestors for @I48857@: []
# 353-Warning: famc_id F17269 not found in records
# 353-Most Distant Ancestors for @I48868@: []
# 353-Warning: famc_id F17275 not found in records
# 353-Most Distant Ancestors for @I48887@: []
# 353-Warning: famc_id F17280 not found in records
# 353-Most Distant Ancestors for @I48898@: []
# 353-Warning: famc_id F17281 not found in records
# 353-Most Distant Ancestors for @I48901@: []
# 353-Warning: famc_id F17291 not found in records
# 353-Most Distant Ancestors for @I48919@: []
# 353-Warning: famc_id F17299 not found in records
# 353-Most Distant Ancestors for @I48935@: []
# 353-Warning: famc_id F17304 not found in records
# 353-Most Distant Ancestors for @I48945@: []
# 353-Warning: famc_id F17308 not found in records
# 353-Most Distant Ancestors for @I48954@: []
# 353-Warning: famc_id F17313 not found in records
# 353-Most Distant Ancestors for @I48965@: []
# 353-Warning: famc_id F17315 not found in records
# 353-Most Distant Ancestors for @I48970@: []
# 353-Warning: famc_id F17318 not found in records
# 353-Most Distant Ancestors for @I48983@: []
# 353-Warning: famc_id F17325 not found in records
# 353-Most Distant Ancestors for @I48998@: []
# 353-Warning: famc_id F17328 not found in records
# 353-Most Distant Ancestors for @I49006@: []
# 353-Warning: famc_id F17334 not found in records
# 353-Most Distant Ancestors for @I49020@: []
# 353-Warning: famc_id F17337 not found in records
# 353-Most Distant Ancestors for @I49027@: []
# 353-Warning: famc_id F17343 not found in records
# 353-Most Distant Ancestors for @I49039@: []
# 353-Warning: famc_id F17353 not found in records
# 353-Most Distant Ancestors for @I49061@: []
# 353-Warning: famc_id F17357 not found in records
# 353-Most Distant Ancestors for @I49076@: []
# 353-Warning: famc_id F17361 not found in records
# 353-Most Distant Ancestors for @I49085@: []
# 353-Warning: famc_id F17366 not found in records
# 353-Most Distant Ancestors for @I49095@: []
# 353-Warning: famc_id F17369 not found in records
# 353-Most Distant Ancestors for @I49101@: []
# 353-Warning: famc_id F17374 not found in records
# 353-Most Distant Ancestors for @I49115@: []
# 353-Warning: famc_id F17382 not found in records
# 353-Most Distant Ancestors for @I49132@: []
# 353-Warning: famc_id F17386 not found in records
# 353-Most Distant Ancestors for @I49140@: []
# 353-Warning: famc_id F17391 not found in records
# 353-Most Distant Ancestors for @I49152@: []
# 353-Warning: famc_id F17396 not found in records
# 353-Most Distant Ancestors for @I49165@: []
# 353-Warning: famc_id F17402 not found in records
# 353-Most Distant Ancestors for @I49178@: []
# 353-Warning: famc_id F17407 not found in records
# 353-Most Distant Ancestors for @I49189@: []
# 353-Warning: famc_id F17411 not found in records
# 353-Most Distant Ancestors for @I49197@: []
# 353-Warning: famc_id F17415 not found in records
# 353-Most Distant Ancestors for @I49206@: []
# 353-Warning: famc_id F17421 not found in records
# 353-Most Distant Ancestors for @I49220@: []
# 353-Warning: famc_id F17426 not found in records
# 353-Most Distant Ancestors for @I49230@: []
# 353-Warning: famc_id F17430 not found in records
# 353-Most Distant Ancestors for @I49240@: []
# 353-Warning: famc_id F17434 not found in records
# 353-Most Distant Ancestors for @I49250@: []
# 353-Warning: famc_id F17440 not found in records
# 353-Most Distant Ancestors for @I49276@: []
# 353-Warning: famc_id F17445 not found in records
# 353-Most Distant Ancestors for @I49289@: []
# 353-Warning: famc_id F17456 not found in records
# 353-Most Distant Ancestors for @I49316@: []
# 353-Warning: famc_id F17462 not found in records
# 353-Most Distant Ancestors for @I49326@: []
# 353-Warning: famc_id F17467 not found in records
# 353-Most Distant Ancestors for @I49337@: []
# 353-Warning: famc_id F17483 not found in records
# 353-Most Distant Ancestors for @I49369@: []
# 353-Warning: famc_id F17488 not found in records
# 353-Most Distant Ancestors for @I49380@: []
# 353-Warning: famc_id F17495 not found in records
# 353-Most Distant Ancestors for @I49396@: []
# 353-Warning: famc_id F17498 not found in records
# 353-Most Distant Ancestors for @I49402@: []
# 353-Warning: famc_id F17501 not found in records
# 353-Most Distant Ancestors for @I49409@: []
# 353-Warning: famc_id F17509 not found in records
# 353-Most Distant Ancestors for @I49427@: []
# 353-Warning: famc_id F17515 not found in records
# 353-Most Distant Ancestors for @I49442@: []
# 353-Warning: famc_id F17516 not found in records
# 353-Most Distant Ancestors for @I49444@: []
# 353-Warning: famc_id F17523 not found in records
# 353-Most Distant Ancestors for @I49459@: []
# 353-Warning: famc_id F17526 not found in records
# 353-Most Distant Ancestors for @I49465@: []
# 353-Warning: famc_id F17529 not found in records
# 353-Most Distant Ancestors for @I49471@: []
# 353-Warning: famc_id F17531 not found in records
# 353-Most Distant Ancestors for @I49476@: []
# 353-Warning: famc_id F17537 not found in records
# 353-Most Distant Ancestors for @I49491@: []
# 353-Warning: famc_id F17542 not found in records
# 353-Most Distant Ancestors for @I49502@: []
# 353-Warning: famc_id F17546 not found in records
# 353-Most Distant Ancestors for @I49511@: []
# 353-Warning: famc_id F17550 not found in records
# 353-Most Distant Ancestors for @I49520@: []
# 353-Warning: famc_id F17567 not found in records
# 353-Most Distant Ancestors for @I49565@: []
# 353-Warning: famc_id F17569 not found in records
# 353-Most Distant Ancestors for @I49570@: []
# 353-Warning: famc_id F17574 not found in records
# 353-Most Distant Ancestors for @I49580@: []
# 353-Warning: famc_id F17580 not found in records
# 353-Most Distant Ancestors for @I49593@: []
# 353-Warning: famc_id F17587 not found in records
# 353-Most Distant Ancestors for @I49607@: []
# 353-Warning: famc_id F17590 not found in records
# 353-Most Distant Ancestors for @I49615@: []
# 353-Warning: famc_id F17601 not found in records
# 353-Most Distant Ancestors for @I49636@: []
# 353-Warning: famc_id F17609 not found in records
# 353-Most Distant Ancestors for @I49652@: []
# 353-Warning: famc_id F17612 not found in records
# 353-Most Distant Ancestors for @I49657@: []
# 353-Warning: famc_id F17620 not found in records
# 353-Most Distant Ancestors for @I49673@: []
# 353-Warning: famc_id F17624 not found in records
# 353-Most Distant Ancestors for @I49682@: []
# 353-Warning: famc_id F17629 not found in records
# 353-Most Distant Ancestors for @I49693@: []
# 353-Warning: famc_id F17632 not found in records
# 353-Most Distant Ancestors for @I49699@: []
# 353-Warning: famc_id F17636 not found in records
# 353-Most Distant Ancestors for @I49708@: []
# 353-Warning: famc_id F17640 not found in records
# 353-Most Distant Ancestors for @I49717@: []
# 353-Warning: famc_id F17646 not found in records
# 353-Most Distant Ancestors for @I49730@: []
# 353-Warning: famc_id F17656 not found in records
# 353-Most Distant Ancestors for @I49755@: []
# 353-Warning: famc_id F17669 not found in records
# 353-Most Distant Ancestors for @I49784@: []
# 353-Warning: famc_id F17676 not found in records
# 353-Most Distant Ancestors for @I49799@: []
# 353-Warning: famc_id F17683 not found in records
# 353-Most Distant Ancestors for @I49813@: []
# 353-Warning: famc_id F17692 not found in records
# 353-Most Distant Ancestors for @I49833@: []
# 353-Warning: famc_id F17698 not found in records
# 353-Most Distant Ancestors for @I49847@: []
# 353-Warning: famc_id F17705 not found in records
# 353-Most Distant Ancestors for @I49862@: []
# 353-Warning: famc_id F17711 not found in records
# 353-Most Distant Ancestors for @I49876@: []
# 353-Warning: famc_id F17720 not found in records
# 353-Most Distant Ancestors for @I49896@: []
# 353-Warning: famc_id F17724 not found in records
# 353-Most Distant Ancestors for @I49905@: []
# 353-Warning: famc_id F17730 not found in records
# 353-Most Distant Ancestors for @I49917@: []
# 353-Warning: famc_id F17745 not found in records
# 353-Most Distant Ancestors for @I49955@: []
# 353-Warning: famc_id F17756 not found in records
# 353-Most Distant Ancestors for @I49982@: []
# 353-Warning: famc_id F17764 not found in records
# 353-Most Distant Ancestors for @I49996@: []
# 353-Warning: famc_id F17769 not found in records
# 353-Most Distant Ancestors for @I50006@: []
# 353-Warning: famc_id F17772 not found in records
# 353-Most Distant Ancestors for @I50013@: []
# 353-Warning: famc_id F17777 not found in records
# 353-Most Distant Ancestors for @I50024@: []
# 353-Warning: famc_id F17781 not found in records
# 353-Most Distant Ancestors for @I50033@: []
# 353-Warning: famc_id F17787 not found in records
# 353-Most Distant Ancestors for @I50046@: []
# 353-Warning: famc_id F17792 not found in records
# 353-Most Distant Ancestors for @I50057@: []
# 353-Warning: famc_id F17797 not found in records
# 353-Most Distant Ancestors for @I50069@: []
# 353-Warning: famc_id F17809 not found in records
# 353-Most Distant Ancestors for @I50098@: []
# 353-Warning: famc_id F17815 not found in records
# 353-Most Distant Ancestors for @I50111@: []
# 353-Warning: famc_id F17821 not found in records
# 353-Most Distant Ancestors for @I50124@: []
# 353-Warning: famc_id F17830 not found in records
# 353-Most Distant Ancestors for @I50144@: []
# 353-Warning: famc_id F17839 not found in records
# 353-Most Distant Ancestors for @I50164@: []
# 353-Warning: famc_id F17848 not found in records
# 353-Most Distant Ancestors for @I50184@: []
# 353-Warning: famc_id F17852 not found in records
# 353-Most Distant Ancestors for @I50191@: []
# 353-Warning: famc_id F17868 not found in records
# 353-Most Distant Ancestors for @I50225@: []
# 353-Warning: famc_id F17877 not found in records
# 353-Most Distant Ancestors for @I50249@: []
# 353-Warning: famc_id F17884 not found in records
# 353-Most Distant Ancestors for @I50264@: []
# 353-Warning: famc_id F17889 not found in records
# 353-Most Distant Ancestors for @I50275@: []
# 353-Warning: famc_id F17905 not found in records
# 353-Most Distant Ancestors for @I50309@: []
# 353-Warning: famc_id F17914 not found in records
# 353-Most Distant Ancestors for @I50326@: []
# 353-Warning: famc_id F17923 not found in records
# 353-Most Distant Ancestors for @I50355@: []
# 353-Warning: famc_id F17928 not found in records
# 353-Most Distant Ancestors for @I50364@: []
# 353-Warning: famc_id F17930 not found in records
# 353-Most Distant Ancestors for @I50369@: []
# 353-Warning: famc_id F17933 not found in records
# 353-Most Distant Ancestors for @I50375@: []
# 353-Warning: famc_id F17941 not found in records
# 353-Most Distant Ancestors for @I50391@: []
# 353-Warning: famc_id F17948 not found in records
# 353-Most Distant Ancestors for @I50405@: []
# 353-Warning: famc_id F17953 not found in records
# 353-Most Distant Ancestors for @I50416@: []
# 353-Warning: famc_id F17958 not found in records
# 353-Most Distant Ancestors for @I50429@: []
# 353-Warning: famc_id F17962 not found in records
# 353-Most Distant Ancestors for @I50440@: []
# 353-Warning: famc_id F17966 not found in records
# 353-Most Distant Ancestors for @I50449@: []
# 353-Warning: famc_id F17970 not found in records
# 353-Most Distant Ancestors for @I50459@: []
# 353-Warning: famc_id F17976 not found in records
# 353-Most Distant Ancestors for @I50472@: []
# 353-Warning: famc_id F17981 not found in records
# 353-Most Distant Ancestors for @I50482@: []
# 353-Warning: famc_id F17989 not found in records
# 353-Most Distant Ancestors for @I50494@: []
# 353-Warning: famc_id F17996 not found in records
# 353-Most Distant Ancestors for @I50511@: []
# 353-Warning: famc_id F18000 not found in records
# 353-Most Distant Ancestors for @I50522@: []
# 353-Warning: famc_id F18007 not found in records
# 353-Most Distant Ancestors for @I50535@: []
# 353-Warning: famc_id F18014 not found in records
# 353-Most Distant Ancestors for @I50551@: []
#           ID#             Name      Match to             cM  \
# 1    @I13817@     YatesamHenry  Default Sort  Default Value
# 2    @I21743@           HuntyA  Default Sort  Default Value
# 3    @I23678@    JohnsondBrett  Default Sort  Default Value
# 4    @I26925@             None  Default Sort  Default Value
# 5    @I31861@        ChurchSue  Default Sort  Default Value
# ..        ...              ...           ...            ...
# 371  @I50494@         Beaversl  Default Sort  Default Value
# 372  @I50511@         Stiverse  Default Sort  Default Value
# 373  @I50522@   FehrenbachaDea  Default Sort  Default Value
# 374  @I50535@   PetersonhJewel  Default Sort  Default Value
# 375  @I50551@  NicholssaColeen  Default Sort  Default Value
#
#                                                   LUN# Ancestral Line A10
# 1    <a href="https://yates.one-name.net/tng/vertic...
# 2    <a href="https://yates.one-name.net/tng/vertic...
# 3    <a href="https://yates.one-name.net/tng/vertic...
# 4    <a href="https://yates.one-name.net/tng/vertic...
# 5    <a href="https://yates.one-name.net/tng/vertic...
# ..                                                 ...                ...
# 371  <a href="https://yates.one-name.net/tng/vertic...
# 372  <a href="https://yates.one-name.net/tng/vertic...
# 373  <a href="https://yates.one-name.net/tng/vertic...
# 374  <a href="https://yates.one-name.net/tng/vertic...
# 375  <a href="https://yates.one-name.net/tng/vertic...
#
# [375 rows x 6 columns]

# %%
# !pip install pandas
# !pip install python-gedcom
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: python-gedcom in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
