# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/a_last_chance_2023_0922_0915_error_free.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd
import os

find_parents_new_counter = 0
last_pair_counter = 0
visited_pairs = set()

last_prime_surname = None

def select_gedcom_file():
    """
    Select the GEDCOM file from the user.

    Returns:
        The path to the selected GEDCOM file.
    """

    gedcom_file_path = filedialog.askopenfilename(
        filetypes=[('GEDCOM Files', '*.ged')],
        initialdir=os.getcwd()
    )
    return gedcom_file_path

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_lines = []
        self.gedcom_datasets = []
        self.filter_pool = []

        self._parse_gedcom()
        self.parse_individuals()
        self.filter_individuals()

    def _parse_gedcom(self):
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            self.gedcom_lines = f.readlines()

    def parse_individuals(self):
        current_dataset = None
        npfx_count = 0
        total_count = 0

        for line in self.gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                total_count += 1
                current_dataset = GedcomDataset(tag.strip('@'))
                self.gedcom_datasets.append(current_dataset)
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_key = tag
                    current_dataset.add_extractable_detail(current_key, value)
                elif level == 2 and tag == 'NPFX':
                    npfx_count += 1
                    if value is None:
                        print(f"Warning: Found None value for NPFX in dataset {current_dataset}.")
                    else:
                        current_dataset.add_extractable_detail(tag, value)
        print(f'Total records found: {total_count}')

    def filter_individuals(self):
        allowed_individual_ids = []

        # Check if Excel file exists for filtering
        if os.path.exists('/content/shortged.xlsx'):
            df = pd.read_excel('/content/shortged.xlsx')
            allowed_individual_ids = df.iloc[:, 0].tolist()

        # Combine the two conditions: Must be in Excel and must have non-empty NPFX
        self.gedcom_datasets = [dataset for dataset in self.gedcom_datasets if (dataset.individual_id in allowed_individual_ids or not allowed_individual_ids) and dataset.get_extractable_NPFX()]

        # Populate the individuals list as before
        self.individuals = []
        for dataset in self.gedcom_datasets:
            individual_id = dataset.individual_id
            name = dataset.get_gen_person()
            self.individuals.append((name, individual_id))

        # Print the counts and datasets for debugging and verification
        print(f'Records tagged as filter_pool records: {len(self.gedcom_datasets)}')
        # Print the counts and datasets for debugging and verification
        print(f'Records tagged as filter_pool records: {len(self.gedcom_datasets)}')
        for dataset in self.gedcom_datasets:
            print(f'Individual ID: {dataset.individual_id}, Anchor Gen1: {dataset.get_anchor_gen1()}')



    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

      # Ensure the class IndividualRecord is well defined as you've shown
class IndividualRecord:
    def __init__(self, id, cm, sort):
        self.id = id
        self.cm = cm
        self.sort = sort

class GedcomDataset:
    def __init__(self, individual_id, individual=None):
        self.individual_id = individual_id
        self.individual = individual
        self.extractable_detail = {}
        self.anchor_gen1 = None
        self.ancestral_line = []

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_anchor_gen1(self):
        return self.anchor_gen1

    def get_gen_person(self):
        return self.individual_id

    def get_extractable_cm(self):
        return self.extractable_detail.get('cm', '')

    def get_extractable_sort(self):
        return self.extractable_detail.get('sort', '')

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_gen_person(self):
        name = self.extractable_detail.get('NAME', '')
        first_name, last_name = name.split('/', 1)
        first_name = first_name.split(' ')[0]
        last_name = last_name.rstrip('/')
        self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")  # Store the value
        self.individual_id = self.individual_id.strip('@')
        return self.anchor_gen1  # Return the updated value

    def get_anchor_gen1(self):
        return self.anchor_gen1

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_full_name(self):
        name = self.extractable_detail.get('NAME', '')
        if '/' in name:
            first_name, last_name = name.split('/', 1)
            first_name = first_name.strip()
            last_name = last_name.rstrip('/')
            full_name = last_name.replace(" ", "") + first_name.replace(" ", "")
        else:
            full_name = name.replace(" ", "")
        return full_name

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

    def find_ancestors(self, individual_id, records):
        if individual_id not in records:
            return
        record = records[individual_id]
        famc_start = record.find('1 FAMC @') + 8
        famc_end = record.find('@', famc_start)
        famc_id = record[famc_start:famc_end]
        if famc_id not in records:
            return

        fam_record = records[famc_id]
        wife_end = fam_record.find('@', wife_start)
        mother_id = fam_record[wife_start:wife_end]

        husb_start = fam_record.find('1 HUSB @') + 8
        husb_end = fam_record.find('@', husb_start)
        father_id = fam_record[husb_start:husb_end]

        if mother_id and mother_id in records:
            mother_record = records[mother_id]
            mother_name = extract_name(mother_record)
            self.ancestral_line.append(mother_name)
            self.find_ancestors(mother_id, records)

        if father_id and father_id in records:
            father_record = records[father_id]
            father_name = extract_name(father_record)
            self.ancestral_line.append(father_name)
            self.find_ancestors(father_id, records)

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found in the Colab contents.")
        return None

    print("List of GEDCOM files:")
    for i, file_name in enumerate(gedcom_files, 1):
        print(f"{i}. {file_name}")

    selected_num = 1
    return gedcom_files[selected_num - 1]

#We set the value of selected_num to 1.
gedcom_file_path = select_gedcom_file()
if gedcom_file_path is None:
    print("No GEDCOM file selected. Exiting.")
    exit()

# Function definitions
def extract_id(record):
  """Extracts the individual ID from a GEDCOM record.

  Args:
    record: A GEDCOM record.

  Returns:
    The individual ID, or None if the record does not contain an individual ID.
  """

  parts = record.split('\n')
  for part in parts:
    if part.startswith('@INDI@'):
      return part[7:11]
  return None

def extract_name(record):
  """Extracts the name of the individual from a GEDCOM record.

  Args:
    record: A GEDCOM record.

  Returns:
    The individual's name, or None if the record does not contain the individual's name.
  """

  parts = record.split('\n')
  for part in parts:
    if part.startswith('NAME '):
      return part[5:]
  return None

# Now, read the GEDCOM file and split it into individual and family records
with open(gedcom_file_path, 'r') as file:
  data = file.read()
  data = data.split('\n0 ')
  records = {extract_id(record): record for record in data}

gedcom_instance = Gedcom(gedcom_file_path)
#gedcom_instance.filter_individuals()

def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record = records[individual_id]

    print(f"record is: {record}")  # Debugging statement

    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]

    if famc_id not in records:
        return

    fam_record = records[famc_id]

    print(f"fam_record is: {fam_record}")  # Debugging statement

    try:
        wife_start = fam_record.find('1 WIFE @') + 8
        wife_end = fam_record.find('@', wife_start)
        mother_id = fam_record[wife_start:wife_end]
    except AttributeError:
        print("AttributeError at wife section.")

    try:
        husb_start = fam_record.find('1 HUSB @') + 8
        husb_end = fam_record.find('@', husb_start)
        father_id = fam_record[husb_start:husb_end]
    except AttributeError:
        print("AttributeError at husband section.")
    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)

def has_both_parents(records, mother_id, father_id):
    return mother_id in records and father_id in records

visited_pairs = set()

import gedcom

def input_prime_surname(last_prime_surname="Yates"):  # Set default surname to "Yates"
    global surname  # Declare surname as a global variable
    if last_prime_surname:
        last_name = last_prime_surname  # Directly use the default value
    else:
        last_name = "Unknown"  # Set to 'Unknown' if no default surname is provided
    surname = last_name  # Assign the value of last_name to the global surname variable
    return last_name

# Call the function to set prime_surname using the default value
prime_surname = input_prime_surname()

# Store the value of prime_surname for later use
last_prime_surname = prime_surname


# Initialize parent_pairs, children, and ancestral_lines
parent_pairs = []
children = {}
ancestral_lines = {}

last_pair_count = 0  # Counter variable outside the function to keep track

def find_parents_new(individual_id, generation, records, parent_pairs, children, ancestral_lines):
    global last_pairs_dict  # Declare as global so we can update it
    global last_pair_count  # Declare as global so we can update it

    current_line = []

    if individual_id not in records:
        # print("0921-2037-individual_id not in records")
        return

    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]

    if famc_id not in records:
        return

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if mother_id in records:
        mother_name = extract_name(records[mother_id])
    else:
        mother_name = None

    if father_id in records:
        father_name = extract_name(records[father_id])
    else:
        father_name = None

    if mother_id not in records and father_id not in records:
        last_pair = "None&None"
    elif mother_id not in records:
        last_pair = f"None&{father_id}"
    elif father_id not in records:
        last_pair = f"{mother_id}&None"
    else:
        last_pair = f"{father_id}&{mother_id}"

    last_pair_count += 1   # Count and print
    print(f"Last Pair {last_pair_count}: {last_pair}")

    last_pairs_dict[individual_id] = last_pair

    if mother_name and father_name:
        parent_pair = father_name + "&" + mother_name
        current_line.append((generation, parent_pair))
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                parent_pairs.append((generation, parent_pair))
                ancestral_lines[parent_pair] = list(current_line)

    if mother_id:
        find_parents_new(mother_id, generation + 1, records, parent_pairs, children, ancestral_lines)

    if father_id:
        find_parents_new(father_id, generation + 1, records, parent_pairs, children, ancestral_lines)

    current_line.pop()

last_pair_count = 0# Reset the counter before running the function again

ancestral_lines = {}
find_parents_new(individual_id, 1, records, parent_pairs, children, ancestral_lines)

for last_pair, ancestral_line in ancestral_lines.items():
    print(f'Ancestral line for last pair {last_pair}:')
    for generation, parent_pair in ancestral_line:
        print(f'  Generation {generation}: {parent_pair}')

def process_individual_new(individual_id):
    global generation_table  # DataFrame to hold generation and parent pair info
    global visited_pairs     # Set to hold visited parent pairs
    global individual        # Individual GEDCOM element

    # Initialize globals
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    visited_pairs = set()

    # Local variables
    parent_pairs = []
    children = {}
    ancestral_lines = {}

    find_parents_new(individual_id, 1, records, parent_pairs, children, ancestral_lines)

    # Add anchor_gen1 to the beginning of each ancestral line
    for last_pair, ancestral_line in ancestral_lines.items():
        # Check if anchor_gen1 has been assigned a value
        if anchor_gen1 is not None:
            ancestral_line.insert(0, (1, anchor_gen1))

    individual_data = {}
    individual_data['Last Pairs'] = ancestral_lines

    return individual_data

individual_data = process_individual_new(individual_id)
last_pairs = individual_data['Last Pairs']

def trace_children(individual_id, parent_pairs, children, visited=None):
    # Create a list to store the children of the individual
    individual_children = []

    # Create a set to keep track of visited individuals
    if visited is None:
        visited = set()

    # Check if the individual has already been visited
    if individual_id in visited:
        # If the individual has already been visited, stop the recursion and return an empty list
        return individual_children

    # Add the individual to the set of visited individuals
    visited.add(individual_id)

    # Find the name of the individual
    individual_name = None
    for pair in parent_pairs:
        if "lastpair" in pair[1]:
            names = pair[1].split('&')
            if individual_id in children[names[0]]:
                individual_name = names[0]
            elif individual_id in children[names[1]]:
                individual_name = names[1]
            break

    # Check if the individual has any children
    if individual_name in children:
        # Add the children of the individual to the list
        individual_children.extend(children[individual_name])

        # Recursively find the children of the individual's children
        for child_id in children[individual_name]:
            child_children = trace_children(child_id, parent_pairs, children, visited)
            individual_children.extend(child_children)

    return individual_children

descendants = trace_children(individual_id, parent_pairs, children)
print(f'0921-2036-The ancestors of individual {individual_id} are: {descendants}')

target_surname = surname# user enters the surname=target surname

# Define a scoring function that counts the number of occurrences of the target surname in an ancestral line
def score_ancestral_line(ancestral_line_list):
    score = 0
    for line in map(str, ancestral_line_list):
        if target_surname in line:
            score += 1
    return score

scores = {}# Initialize an empty dictionary to store the scores

ancestral_lines_list = list(ancestral_lines.items())# Convert the tuples into a list

# Compute and store the scores for each last pair
for last_pair, ancestral_line in ancestral_lines_list:
    scores[last_pair] = score_ancestral_line(ancestral_line)

# Find the final-line with the highest score
if scores:
    final_pair = max(scores, key=scores.get)
else:
    print("Scores dictionary is empty. Cannot find the maximum.")
    final_pair = None

if final_pair is not None:
    final_score = scores[final_pair]
else:
    print("Final pair is None. Cannot find the final score.")
    final_score = None

# Print the last pair and score for each ancestral line
#for last_pair, score in scores.items():
#    print(f"Last pair: {last_pair} (score: {score})")

# Print the final-line with a designation of 'final-line' to the highest score
# print(f"dnaline: {final_pair} (score: {final_score})")

# Initialize a dictionary to store the cumulative scores for each branch line
cumulative_scores = {}

# Calculate and store the cumulative scores for each branch line and generation
for last_pair, ancestral_line in ancestral_lines_list:
    cumulative_score = 0
    for generation, line in enumerate(ancestral_line, start=1):
        generation_score = score_ancestral_line([line])
        cumulative_score += generation_score
        cumulative_scores.setdefault(line, 0)  # Initialize cumulative score for line if not exists
        cumulative_scores[line] += cumulative_score

# Print the cumulative scores for each branch line and generation
for line, cumulative_score in cumulative_scores.items():
    print(f"Ancestral line: {line}, Cumulative Score = {cumulative_score}")

if cumulative_scores:  # Checks if the dictionary is not empty# Find the final-line with the highest cumulative score
    final_line = max(cumulative_scores, key=cumulative_scores.get)
    final_cumulative_score = cumulative_scores[final_line]
else:
    print("#1 Cumulative scores are empty. Cannot find the final line or score.")
    final_line = None
    final_cumulative_score = None

if cumulative_scores:  # Checks if the dictionary is not empty
    final_line = max(cumulative_scores, key=cumulative_scores.get)
    final_cumulative_score = cumulative_scores[final_line]
else:
    print("#2 Cumulative scores are empty. Cannot find the final line or score.")
    final_line = None
    final_cumulative_score = None

if final_line is not None:
    final_cumulative_score = cumulative_scores[final_line]
else:
    print("Final line is None. Cannot access cumulative_scores[final_line].")
    final_cumulative_score = None

print(f"dnaline: {final_line}, Cumulative Score = {final_cumulative_score}")# Print the final-line with the highest cumulative score

combined_df_rows = []# Run the process_individual function for each individual in the individuals list and create a combined DataFrame

for name, individual_id in gedcom_instance.individuals:
    individual_data = process_individual_new(individual_id)

    cm = individual_data.get('cM', None)  # Get 'cM' from dictionary, default to None if not found
    sort = individual_data.get('Sort', None)  # Get 'Sort' from dictionary, default to None if not found
    parent_pairs_a10 = individual_data.get('Last Pairs', {})  # Get 'Last Pairs' from dictionary, default to empty dict if not found

    if cm is not None and sort is not None:  # Check if both 'cM' and 'Sort' are not None before proceeding
        most_distant_ancestor = generation_table.iloc[0]['Parent Pair']  # Get the most distant ancestor from the last row of generation_table
        combined_df_rows.append([individual_id, name, sort, cm, most_distant_ancestor, parent_pairs_a10])

combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Name', 'Match to', 'cM', 'Most Distant Ancestor', 'Ancestral Line A10'])
# Out:
# List of GEDCOM files:
# 1. yates-one-name-study.ged
# Total records found: 50776
# Records tagged as filter_pool records: 375
# Records tagged as filter_pool records: 375
# Individual ID: I13817, Anchor Gen1: YatesWilliam
# Individual ID: I21743, Anchor Gen1: HuntKelsey
# Individual ID: I23678, Anchor Gen1: JohnsonDonald
# Individual ID: I26925, Anchor Gen1: HudsonJL
# Individual ID: I31861, Anchor Gen1: ChurchDebra
# Individual ID: I40190, Anchor Gen1: DikeBeth
# Individual ID: I42478, Anchor Gen1: RoperHolly
# Individual ID: I44570, Anchor Gen1: HepburnMark
# Individual ID: I44883, Anchor Gen1: YatesRobert
# Individual ID: I44894, Anchor Gen1: YatesCraig
# Individual ID: I44935, Anchor Gen1: PugsleyHarold
# Individual ID: I45040, Anchor Gen1: KeethLaura
# Individual ID: I45059, Anchor Gen1: OstergaardDale
# Individual ID: I45072, Anchor Gen1: JacksonVirginia
# Individual ID: I45084, Anchor Gen1: AndrewsMarvin
# Individual ID: I45104, Anchor Gen1: DaleJuletta
# Individual ID: I45119, Anchor Gen1: KearleyCharles
# Individual ID: I45133, Anchor Gen1: LichtensteinEric
# Individual ID: I45149, Anchor Gen1: CresseBarbara
# Individual ID: I45150, Anchor Gen1: MeadowsDana
# Individual ID: I45201, Anchor Gen1: WaltersBecky
# Individual ID: I45394, Anchor Gen1: AyersDianna
# Individual ID: I45417, Anchor Gen1: AntillMargaret
# Individual ID: I45439, Anchor Gen1: CombsMegan
# Individual ID: I45462, Anchor Gen1: BolesDavid
# Individual ID: I45467, Anchor Gen1: CopelandDean
# Individual ID: I45499, Anchor Gen1: FitchJeanee
# Individual ID: I45520, Anchor Gen1: ClodfelterGrace
# Individual ID: I45534, Anchor Gen1: RobinsonDiane
# Individual ID: I45552, Anchor Gen1: DavisSara
# Individual ID: I45591, Anchor Gen1: ErkmannMegan
# Individual ID: I45612, Anchor Gen1: SegrestMichael
# Individual ID: I45632, Anchor Gen1: WilsonValorie
# Individual ID: I45636, Anchor Gen1: KelleyWalter
# Individual ID: I45665, Anchor Gen1: ShakeNancy
# Individual ID: I45670, Anchor Gen1: YatesClinton
# Individual ID: I45672, Anchor Gen1: BearceKara
# Individual ID: I45690, Anchor Gen1: BennettKarry
# Individual ID: I45700, Anchor Gen1: HarveyBrittany
# Individual ID: I45722, Anchor Gen1: DotyNathaniel
# Individual ID: I45741, Anchor Gen1: KramerRichard
# Individual ID: I45809, Anchor Gen1: YoungJ
# Individual ID: I45823, Anchor Gen1: EstepEllen
# Individual ID: I45833, Anchor Gen1: ShepardG
# Individual ID: I45864, Anchor Gen1: WilliamsRonald
# Individual ID: I45897, Anchor Gen1: GravesGene
# Individual ID: I45907, Anchor Gen1: HallBryan
# Individual ID: I45932, Anchor Gen1: DayMary
# Individual ID: I45937, Anchor Gen1: DuttonRegina
# Individual ID: I45949, Anchor Gen1: HerndonKathryn
# Individual ID: I45980, Anchor Gen1: CooperJames
# Individual ID: I46008, Anchor Gen1: SmithRoy
# Individual ID: I46034, Anchor Gen1: LaDuctScott
# Individual ID: I46054, Anchor Gen1: GentrySharon
# Individual ID: I46068, Anchor Gen1: RoseCynthia
# Individual ID: I46085, Anchor Gen1: LyonsMichael
# Individual ID: I46102, Anchor Gen1: OdlePeggy
# Individual ID: I46119, Anchor Gen1: RameyMyrtle
# Individual ID: I46129, Anchor Gen1: JonesMary
# Individual ID: I46144, Anchor Gen1: RiddleAllison
# Individual ID: I46154, Anchor Gen1: BurranEdward
# Individual ID: I46168, Anchor Gen1: LawsonGary
# Individual ID: I46175, Anchor Gen1: SheroanJames
# Individual ID: I46186, Anchor Gen1: FishbackCarol
# Individual ID: I46197, Anchor Gen1: YoutherRobert
# Individual ID: I46207, Anchor Gen1: WhiteTodd
# Individual ID: I46214, Anchor Gen1: RayburnSteven
# Individual ID: I46231, Anchor Gen1: DenbowKimberly
# Individual ID: I46243, Anchor Gen1: RolandLee
# Individual ID: I46269, Anchor Gen1: StewartThomas
# Individual ID: I46285, Anchor Gen1: RileyWilliam
# Individual ID: I46303, Anchor Gen1: PetersonTerry
# Individual ID: I46317, Anchor Gen1: SmithDeborah
# Individual ID: I46330, Anchor Gen1: WeedmanAngela
# Individual ID: I46346, Anchor Gen1: SchenckLarry
# Individual ID: I46370, Anchor Gen1: PerkinsTeresa
# Individual ID: I46390, Anchor Gen1: BurnsCarole
# Individual ID: I46402, Anchor Gen1: MartinRobert
# Individual ID: I46403, Anchor Gen1: MartinTroy
# Individual ID: I46415, Anchor Gen1: HarrisMary
# Individual ID: I46423, Anchor Gen1: HilburnTeresa
# Individual ID: I46430, Anchor Gen1: MolesworthBrandi
# Individual ID: I46448, Anchor Gen1: Walden-JacoMargo
# Individual ID: I46457, Anchor Gen1: HartLeonard
# Individual ID: I46470, Anchor Gen1: PriceCheryl
# Individual ID: I46495, Anchor Gen1: StocksdaleTammy
# Individual ID: I46502, Anchor Gen1: LooneyCathi
# Individual ID: I46508, Anchor Gen1: OsterholmDebra
# Individual ID: I46516, Anchor Gen1: ArfmannSusan
# Individual ID: I46528, Anchor Gen1: JohnsonJeremiah
# Individual ID: I46538, Anchor Gen1: WadeCorey
# Individual ID: I46550, Anchor Gen1: JonesDonald
# Individual ID: I46562, Anchor Gen1: BooneDavid
# Individual ID: I46572, Anchor Gen1: ClemmerJuliana
# Individual ID: I46584, Anchor Gen1: YatesMary
# Individual ID: I46593, Anchor Gen1: CollinsChristopher
# Individual ID: I46603, Anchor Gen1: WilesAaron
# Individual ID: I46628, Anchor Gen1: BlackAnne
# Individual ID: I46641, Anchor Gen1: MapesPatricia
# Individual ID: I46655, Anchor Gen1: KaiserSamantha
# Individual ID: I46667, Anchor Gen1: EddyJoni
# Individual ID: I46681, Anchor Gen1: LauterLarraine
# Individual ID: I46706, Anchor Gen1: WessnerTracey
# Individual ID: I46721, Anchor Gen1: CurtisMarjorie
# Individual ID: I46750, Anchor Gen1: TurleyJacqueline
# Individual ID: I46764, Anchor Gen1: FiskWalter
# Individual ID: I46792, Anchor Gen1: LeavertonMelissa
# Individual ID: I46811, Anchor Gen1: NielsenSusan
# Individual ID: I46826, Anchor Gen1: ClemLissa
# Individual ID: I46836, Anchor Gen1: BeshearsJames
# Individual ID: I46847, Anchor Gen1: FredrickAmanda
# Individual ID: I46861, Anchor Gen1: RobertsonArch
# Individual ID: I46872, Anchor Gen1: LeCompteNina
# Individual ID: I46881, Anchor Gen1: SmockEldon
# Individual ID: I46894, Anchor Gen1: StewartPatricia
# Individual ID: I46903, Anchor Gen1: TewellPhyllis
# Individual ID: I46917, Anchor Gen1: BoyceJames
# Individual ID: I46924, Anchor Gen1: ParkinsonAmber
# Individual ID: I46934, Anchor Gen1: NearingMary
# Individual ID: I46945, Anchor Gen1: MassieKimberly
# Individual ID: I46954, Anchor Gen1: WhiteJennifer
# Individual ID: I46965, Anchor Gen1: HadleyJoan
# Individual ID: I46985, Anchor Gen1: Carson-KimpleLeah
# Individual ID: I46996, Anchor Gen1: SmithDeborah
# Individual ID: I47009, Anchor Gen1: MasseyPamela
# Individual ID: I47026, Anchor Gen1: Tullis-Taylor
# Individual ID: I47039, Anchor Gen1: ShottsAmanda
# Individual ID: I47054, Anchor Gen1: HamiltonKatherine
# Individual ID: I47076, Anchor Gen1: DyerClarice
# Individual ID: I47088, Anchor Gen1: SullivanGinevera
# Individual ID: I47098, Anchor Gen1: YoungmanDiane
# Individual ID: I47110, Anchor Gen1: CloningerWilliam
# Individual ID: I47123, Anchor Gen1: Haney-ChandlerErin
# Individual ID: I47131, Anchor Gen1: CrabtreeChad
# Individual ID: I47142, Anchor Gen1: MatthisSharon
# Individual ID: I47156, Anchor Gen1: ReedPatricia
# Individual ID: I47163, Anchor Gen1: BarkleyBeverly
# Individual ID: I47172, Anchor Gen1: SullensLawrence
# Individual ID: I47182, Anchor Gen1: GrauDavid
# Individual ID: I47193, Anchor Gen1: FaberCecelia
# Individual ID: I47205, Anchor Gen1: MooreHarold
# Individual ID: I47216, Anchor Gen1: BrysonMildred
# Individual ID: I47228, Anchor Gen1: FlemingTlcjones111
# Individual ID: I47241, Anchor Gen1: StanleyMilton
# Individual ID: I47250, Anchor Gen1: HelsleyNathan
# Individual ID: I47257, Anchor Gen1: ViolettaLawrence
# Individual ID: I47270, Anchor Gen1: RunyonSusan
# Individual ID: I47279, Anchor Gen1: Peckgabmore29
# Individual ID: I47292, Anchor Gen1: CrapseTeresa
# Individual ID: I47306, Anchor Gen1: MyersDiana
# Individual ID: I47318, Anchor Gen1: NicholasMary
# Individual ID: I47327, Anchor Gen1: PrattSharon
# Individual ID: I47338, Anchor Gen1: GilmoreCheri
# Individual ID: I47350, Anchor Gen1: LaxTina
# Individual ID: I47365, Anchor Gen1: AndersonSaralinda
# Individual ID: I47379, Anchor Gen1: AdamsRichard
# Individual ID: I47393, Anchor Gen1: CrouchJohn
# Individual ID: I47406, Anchor Gen1: WolfeChristopher
# Individual ID: I47416, Anchor Gen1: StrattonJudith
# Individual ID: I47427, Anchor Gen1: BrickerLoretta
# Individual ID: I47435, Anchor Gen1: BrooksJenny
# Individual ID: I47447, Anchor Gen1: LucasAmanda
# Individual ID: I47466, Anchor Gen1: OgleFremont
# Individual ID: I47497, Anchor Gen1: ErwinJames
# Individual ID: I47510, Anchor Gen1: EvansMarilyn
# Individual ID: I47528, Anchor Gen1: HafnerMichael
# Individual ID: I47542, Anchor Gen1: HubbardTuffy
# Individual ID: I47691, Anchor Gen1: RiddleBlakeRonald
# Individual ID: I47698, Anchor Gen1: JonesDonna
# Individual ID: I47711, Anchor Gen1: ThompsonLane
# Individual ID: I47733, Anchor Gen1: HayesCharles
# Individual ID: I47798, Anchor Gen1: SearsCathleen
# Individual ID: I47806, Anchor Gen1: SuttleJason
# Individual ID: I47881, Anchor Gen1: LawsonCyntha
# Individual ID: I47891, Anchor Gen1: GlissonCharles
# Individual ID: I47906, Anchor Gen1: FullenSpencer
# Individual ID: I47918, Anchor Gen1: EnglandS
# Individual ID: I47929, Anchor Gen1: BurnsMaggy
# Individual ID: I47948, Anchor Gen1: WebbAndrew
# Individual ID: I47958, Anchor Gen1: HeiserGeorge
# Individual ID: I47971, Anchor Gen1: UtzJohn
# Individual ID: I47979, Anchor Gen1: RuddPatsy
# Individual ID: I48125, Anchor Gen1: LukeNancy
# Individual ID: I48151, Anchor Gen1: CarterStuart
# Individual ID: I48162, Anchor Gen1: NewtonMark
# Individual ID: I48171, Anchor Gen1: BowenCharles
# Individual ID: I48182, Anchor Gen1: AdamsShirley
# Individual ID: I48195, Anchor Gen1: YatesDavid
# Individual ID: I48210, Anchor Gen1: ChamberlainCorey
# Individual ID: I48217, Anchor Gen1: YatesBeverly
# Individual ID: I48228, Anchor Gen1: LoveDaniel
# Individual ID: I48240, Anchor Gen1: MarshElizabeth
# Individual ID: I48247, Anchor Gen1: SmootKathryn
# Individual ID: I48257, Anchor Gen1: MontgomeryTina
# Individual ID: I48274, Anchor Gen1: CurtisBeverly
# Individual ID: I48278, Anchor Gen1: ThompsonMelba
# Individual ID: I48292, Anchor Gen1: VaughnJeff
# Individual ID: I48304, Anchor Gen1: BurnamJudy
# Individual ID: I48314, Anchor Gen1: SniderJill
# Individual ID: I48331, Anchor Gen1: HamptonAbbigail
# Individual ID: I48337, Anchor Gen1: DavisChristine
# Individual ID: I48354, Anchor Gen1: RigginsSara
# Individual ID: I48375, Anchor Gen1: SheltonDiana
# Individual ID: I48384, Anchor Gen1: YatesBryan
# Individual ID: I48391, Anchor Gen1: YatesMarion
# Individual ID: I48403, Anchor Gen1: GodseyDaisy
# Individual ID: I48415, Anchor Gen1: MedcalfSarah
# Individual ID: I48420, Anchor Gen1: HuguninWilliam
# Individual ID: I48430, Anchor Gen1: KnutsonMichelle
# Individual ID: I48438, Anchor Gen1: McClendonAlicia
# Individual ID: I48452, Anchor Gen1: CobleJames
# Individual ID: I48471, Anchor Gen1: ThomasEmma
# Individual ID: I48481, Anchor Gen1: FreemanDennis
# Individual ID: I48489, Anchor Gen1: YatesMelva
# Individual ID: I48503, Anchor Gen1: OutlawLinda
# Individual ID: I48516, Anchor Gen1: EshelmanJake
# Individual ID: I48525, Anchor Gen1: ShuckHarley
# Individual ID: I48538, Anchor Gen1: WilfongJeremy
# Individual ID: I48552, Anchor Gen1: SheltonDonald
# Individual ID: I48560, Anchor Gen1: MillerJeffrey
# Individual ID: I48573, Anchor Gen1: BriggsPenny
# Individual ID: I48581, Anchor Gen1: HerrinJanet
# Individual ID: I48593, Anchor Gen1: FlintAshley
# Individual ID: I48605, Anchor Gen1: HalleyKathleen
# Individual ID: I48614, Anchor Gen1: DockeryNicole
# Individual ID: I48627, Anchor Gen1: CrossJohn
# Individual ID: I48628, Anchor Gen1: DeliganisMelinda
# Individual ID: I48642, Anchor Gen1: PratherJackie
# Individual ID: I48652, Anchor Gen1: WestcottGloria
# Individual ID: I48664, Anchor Gen1: TuckerDaniel
# Individual ID: I48670, Anchor Gen1: CheeverConnie
# Individual ID: I48674, Anchor Gen1: YatesRalph
# Individual ID: I48686, Anchor Gen1: UnderwoodLarry
# Individual ID: I48697, Anchor Gen1: BurchitRobert
# Individual ID: I48706, Anchor Gen1: FornalStephen
# Individual ID: I48710, Anchor Gen1: ArnoldEmily
# Individual ID: I48721, Anchor Gen1: ChildersPeggy
# Individual ID: I48728, Anchor Gen1: WermePamela
# Individual ID: I48737, Anchor Gen1: SitzerKaren
# Individual ID: I48744, Anchor Gen1: ThomasWoodrow
# Individual ID: I48752, Anchor Gen1: FarmerClaudia
# Individual ID: I48765, Anchor Gen1: HarclerodeLouis
# Individual ID: I48767, Anchor Gen1: NunnRoseann
# Individual ID: I48784, Anchor Gen1: StoufferLinda
# Individual ID: I48792, Anchor Gen1: CarrawayViolet
# Individual ID: I48799, Anchor Gen1: JonesJeremie
# Individual ID: I48812, Anchor Gen1: ColwellBrittany
# Individual ID: I48821, Anchor Gen1: KinselJohn
# Individual ID: I48830, Anchor Gen1: ParksKathy
# Individual ID: I48837, Anchor Gen1: AdamsAdrew
# Individual ID: I48843, Anchor Gen1: RussellPatsy
# Individual ID: I48857, Anchor Gen1: JohnsonLarry
# Individual ID: I48868, Anchor Gen1: BranchDaughter
# Individual ID: I48887, Anchor Gen1: BarnesLinda
# Individual ID: I48898, Anchor Gen1: WalkerMary
# Individual ID: I48901, Anchor Gen1: OdenwaldBetty
# Individual ID: I48919, Anchor Gen1: PalmerMayhugh
# Individual ID: I48935, Anchor Gen1: ChaneySierra
# Individual ID: I48945, Anchor Gen1: StevensGregory
# Individual ID: I48954, Anchor Gen1: PowersKatherine
# Individual ID: I48965, Anchor Gen1: TreeceGary
# Individual ID: I48970, Anchor Gen1: PresleyKathleen
# Individual ID: I48983, Anchor Gen1: DillionSusan
# Individual ID: I48998, Anchor Gen1: SmithBB
# Individual ID: I49006, Anchor Gen1: DreckshageTeresa
# Individual ID: I49020, Anchor Gen1: BrewerRilla
# Individual ID: I49027, Anchor Gen1: WillinghamItura
# Individual ID: I49039, Anchor Gen1: CallawayJames
# Individual ID: I49061, Anchor Gen1: BaughAngela
# Individual ID: I49076, Anchor Gen1: YatesJuanita
# Individual ID: I49085, Anchor Gen1: JonesDonald
# Individual ID: I49095, Anchor Gen1: MaxwellTaylor
# Individual ID: I49101, Anchor Gen1: WeibeMark
# Individual ID: I49115, Anchor Gen1: GrissomMichael
# Individual ID: I49132, Anchor Gen1: BradleyJeffrey
# Individual ID: I49140, Anchor Gen1: WallaceLuke
# Individual ID: I49152, Anchor Gen1: StewartLowell
# Individual ID: I49165, Anchor Gen1: ThompsonBeverly
# Individual ID: I49178, Anchor Gen1: LewisCynthia
# Individual ID: I49189, Anchor Gen1: HartyVivian
# Individual ID: I49197, Anchor Gen1: PattonMichael
# Individual ID: I49206, Anchor Gen1: WilliamsVickie
# Individual ID: I49220, Anchor Gen1: ThompsonDorothy
# Individual ID: I49230, Anchor Gen1: HollandLoren
# Individual ID: I49240, Anchor Gen1: CaudleLisa
# Individual ID: I49250, Anchor Gen1: YatesLinda
# Individual ID: I49276, Anchor Gen1: MacyCassy
# Individual ID: I49289, Anchor Gen1: WhiteJames
# Individual ID: I49316, Anchor Gen1: YatesNathan
# Individual ID: I49326, Anchor Gen1: WilsonHaley
# Individual ID: I49337, Anchor Gen1: SmithSue
# Individual ID: I49369, Anchor Gen1: GrahamLarry
# Individual ID: I49380, Anchor Gen1: ShackletteRomi
# Individual ID: I49396, Anchor Gen1: JarboeSherree
# Individual ID: I49402, Anchor Gen1: HarrisNorman
# Individual ID: I49409, Anchor Gen1: ShearJoshua
# Individual ID: I49427, Anchor Gen1: BergJeanell
# Individual ID: I49442, Anchor Gen1: HadleyJed
# Individual ID: I49444, Anchor Gen1: BrowningChristina
# Individual ID: I49459, Anchor Gen1: SimpsonWilliam
# Individual ID: I49465, Anchor Gen1: GirtenWilliam
# Individual ID: I49471, Anchor Gen1: HarringtonD
# Individual ID: I49476, Anchor Gen1: PeakJacqueline
# Individual ID: I49491, Anchor Gen1: HonLinda
# Individual ID: I49502, Anchor Gen1: SnookZach
# Individual ID: I49511, Anchor Gen1: StorkRichard
# Individual ID: I49520, Anchor Gen1: FieldsMichelle
# Individual ID: I49565, Anchor Gen1: HunnicuttM.
# Individual ID: I49570, Anchor Gen1: GreenJanice
# Individual ID: I49580, Anchor Gen1: BarberRobert
# Individual ID: I49593, Anchor Gen1: HowlandChristopher
# Individual ID: I49607, Anchor Gen1: LacewellGlenn
# Individual ID: I49615, Anchor Gen1: YatesMichael
# Individual ID: I49636, Anchor Gen1: WelchKatherine
# Individual ID: I49652, Anchor Gen1: BriggsMary
# Individual ID: I49657, Anchor Gen1: SmithRobyn
# Individual ID: I49673, Anchor Gen1: WilliamsJessie
# Individual ID: I49682, Anchor Gen1: GriffisTonya
# Individual ID: I49693, Anchor Gen1: RobertsonMiriam
# Individual ID: I49699, Anchor Gen1: ConnerAddie
# Individual ID: I49708, Anchor Gen1: YatesRobert
# Individual ID: I49717, Anchor Gen1: FussellAngela
# Individual ID: I49730, Anchor Gen1: CarnegieRichard
# Individual ID: I49755, Anchor Gen1: McDanalZachary
# Individual ID: I49784, Anchor Gen1: MidyetteSarah
# Individual ID: I49799, Anchor Gen1: StonerStephanie
# Individual ID: I49813, Anchor Gen1: IngeElizabeth
# Individual ID: I49833, Anchor Gen1: HayesPreston
# Individual ID: I49847, Anchor Gen1: ZimmermanJessica
# Individual ID: I49862, Anchor Gen1: PorterSheila
# Individual ID: I49876, Anchor Gen1: TempletonDonald
# Individual ID: I49896, Anchor Gen1: CrispBryan
# Individual ID: I49905, Anchor Gen1: WellsRhonda
# Individual ID: I49917, Anchor Gen1: HurleyTiffany
# Individual ID: I49955, Anchor Gen1: HallTashia
# Individual ID: I49982, Anchor Gen1: HollingsworthKN
# Individual ID: I49996, Anchor Gen1: FaughnAmanda
# Individual ID: I50006, Anchor Gen1: HansonDaryl
# Individual ID: I50013, Anchor Gen1: YatesRobert
# Individual ID: I50024, Anchor Gen1: MillerSusan
# Individual ID: I50033, Anchor Gen1: DudleyJean
# Individual ID: I50046, Anchor Gen1: RogersRhonda
# Individual ID: I50057, Anchor Gen1: HaeckerArthur
# Individual ID: I50069, Anchor Gen1: HorneGlynda
# Individual ID: I50098, Anchor Gen1: WinkelmanPeter
# Individual ID: I50111, Anchor Gen1: PowersKaren
# Individual ID: I50124, Anchor Gen1: AmesCharlotte
# Individual ID: I50144, Anchor Gen1: TerryCarolyn
# Individual ID: I50164, Anchor Gen1: FarrHayley
# Individual ID: I50184, Anchor Gen1: UngerJill
# Individual ID: I50191, Anchor Gen1: RichardsRoxie
# Individual ID: I50225, Anchor Gen1: SingletonJohn
# Individual ID: I50249, Anchor Gen1: MosesShelley
# Individual ID: I50264, Anchor Gen1: BaileyJ
# Individual ID: I50275, Anchor Gen1: MasonJean
# Individual ID: I50309, Anchor Gen1: YatesDonald
# Individual ID: I50326, Anchor Gen1: LibbyShirley
# Individual ID: I50355, Anchor Gen1: HunterSamuel
# Individual ID: I50364, Anchor Gen1: HumphriesBrandon
# Individual ID: I50369, Anchor Gen1: MillerMyra
# Individual ID: I50375, Anchor Gen1: MyersRichard
# Individual ID: I50391, Anchor Gen1: WilsonDeborah
# Individual ID: I50405, Anchor Gen1: HarndenScott
# Individual ID: I50416, Anchor Gen1: GoreSon
# Individual ID: I50429, Anchor Gen1: MannSharon
# Individual ID: I50440, Anchor Gen1: BevingtonShelly
# Individual ID: I50449, Anchor Gen1: SheltonLinda
# Individual ID: I50459, Anchor Gen1: EdwardsSandra
# Individual ID: I50472, Anchor Gen1: BrazellDeborah
# Individual ID: I50482, Anchor Gen1: PotterSusan
# Individual ID: I50494, Anchor Gen1: BeaversLaNell
# Individual ID: I50511, Anchor Gen1: StiversKaylee
# Individual ID: I50522, Anchor Gen1: FehrenbacherAngela
# Individual ID: I50535, Anchor Gen1: PetersonHannah
# Individual ID: I50551, Anchor Gen1: NicholsTheresa
# 0921-2036-The ancestors of individual I50551 are: []
# Scores dictionary is empty. Cannot find the maximum.
# Final pair is None. Cannot find the final score.
# #1 Cumulative scores are empty. Cannot find the final line or score.
# #2 Cumulative scores are empty. Cannot find the final line or score.
# Final line is None. Cannot access cumulative_scores[final_line].
# dnaline: None, Cumulative Score = None

# %%
# !pip install pandas
# !pip install python-gedcom
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting python-gedcom
#   Downloading python_gedcom-1.0.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
