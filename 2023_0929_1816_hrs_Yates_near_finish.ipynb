# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/2023_0929_1816_hrs_Yates_near_finish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import glob
import os
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.records = {}  # Initialize records attribute here
        self.gedcom_datasets = []  # Keep this if other parts of your code depend on it
        self.filter_pool = {}

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

    def parse_gedcom(self):
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()

        current_dataset = None
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                current_dataset = GedcomDataset(tag)
                self.records[tag] = current_dataset
                self.gedcom_datasets.append(current_dataset)  # Add to the list of datasets
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_dataset.add_extractable_detail(tag, value)
                elif level == 2 and tag == 'NPFX':
                    current_dataset.add_extractable_detail(tag, value)

#        print(f"47-GEDCOM contained {len(self.records)} total records")

    def apply_csv_filter(self, csv_file_path):  # BACKWARDS CONVERSION TO EASE CSV MAUNUAL FILTER OF ID"s
        if not os.path.exists(csv_file_path):
            print("CSV file not found. Proceeding without filtering by CSV.")
            return

        df = pd.read_csv(csv_file_path)
        # Add '@' to the beginning and end of each ID to match the GEDCOM format
        filtered_ids = set(f"@{x}@" for x in df['ID'])

        self.filter_pool = {k: v for k, v in self.records.items() if k in filtered_ids}

        print(f'Records manually CSV filtered: {len(self.filter_pool)}')

    def apply_npfx_filter(self):
        self.filter_pool = {k: v for k, v in self.records.items() if v.get_extractable_NPFX()}

        print(f"Records tagged and filtered by NPFX: {len(self.filter_pool)}")
        print(f"GEDCOM contained {len(self.records)} total records")

        for dataset in self.gedcom_datasets:
            if dataset.get_extractable_NPFX():
                self.filter_pool[dataset.get_gen_person()] = dataset  # Use dataset ID as the key

        print("Number of records:", len(self.records))
        print("Keys of the records:", list(self.records.keys()))

def extract_id(record):  # Moved outside of the class so it's a standalone function
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(gedcom_dataset_instance):# Moved outside of the class so it's a standalone function
    record = gedcom_dataset_instance.extractable_detail.get('NAME', '')
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]

    if '/' not in name:
        print(f"Invalid name format for record: {record[:50]}...")  # Print the first 100 characters of the problematic record for debugging
        return None  # or you could return a default value like "UnknownUnknown"

    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]  # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/')  # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def has_both_parents(records, mother_id, father_id):   # Moved outside of the class so it's a standalone function
    return mother_id in records and father_id in records

class GedcomDataset:
    def __init__(self, individual_id):
        self.individual_id = individual_id
        self.extractable_detail = {}
        self.anchor_gen1 = None

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        return self.individual_id.strip('@')

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

    def get_extractable_WIFE(self):
        return self.extractable_detail.get('WIFE', '').strip('@')

    def get_extractable_HUSB(self):
        return self.extractable_detail.get('HUSB', '').strip('@')


    def get_anchor_gen1(self):
        name = self.extractable_detail.get('NAME', '')
        if '/' in name:
            first_name, last_name = name.split('/', 1)
            first_name = first_name.split(' ')[0]
            last_name = last_name.rstrip('/')
            self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
            return self.anchor_gen1
        else:
#            print(f"Warning: No '/' found in NAME tag for individual {self.get_gen_person()}")
            return ''

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

gedcom_file_path = select_gedcom_file()

if gedcom_file_path:
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    # Apply manual CSV filter
    gedcom_instance.apply_csv_filter("/content/filtered_ids.csv")  # Replace with your actual CSV file path

    # Apply NPFX filter
    gedcom_instance.apply_npfx_filter()

    # Initialize the list of individuals
    individuals = []

    # Reading the GEDCOM file and parsing records
    with open(gedcom_file_path, 'r') as file:
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

    # Create the filtered_records dictionary after self.records has been populated
    filtered_records = {dataset.get_gen_person(): records.get(dataset.get_gen_person(), "") for dataset in gedcom_instance.records.values()}

    # Initialize the list of individuals
    individuals = []


def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]
    if famc_id not in records:
        return

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)


def get_formatted_name(male_individual_id, female_individual_id, records):
    male_record = records.get(male_individual_id, "")
    female_record = records.get(female_individual_id, "")

    male_name = extract_name(male_record)
    female_name = extract_name(female_record)

    if male_name is None or female_name is None:
        print(f"Could not extract name for either male ID: {male_individual_id} or female ID: {female_individual_id}")
        return None  # or return a default value

    return male_name + "&" + female_name


most_distant_ancestors = []  # New list to collect most distant ancestors

# This function now expects records to be a dictionary where each key is a unique identifier,
# and each value is an instance of the GedcomDataset class.
def find_distant_ancestors(individual_id, records, path=None, spouses=None, most_distant_ancestors=None):
#    print(f"Searching for distant ancestors of {individual_id}")

    if path is None:
        path = [individual_id]

    if spouses is None:
        spouses = {}

    if most_distant_ancestors is None:
        most_distant_ancestors = []

    record = records.get(individual_id, None)
#    print(f"256-Type of record: {type(record)}, Content: {record}")

    if not record:
        print(f"Record not found for {individual_id}")
        return [], spouses, most_distant_ancestors

    paths = []
    famc_id = extract_famc_id(record)

    if famc_id in records:
        mother_id, father_id = extract_parent_ids(records[famc_id])

        if father_id:
            father_name = father_id
            new_path = list(path) + [father_name]
            paths.extend(find_distant_ancestors(father_id, records, new_path, spouses, most_distant_ancestors)[0])

        if mother_id:
            mother_name = mother_id
            new_path = list(path) + [mother_name]
            paths.extend(find_distant_ancestors(mother_id, records, new_path, spouses, most_distant_ancestors)[0])

    return paths, spouses, most_distant_ancestors


def extract_famc_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()


def extract_fams_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMS()


def extract_parent_ids(gedcom_dataset_instance):
    mother_id = gedcom_dataset_instance.get_extractable_WIFE()
    father_id = gedcom_dataset_instance.get_extractable_HUSB()
    return mother_id, father_id



    return paths, spouses, most_distant_ancestors

    record = gedcom_instance.records.get(individual_id, "")
    print(f"299-Type of record: {type(record)}, Content: {record}")


def extract_famc_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_fam_id(gedcom_dataset_instance):
    return gedcom_dataset_instance.get_extractable_FAMC()

def extract_parent_ids(fam_record):
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    return mother_id, father_id

def extract_spouse_id(fam_record, individual_record):
    if '1 HUSB @' in individual_record:
        spouse_start = fam_record.find('1 WIFE @') + 8
    else:
        spouse_start = fam_record.find('1 HUSB @') + 8
    spouse_end = fam_record.find('@', spouse_start)
    return fam_record[spouse_start:spouse_end]

# Loop through the filtered IDs.
for individual_id in gedcom_instance.records.keys():
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(
        individual_id, gedcom_instance.records
    )
    print(f"Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")


individual_and_spouse = {}  # Create a dictionary to track individual and their spouse.

# Instead of using individual_id_to_search, loop through the filtered IDs.
for individual_id in gedcom_instance.records.keys():
    distant_ancestors_paths, spouses, most_distant_ancestors = find_distant_ancestors(individual_id, gedcom_instance.records)
#    print(f"352-Distant Ancestors Paths for {individual_id}: {distant_ancestors_paths}")
    print(f"Most Distant Ancestors for {individual_id}: {most_distant_ancestors}")

indexed_paths = {i: path for i, path in enumerate(distant_ancestors_paths)}

# Assuming `spouses` is a dictionary where the key is the individual ID and the value is the spouse ID
spouses = {}  # Populate this based on your function that finds distant ancestors

name_paths = []

for path in distant_ancestors_paths:
    name_path_with_spouse = []
    for id in path:  # This should be a single ID, not a list
        individual_name = extract_name(records.get(id, ''))
        spouse_id = spouses.get(id, None)
        spouse_name = extract_name(records.get(spouse_id, '')) if spouse_id else "unknown"
        name_path_with_spouse.append(f"{individual_name}&{spouse_name}")
    name_paths.append(name_path_with_spouse)

for idx, name_path in enumerate(name_paths):  # Check for the surname 'Yates' in the paths
    has_yates = any("Yates" in name for name in name_path)
    if has_yates:
        print(f"Path index: {idx}, Contains Yates: {has_yates}, Names: {name_path}")

path_scores = {}  # Initialize an empty dictionary to store the scores of each path

for idx, name_path in enumerate(name_paths): # Loop through the paths and apply the scoring scheme
    score = 0
    for generation, name in enumerate(name_path):
        if 'Yates' in name:
            score += 1 * (generation + 1)  # Add 1 to generation because index starts at 0
    path_scores[idx] = score     # Store the score of this path

# Find the index of the path with the highest score
#winning_path_index = max(path_scores, key=path_scores.get)
#winning_path_score = path_scores[winning_path_index]
#winning_path_names = name_paths[winning_path_index]

# Print the winning path to the console
#print(f"High Branch score was {winning_path_score}.")    #The winning path is at index {winning_path_index}
#print(f"Names in the winning path: {winning_path_names}")

#winning_path_names.reverse() # Reversing the list for highest generation first

# Adding spouses (Replace 'unknown' with actual spouse names if you have them)
#spouse_names = ['unknown'] * len(winning_path_names)  # Replace with real names or keep as 'unknown'

# Combine names and spouses in your specified format
formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)]

final_output = "|".join(formatted_names)# Join all the formatted names with '|'

print("Selected DNA Branch:", final_output)

visited_pairs = set()

def process_individual(individual_id, gedcom_instance):
    global generation_table
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    global visited_pairs
    visited_pairs = set()

    find_parents(individual_id, 1, records)

    for dataset in gedcom_instance.filter_pool:     # Concatenate the value of the anchor_gen1 attribute to the beginning of the generation table
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    generation_table = generation_table.sort_values('Generation', ascending=False).reset_index(drop=True)

    individual_data = {}
    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            individual_data['cM'] = dataset.get_extractable_cm()
            individual_data['Sort'] = dataset.get_extractable_sort()
            break

    individual_data['Parent Pairs A10'] = '|'.join([f"{row['Parent Pair']}" for index, row in generation_table[:10].iterrows()])

    print(f"Returning data for {individual_id}: {individual_data}")  # Debug print
    return individual_data

import pandas as pd

# Global variables
generation_table = None
visited_pairs = set()

# Run the process_individual function for each individual in the filtered_individuals list and create a combined DataFrame
combined_df_rows = []
for name, individual_id in filtered_individuals:
    individual_data = process_individual(individual_id, gedcom_instance)
    print("Debugging individual_data:", individual_data)  # This will print out the contents
    cm = individual_data.get('cM', 'Default Value')  # This will prevent KeyError
    sort = individual_data.get('Sort', 'Default Sort')
    parent_pairs_a10 = individual_data.get('Parent Pairs A10', 'Default Parent Pairs A10')
#    most_distant_ancestor = generation_table.iloc[0]['Parent Pair']  # Get the most distant ancestor from the last row of generation_table
    combined_df_rows.append([individual_id, name, sort, cm, parent_pairs_a10]) #, most_distant_ancestor

combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Name', 'Match to', 'cM', 'Ancestral Line A10'])

def create_hotlink(row):# Function to create hotlinks
    url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
    person_id = row['ID#']
    hotlink = f'<a href="{url_base}{person_id}&tree=tree1&parentset=0&display=vertical&generations=8" target="_blank">{person_id}</a>'
    return hotlink

combined_df['LUN#'] = combined_df.apply(lambda row: create_hotlink(row), axis=1) # Apply the hotlink function to create the 'LUN#' column
# Change the order of the columns
combined_df = combined_df[['ID#', 'Name', 'Match to', 'cM', 'LUN#', 'Ancestral Line A10']] # 'Most Distant Ancestor',
# Adjust index to start from 1 instead of 0
combined_df.index = combined_df.index + 1
# Print all records from the DataFrame
print(combined_df)
# Export the combined_df DataFrame to an Excel file
combined_df.to_excel('/content/output.xlsx', index=False)
# Out:
# Streaming output truncated to the last 5000 lines.
# Most Distant Ancestors for @I45777@: []
# Most Distant Ancestors for @I45778@: []
# Most Distant Ancestors for @I45779@: []
# Most Distant Ancestors for @I45780@: []
# Most Distant Ancestors for @I45781@: []
# Most Distant Ancestors for @I45782@: []
# Most Distant Ancestors for @I45783@: []
# Most Distant Ancestors for @I45784@: []
# Most Distant Ancestors for @I45785@: []
# Most Distant Ancestors for @I45786@: []
# Most Distant Ancestors for @I45787@: []
# Most Distant Ancestors for @I45788@: []
# Most Distant Ancestors for @I45789@: []
# Most Distant Ancestors for @I45790@: []
# Most Distant Ancestors for @I45791@: []
# Most Distant Ancestors for @I45792@: []
# Most Distant Ancestors for @I45793@: []
# Most Distant Ancestors for @I45794@: []
# Most Distant Ancestors for @I45795@: []
# Most Distant Ancestors for @I45796@: []
# Most Distant Ancestors for @I45797@: []
# Most Distant Ancestors for @I45798@: []
# Most Distant Ancestors for @I45799@: []
# Most Distant Ancestors for @I45800@: []
# Most Distant Ancestors for @I45801@: []
# Most Distant Ancestors for @I45802@: []
# Most Distant Ancestors for @I45803@: []
# Most Distant Ancestors for @I45804@: []
# Most Distant Ancestors for @I45805@: []
# Most Distant Ancestors for @I45806@: []
# Most Distant Ancestors for @I45807@: []
# Most Distant Ancestors for @I45808@: []
# Most Distant Ancestors for @I45809@: []
# Most Distant Ancestors for @I45810@: []
# Most Distant Ancestors for @I45811@: []
# Most Distant Ancestors for @I45812@: []
# Most Distant Ancestors for @I45813@: []
# Most Distant Ancestors for @I45814@: []
# Most Distant Ancestors for @I45815@: []
# Most Distant Ancestors for @I45816@: []
# Most Distant Ancestors for @I45817@: []
# Most Distant Ancestors for @I45818@: []
# Most Distant Ancestors for @I45819@: []
# Most Distant Ancestors for @I45820@: []
# Most Distant Ancestors for @I45821@: []
# Most Distant Ancestors for @I45822@: []
# Most Distant Ancestors for @I45823@: []
# Most Distant Ancestors for @I45824@: []
# Most Distant Ancestors for @I45825@: []
# Most Distant Ancestors for @I45826@: []
# Most Distant Ancestors for @I45827@: []
# Most Distant Ancestors for @I45828@: []
# Most Distant Ancestors for @I45829@: []
# Most Distant Ancestors for @I45830@: []
# Most Distant Ancestors for @I45831@: []
# Most Distant Ancestors for @I45832@: []
# Most Distant Ancestors for @I45833@: []
# Most Distant Ancestors for @I45834@: []
# Most Distant Ancestors for @I45835@: []
# Most Distant Ancestors for @I45836@: []
# Most Distant Ancestors for @I45837@: []
# Most Distant Ancestors for @I45838@: []
# Most Distant Ancestors for @I45839@: []
# Most Distant Ancestors for @I45840@: []
# Most Distant Ancestors for @I45841@: []
# Most Distant Ancestors for @I45842@: []
# Most Distant Ancestors for @I45843@: []
# Most Distant Ancestors for @I45844@: []
# Most Distant Ancestors for @I45845@: []
# Most Distant Ancestors for @I45846@: []
# Most Distant Ancestors for @I45847@: []
# Most Distant Ancestors for @I45848@: []
# Most Distant Ancestors for @I45849@: []
# Most Distant Ancestors for @I45850@: []
# Most Distant Ancestors for @I45851@: []
# Most Distant Ancestors for @I45852@: []
# Most Distant Ancestors for @I45853@: []
# Most Distant Ancestors for @I45854@: []
# Most Distant Ancestors for @I45855@: []
# Most Distant Ancestors for @I45856@: []
# Most Distant Ancestors for @I45857@: []
# Most Distant Ancestors for @I45858@: []
# Most Distant Ancestors for @I45859@: []
# Most Distant Ancestors for @I45860@: []
# Most Distant Ancestors for @I45861@: []
# Most Distant Ancestors for @I45862@: []
# Most Distant Ancestors for @I45863@: []
# Most Distant Ancestors for @I45864@: []
# Most Distant Ancestors for @I45865@: []
# Most Distant Ancestors for @I45866@: []
# Most Distant Ancestors for @I45867@: []
# Most Distant Ancestors for @I45868@: []
# Most Distant Ancestors for @I45869@: []
# Most Distant Ancestors for @I45870@: []
# Most Distant Ancestors for @I45871@: []
# Most Distant Ancestors for @I45872@: []
# Most Distant Ancestors for @I45873@: []
# Most Distant Ancestors for @I45874@: []
# Most Distant Ancestors for @I45875@: []
# Most Distant Ancestors for @I45876@: []
# Most Distant Ancestors for @I45877@: []
# Most Distant Ancestors for @I45878@: []
# Most Distant Ancestors for @I45879@: []
# Most Distant Ancestors for @I45880@: []
# Most Distant Ancestors for @I45881@: []
# Most Distant Ancestors for @I45882@: []
# Most Distant Ancestors for @I45883@: []
# Most Distant Ancestors for @I45884@: []
# Most Distant Ancestors for @I45885@: []
# Most Distant Ancestors for @I45886@: []
# Most Distant Ancestors for @I45887@: []
# Most Distant Ancestors for @I45888@: []
# Most Distant Ancestors for @I45889@: []
# Most Distant Ancestors for @I45890@: []
# Most Distant Ancestors for @I45891@: []
# Most Distant Ancestors for @I45892@: []
# Most Distant Ancestors for @I45893@: []
# Most Distant Ancestors for @I45894@: []
# Most Distant Ancestors for @I45895@: []
# Most Distant Ancestors for @I45896@: []
# Most Distant Ancestors for @I45897@: []
# Most Distant Ancestors for @I45898@: []
# Most Distant Ancestors for @I45899@: []
# Most Distant Ancestors for @I45900@: []
# Most Distant Ancestors for @I45901@: []
# Most Distant Ancestors for @I45902@: []
# Most Distant Ancestors for @I45903@: []
# Most Distant Ancestors for @I45904@: []
# Most Distant Ancestors for @I45905@: []
# Most Distant Ancestors for @I45906@: []
# Most Distant Ancestors for @I45907@: []
# Most Distant Ancestors for @I45908@: []
# Most Distant Ancestors for @I45909@: []
# Most Distant Ancestors for @I45910@: []
# Most Distant Ancestors for @I45911@: []
# Most Distant Ancestors for @I45912@: []
# Most Distant Ancestors for @I45913@: []
# Most Distant Ancestors for @I45914@: []
# Most Distant Ancestors for @I45915@: []
# Most Distant Ancestors for @I45916@: []
# Most Distant Ancestors for @I45917@: []
# Most Distant Ancestors for @I45918@: []
# Most Distant Ancestors for @I45919@: []
# Most Distant Ancestors for @I45920@: []
# Most Distant Ancestors for @I45921@: []
# Most Distant Ancestors for @I45922@: []
# Most Distant Ancestors for @I45923@: []
# Most Distant Ancestors for @I45924@: []
# Most Distant Ancestors for @I45925@: []
# Most Distant Ancestors for @I45926@: []
# Most Distant Ancestors for @I45927@: []
# Most Distant Ancestors for @I45928@: []
# Most Distant Ancestors for @I45929@: []
# Most Distant Ancestors for @I45930@: []
# Most Distant Ancestors for @I45931@: []
# Most Distant Ancestors for @I45932@: []
# Most Distant Ancestors for @I45933@: []
# Most Distant Ancestors for @I45934@: []
# Most Distant Ancestors for @I45935@: []
# Most Distant Ancestors for @I45936@: []
# Most Distant Ancestors for @I45937@: []
# Most Distant Ancestors for @I45938@: []
# Most Distant Ancestors for @I45939@: []
# Most Distant Ancestors for @I45940@: []
# Most Distant Ancestors for @I45941@: []
# Most Distant Ancestors for @I45942@: []
# Most Distant Ancestors for @I45943@: []
# Most Distant Ancestors for @I45944@: []
# Most Distant Ancestors for @I45945@: []
# Most Distant Ancestors for @I45946@: []
# Most Distant Ancestors for @I45947@: []
# Most Distant Ancestors for @I45948@: []
# Most Distant Ancestors for @I45949@: []
# Most Distant Ancestors for @I45950@: []
# Most Distant Ancestors for @I45951@: []
# Most Distant Ancestors for @I45952@: []
# Most Distant Ancestors for @I45953@: []
# Most Distant Ancestors for @I45954@: []
# Most Distant Ancestors for @I45955@: []
# Most Distant Ancestors for @I45956@: []
# Most Distant Ancestors for @I45957@: []
# Most Distant Ancestors for @I45958@: []
# Most Distant Ancestors for @I45959@: []
# Most Distant Ancestors for @I45960@: []
# Most Distant Ancestors for @I45961@: []
# Most Distant Ancestors for @I45962@: []
# Most Distant Ancestors for @I45963@: []
# Most Distant Ancestors for @I45964@: []
# Most Distant Ancestors for @I45965@: []
# Most Distant Ancestors for @I45966@: []
# Most Distant Ancestors for @I45967@: []
# Most Distant Ancestors for @I45968@: []
# Most Distant Ancestors for @I45969@: []
# Most Distant Ancestors for @I45970@: []
# Most Distant Ancestors for @I45971@: []
# Most Distant Ancestors for @I45972@: []
# Most Distant Ancestors for @I45973@: []
# Most Distant Ancestors for @I45974@: []
# Most Distant Ancestors for @I45975@: []
# Most Distant Ancestors for @I45976@: []
# Most Distant Ancestors for @I45977@: []
# Most Distant Ancestors for @I45978@: []
# Most Distant Ancestors for @I45979@: []
# Most Distant Ancestors for @I45980@: []
# Most Distant Ancestors for @I45981@: []
# Most Distant Ancestors for @I45982@: []
# Most Distant Ancestors for @I45983@: []
# Most Distant Ancestors for @I45984@: []
# Most Distant Ancestors for @I45985@: []
# Most Distant Ancestors for @I45986@: []
# Most Distant Ancestors for @I45987@: []
# Most Distant Ancestors for @I45988@: []
# Most Distant Ancestors for @I45989@: []
# Most Distant Ancestors for @I45990@: []
# Most Distant Ancestors for @I45991@: []
# Most Distant Ancestors for @I45992@: []
# Most Distant Ancestors for @I45993@: []
# Most Distant Ancestors for @I45994@: []
# Most Distant Ancestors for @I45995@: []
# Most Distant Ancestors for @I45996@: []
# Most Distant Ancestors for @I45997@: []
# Most Distant Ancestors for @I45998@: []
# Most Distant Ancestors for @I45999@: []
# Most Distant Ancestors for @I46000@: []
# Most Distant Ancestors for @I46001@: []
# Most Distant Ancestors for @I46002@: []
# Most Distant Ancestors for @I46003@: []
# Most Distant Ancestors for @I46004@: []
# Most Distant Ancestors for @I46005@: []
# Most Distant Ancestors for @I46006@: []
# Most Distant Ancestors for @I46007@: []
# Most Distant Ancestors for @I46008@: []
# Most Distant Ancestors for @I46009@: []
# Most Distant Ancestors for @I46010@: []
# Most Distant Ancestors for @I46011@: []
# Most Distant Ancestors for @I46012@: []
# Most Distant Ancestors for @I46013@: []
# Most Distant Ancestors for @I46014@: []
# Most Distant Ancestors for @I46015@: []
# Most Distant Ancestors for @I46016@: []
# Most Distant Ancestors for @I46017@: []
# Most Distant Ancestors for @I46018@: []
# Most Distant Ancestors for @I46019@: []
# Most Distant Ancestors for @I46020@: []
# Most Distant Ancestors for @I46021@: []
# Most Distant Ancestors for @I46022@: []
# Most Distant Ancestors for @I46023@: []
# Most Distant Ancestors for @I46024@: []
# Most Distant Ancestors for @I46025@: []
# Most Distant Ancestors for @I46026@: []
# Most Distant Ancestors for @I46027@: []
# Most Distant Ancestors for @I46028@: []
# Most Distant Ancestors for @I46029@: []
# Most Distant Ancestors for @I46030@: []
# Most Distant Ancestors for @I46031@: []
# Most Distant Ancestors for @I46032@: []
# Most Distant Ancestors for @I46033@: []
# Most Distant Ancestors for @I46034@: []
# Most Distant Ancestors for @I46035@: []
# Most Distant Ancestors for @I46036@: []
# Most Distant Ancestors for @I46037@: []
# Most Distant Ancestors for @I46038@: []
# Most Distant Ancestors for @I46039@: []
# Most Distant Ancestors for @I46040@: []
# Most Distant Ancestors for @I46041@: []
# Most Distant Ancestors for @I46042@: []
# Most Distant Ancestors for @I46043@: []
# Most Distant Ancestors for @I46044@: []
# Most Distant Ancestors for @I46045@: []
# Most Distant Ancestors for @I46046@: []
# Most Distant Ancestors for @I46047@: []
# Most Distant Ancestors for @I46048@: []
# Most Distant Ancestors for @I46049@: []
# Most Distant Ancestors for @I46050@: []
# Most Distant Ancestors for @I46051@: []
# Most Distant Ancestors for @I46052@: []
# Most Distant Ancestors for @I46053@: []
# Most Distant Ancestors for @I46054@: []
# Most Distant Ancestors for @I46055@: []
# Most Distant Ancestors for @I46056@: []
# Most Distant Ancestors for @I46057@: []
# Most Distant Ancestors for @I46058@: []
# Most Distant Ancestors for @I46059@: []
# Most Distant Ancestors for @I46060@: []
# Most Distant Ancestors for @I46061@: []
# Most Distant Ancestors for @I46062@: []
# Most Distant Ancestors for @I46063@: []
# Most Distant Ancestors for @I46064@: []
# Most Distant Ancestors for @I46065@: []
# Most Distant Ancestors for @I46066@: []
# Most Distant Ancestors for @I46067@: []
# Most Distant Ancestors for @I46068@: []
# Most Distant Ancestors for @I46069@: []
# Most Distant Ancestors for @I46070@: []
# Most Distant Ancestors for @I46071@: []
# Most Distant Ancestors for @I46072@: []
# Most Distant Ancestors for @I46073@: []
# Most Distant Ancestors for @I46074@: []
# Most Distant Ancestors for @I46075@: []
# Most Distant Ancestors for @I46076@: []
# Most Distant Ancestors for @I46077@: []
# Most Distant Ancestors for @I46078@: []
# Most Distant Ancestors for @I46079@: []
# Most Distant Ancestors for @I46080@: []
# Most Distant Ancestors for @I46081@: []
# Most Distant Ancestors for @I46082@: []
# Most Distant Ancestors for @I46083@: []
# Most Distant Ancestors for @I46084@: []
# Most Distant Ancestors for @I46085@: []
# Most Distant Ancestors for @I46086@: []
# Most Distant Ancestors for @I46087@: []
# Most Distant Ancestors for @I46088@: []
# Most Distant Ancestors for @I46089@: []
# Most Distant Ancestors for @I46090@: []
# Most Distant Ancestors for @I46091@: []
# Most Distant Ancestors for @I46092@: []
# Most Distant Ancestors for @I46093@: []
# Most Distant Ancestors for @I46094@: []
# Most Distant Ancestors for @I46095@: []
# Most Distant Ancestors for @I46096@: []
# Most Distant Ancestors for @I46097@: []
# Most Distant Ancestors for @I46098@: []
# Most Distant Ancestors for @I46099@: []
# Most Distant Ancestors for @I46100@: []
# Most Distant Ancestors for @I46101@: []
# Most Distant Ancestors for @I46102@: []
# Most Distant Ancestors for @I46103@: []
# Most Distant Ancestors for @I46104@: []
# Most Distant Ancestors for @I46105@: []
# Most Distant Ancestors for @I46106@: []
# Most Distant Ancestors for @I46107@: []
# Most Distant Ancestors for @I46108@: []
# Most Distant Ancestors for @I46109@: []
# Most Distant Ancestors for @I46110@: []
# Most Distant Ancestors for @I46111@: []
# Most Distant Ancestors for @I46112@: []
# Most Distant Ancestors for @I46113@: []
# Most Distant Ancestors for @I46114@: []
# Most Distant Ancestors for @I46115@: []
# Most Distant Ancestors for @I46116@: []
# Most Distant Ancestors for @I46117@: []
# Most Distant Ancestors for @I46118@: []
# Most Distant Ancestors for @I46119@: []
# Most Distant Ancestors for @I46120@: []
# Most Distant Ancestors for @I46121@: []
# Most Distant Ancestors for @I46122@: []
# Most Distant Ancestors for @I46123@: []
# Most Distant Ancestors for @I46124@: []
# Most Distant Ancestors for @I46125@: []
# Most Distant Ancestors for @I46126@: []
# Most Distant Ancestors for @I46127@: []
# Most Distant Ancestors for @I46128@: []
# Most Distant Ancestors for @I46129@: []
# Most Distant Ancestors for @I46130@: []
# Most Distant Ancestors for @I46131@: []
# Most Distant Ancestors for @I46132@: []
# Most Distant Ancestors for @I46133@: []
# Most Distant Ancestors for @I46134@: []
# Most Distant Ancestors for @I46135@: []
# Most Distant Ancestors for @I46136@: []
# Most Distant Ancestors for @I46137@: []
# Most Distant Ancestors for @I46138@: []
# Most Distant Ancestors for @I46139@: []
# Most Distant Ancestors for @I46140@: []
# Most Distant Ancestors for @I46141@: []
# Most Distant Ancestors for @I46142@: []
# Most Distant Ancestors for @I46143@: []
# Most Distant Ancestors for @I46144@: []
# Most Distant Ancestors for @I46145@: []
# Most Distant Ancestors for @I46146@: []
# Most Distant Ancestors for @I46147@: []
# Most Distant Ancestors for @I46148@: []
# Most Distant Ancestors for @I46149@: []
# Most Distant Ancestors for @I46150@: []
# Most Distant Ancestors for @I46151@: []
# Most Distant Ancestors for @I46152@: []
# Most Distant Ancestors for @I46153@: []
# Most Distant Ancestors for @I46154@: []
# Most Distant Ancestors for @I46155@: []
# Most Distant Ancestors for @I46156@: []
# Most Distant Ancestors for @I46157@: []
# Most Distant Ancestors for @I46158@: []
# Most Distant Ancestors for @I46159@: []
# Most Distant Ancestors for @I46160@: []
# Most Distant Ancestors for @I46161@: []
# Most Distant Ancestors for @I46162@: []
# Most Distant Ancestors for @I46163@: []
# Most Distant Ancestors for @I46164@: []
# Most Distant Ancestors for @I46165@: []
# Most Distant Ancestors for @I46166@: []
# Most Distant Ancestors for @I46167@: []
# Most Distant Ancestors for @I46168@: []
# Most Distant Ancestors for @I46169@: []
# Most Distant Ancestors for @I46170@: []
# Most Distant Ancestors for @I46171@: []
# Most Distant Ancestors for @I46172@: []
# Most Distant Ancestors for @I46173@: []
# Most Distant Ancestors for @I46174@: []
# Most Distant Ancestors for @I46175@: []
# Most Distant Ancestors for @I46176@: []
# Most Distant Ancestors for @I46177@: []
# Most Distant Ancestors for @I46178@: []
# Most Distant Ancestors for @I46179@: []
# Most Distant Ancestors for @I46180@: []
# Most Distant Ancestors for @I46181@: []
# Most Distant Ancestors for @I46182@: []
# Most Distant Ancestors for @I46183@: []
# Most Distant Ancestors for @I46184@: []
# Most Distant Ancestors for @I46185@: []
# Most Distant Ancestors for @I46186@: []
# Most Distant Ancestors for @I46187@: []
# Most Distant Ancestors for @I46188@: []
# Most Distant Ancestors for @I46189@: []
# Most Distant Ancestors for @I46190@: []
# Most Distant Ancestors for @I46191@: []
# Most Distant Ancestors for @I46192@: []
# Most Distant Ancestors for @I46193@: []
# Most Distant Ancestors for @I46194@: []
# Most Distant Ancestors for @I46195@: []
# Most Distant Ancestors for @I46196@: []
# Most Distant Ancestors for @I46197@: []
# Most Distant Ancestors for @I46198@: []
# Most Distant Ancestors for @I46199@: []
# Most Distant Ancestors for @I46200@: []
# Most Distant Ancestors for @I46201@: []
# Most Distant Ancestors for @I46202@: []
# Most Distant Ancestors for @I46203@: []
# Most Distant Ancestors for @I46204@: []
# Most Distant Ancestors for @I46205@: []
# Most Distant Ancestors for @I46206@: []
# Most Distant Ancestors for @I46207@: []
# Most Distant Ancestors for @I46208@: []
# Most Distant Ancestors for @I46209@: []
# Most Distant Ancestors for @I46210@: []
# Most Distant Ancestors for @I46211@: []
# Most Distant Ancestors for @I46212@: []
# Most Distant Ancestors for @I46213@: []
# Most Distant Ancestors for @I46214@: []
# Most Distant Ancestors for @I46215@: []
# Most Distant Ancestors for @I46216@: []
# Most Distant Ancestors for @I46217@: []
# Most Distant Ancestors for @I46218@: []
# Most Distant Ancestors for @I46219@: []
# Most Distant Ancestors for @I46220@: []
# Most Distant Ancestors for @I46221@: []
# Most Distant Ancestors for @I46222@: []
# Most Distant Ancestors for @I46223@: []
# Most Distant Ancestors for @I46224@: []
# Most Distant Ancestors for @I46225@: []
# Most Distant Ancestors for @I46226@: []
# Most Distant Ancestors for @I46227@: []
# Most Distant Ancestors for @I46228@: []
# Most Distant Ancestors for @I46229@: []
# Most Distant Ancestors for @I46230@: []
# Most Distant Ancestors for @I46231@: []
# Most Distant Ancestors for @I46232@: []
# Most Distant Ancestors for @I46233@: []
# Most Distant Ancestors for @I46234@: []
# Most Distant Ancestors for @I46235@: []
# Most Distant Ancestors for @I46236@: []
# Most Distant Ancestors for @I46237@: []
# Most Distant Ancestors for @I46238@: []
# Most Distant Ancestors for @I46239@: []
# Most Distant Ancestors for @I46240@: []
# Most Distant Ancestors for @I46241@: []
# Most Distant Ancestors for @I46242@: []
# Most Distant Ancestors for @I46243@: []
# Most Distant Ancestors for @I46244@: []
# Most Distant Ancestors for @I46245@: []
# Most Distant Ancestors for @I46246@: []
# Most Distant Ancestors for @I46247@: []
# Most Distant Ancestors for @I46248@: []
# Most Distant Ancestors for @I46249@: []
# Most Distant Ancestors for @I46250@: []
# Most Distant Ancestors for @I46251@: []
# Most Distant Ancestors for @I46252@: []
# Most Distant Ancestors for @I46253@: []
# Most Distant Ancestors for @I46254@: []
# Most Distant Ancestors for @I46255@: []
# Most Distant Ancestors for @I46256@: []
# Most Distant Ancestors for @I46257@: []
# Most Distant Ancestors for @I46258@: []
# Most Distant Ancestors for @I46259@: []
# Most Distant Ancestors for @I46260@: []
# Most Distant Ancestors for @I46261@: []
# Most Distant Ancestors for @I46262@: []
# Most Distant Ancestors for @I46263@: []
# Most Distant Ancestors for @I46264@: []
# Most Distant Ancestors for @I46265@: []
# Most Distant Ancestors for @I46266@: []
# Most Distant Ancestors for @I46267@: []
# Most Distant Ancestors for @I46268@: []
# Most Distant Ancestors for @I46269@: []
# Most Distant Ancestors for @I46270@: []
# Most Distant Ancestors for @I46271@: []
# Most Distant Ancestors for @I46272@: []
# Most Distant Ancestors for @I46273@: []
# Most Distant Ancestors for @I46274@: []
# Most Distant Ancestors for @I46275@: []
# Most Distant Ancestors for @I46276@: []
# Most Distant Ancestors for @I46277@: []
# Most Distant Ancestors for @I46278@: []
# Most Distant Ancestors for @I46279@: []
# Most Distant Ancestors for @I46280@: []
# Most Distant Ancestors for @I46281@: []
# Most Distant Ancestors for @I46282@: []
# Most Distant Ancestors for @I46283@: []
# Most Distant Ancestors for @I46284@: []
# Most Distant Ancestors for @I46285@: []
# Most Distant Ancestors for @I46286@: []
# Most Distant Ancestors for @I46287@: []
# Most Distant Ancestors for @I46288@: []
# Most Distant Ancestors for @I46289@: []
# Most Distant Ancestors for @I46290@: []
# Most Distant Ancestors for @I46291@: []
# Most Distant Ancestors for @I46292@: []
# Most Distant Ancestors for @I46293@: []
# Most Distant Ancestors for @I46294@: []
# Most Distant Ancestors for @I46295@: []
# Most Distant Ancestors for @I46296@: []
# Most Distant Ancestors for @I46297@: []
# Most Distant Ancestors for @I46298@: []
# Most Distant Ancestors for @I46299@: []
# Most Distant Ancestors for @I46300@: []
# Most Distant Ancestors for @I46301@: []
# Most Distant Ancestors for @I46302@: []
# Most Distant Ancestors for @I46303@: []
# Most Distant Ancestors for @I46304@: []
# Most Distant Ancestors for @I46305@: []
# Most Distant Ancestors for @I46306@: []
# Most Distant Ancestors for @I46307@: []
# Most Distant Ancestors for @I46308@: []
# Most Distant Ancestors for @I46309@: []
# Most Distant Ancestors for @I46310@: []
# Most Distant Ancestors for @I46311@: []
# Most Distant Ancestors for @I46312@: []
# Most Distant Ancestors for @I46313@: []
# Most Distant Ancestors for @I46314@: []
# Most Distant Ancestors for @I46315@: []
# Most Distant Ancestors for @I46316@: []
# Most Distant Ancestors for @I46317@: []
# Most Distant Ancestors for @I46318@: []
# Most Distant Ancestors for @I46319@: []
# Most Distant Ancestors for @I46320@: []
# Most Distant Ancestors for @I46321@: []
# Most Distant Ancestors for @I46322@: []
# Most Distant Ancestors for @I46323@: []
# Most Distant Ancestors for @I46324@: []
# Most Distant Ancestors for @I46325@: []
# Most Distant Ancestors for @I46326@: []
# Most Distant Ancestors for @I46327@: []
# Most Distant Ancestors for @I46328@: []
# Most Distant Ancestors for @I46329@: []
# Most Distant Ancestors for @I46330@: []
# Most Distant Ancestors for @I46331@: []
# Most Distant Ancestors for @I46332@: []
# Most Distant Ancestors for @I46333@: []
# Most Distant Ancestors for @I46334@: []
# Most Distant Ancestors for @I46335@: []
# Most Distant Ancestors for @I46336@: []
# Most Distant Ancestors for @I46337@: []
# Most Distant Ancestors for @I46338@: []
# Most Distant Ancestors for @I46339@: []
# Most Distant Ancestors for @I46340@: []
# Most Distant Ancestors for @I46341@: []
# Most Distant Ancestors for @I46342@: []
# Most Distant Ancestors for @I46343@: []
# Most Distant Ancestors for @I46344@: []
# Most Distant Ancestors for @I46345@: []
# Most Distant Ancestors for @I46346@: []
# Most Distant Ancestors for @I46347@: []
# Most Distant Ancestors for @I46348@: []
# Most Distant Ancestors for @I46349@: []
# Most Distant Ancestors for @I46350@: []
# Most Distant Ancestors for @I46351@: []
# Most Distant Ancestors for @I46352@: []
# Most Distant Ancestors for @I46353@: []
# Most Distant Ancestors for @I46354@: []
# Most Distant Ancestors for @I46355@: []
# Most Distant Ancestors for @I46356@: []
# Most Distant Ancestors for @I46357@: []
# Most Distant Ancestors for @I46358@: []
# Most Distant Ancestors for @I46359@: []
# Most Distant Ancestors for @I46360@: []
# Most Distant Ancestors for @I46361@: []
# Most Distant Ancestors for @I46362@: []
# Most Distant Ancestors for @I46363@: []
# Most Distant Ancestors for @I46364@: []
# Most Distant Ancestors for @I46365@: []
# Most Distant Ancestors for @I46366@: []
# Most Distant Ancestors for @I46367@: []
# Most Distant Ancestors for @I46368@: []
# Most Distant Ancestors for @I46369@: []
# Most Distant Ancestors for @I46370@: []
# Most Distant Ancestors for @I46371@: []
# Most Distant Ancestors for @I46372@: []
# Most Distant Ancestors for @I46373@: []
# Most Distant Ancestors for @I46374@: []
# Most Distant Ancestors for @I46375@: []
# Most Distant Ancestors for @I46376@: []
# Most Distant Ancestors for @I46377@: []
# Most Distant Ancestors for @I46378@: []
# Most Distant Ancestors for @I46379@: []
# Most Distant Ancestors for @I46380@: []
# Most Distant Ancestors for @I46381@: []
# Most Distant Ancestors for @I46382@: []
# Most Distant Ancestors for @I46383@: []
# Most Distant Ancestors for @I46384@: []
# Most Distant Ancestors for @I46385@: []
# Most Distant Ancestors for @I46386@: []
# Most Distant Ancestors for @I46387@: []
# Most Distant Ancestors for @I46388@: []
# Most Distant Ancestors for @I46389@: []
# Most Distant Ancestors for @I46390@: []
# Most Distant Ancestors for @I46391@: []
# Most Distant Ancestors for @I46392@: []
# Most Distant Ancestors for @I46393@: []
# Most Distant Ancestors for @I46394@: []
# Most Distant Ancestors for @I46395@: []
# Most Distant Ancestors for @I46396@: []
# Most Distant Ancestors for @I46397@: []
# Most Distant Ancestors for @I46398@: []
# Most Distant Ancestors for @I46399@: []
# Most Distant Ancestors for @I46400@: []
# Most Distant Ancestors for @I46401@: []
# Most Distant Ancestors for @I46402@: []
# Most Distant Ancestors for @I46403@: []
# Most Distant Ancestors for @I46404@: []
# Most Distant Ancestors for @I46405@: []
# Most Distant Ancestors for @I46406@: []
# Most Distant Ancestors for @I46407@: []
# Most Distant Ancestors for @I46408@: []
# Most Distant Ancestors for @I46409@: []
# Most Distant Ancestors for @I46410@: []
# Most Distant Ancestors for @I46411@: []
# Most Distant Ancestors for @I46412@: []
# Most Distant Ancestors for @I46413@: []
# Most Distant Ancestors for @I46414@: []
# Most Distant Ancestors for @I46415@: []
# Most Distant Ancestors for @I46416@: []
# Most Distant Ancestors for @I46417@: []
# Most Distant Ancestors for @I46418@: []
# Most Distant Ancestors for @I46419@: []
# Most Distant Ancestors for @I46420@: []
# Most Distant Ancestors for @I46421@: []
# Most Distant Ancestors for @I46422@: []
# Most Distant Ancestors for @I46423@: []
# Most Distant Ancestors for @I46424@: []
# Most Distant Ancestors for @I46425@: []
# Most Distant Ancestors for @I46426@: []
# Most Distant Ancestors for @I46427@: []
# Most Distant Ancestors for @I46428@: []
# Most Distant Ancestors for @I46429@: []
# Most Distant Ancestors for @I46430@: []
# Most Distant Ancestors for @I46431@: []
# Most Distant Ancestors for @I46432@: []
# Most Distant Ancestors for @I46433@: []
# Most Distant Ancestors for @I46434@: []
# Most Distant Ancestors for @I46435@: []
# Most Distant Ancestors for @I46436@: []
# Most Distant Ancestors for @I46437@: []
# Most Distant Ancestors for @I46438@: []
# Most Distant Ancestors for @I46439@: []
# Most Distant Ancestors for @I46440@: []
# Most Distant Ancestors for @I46441@: []
# Most Distant Ancestors for @I46442@: []
# Most Distant Ancestors for @I46443@: []
# Most Distant Ancestors for @I46444@: []
# Most Distant Ancestors for @I46445@: []
# Most Distant Ancestors for @I46446@: []
# Most Distant Ancestors for @I46447@: []
# Most Distant Ancestors for @I46448@: []
# Most Distant Ancestors for @I46449@: []
# Most Distant Ancestors for @I46450@: []
# Most Distant Ancestors for @I46451@: []
# Most Distant Ancestors for @I46452@: []
# Most Distant Ancestors for @I46453@: []
# Most Distant Ancestors for @I46454@: []
# Most Distant Ancestors for @I46455@: []
# Most Distant Ancestors for @I46456@: []
# Most Distant Ancestors for @I46457@: []
# Most Distant Ancestors for @I46458@: []
# Most Distant Ancestors for @I46459@: []
# Most Distant Ancestors for @I46460@: []
# Most Distant Ancestors for @I46461@: []
# Most Distant Ancestors for @I46462@: []
# Most Distant Ancestors for @I46463@: []
# Most Distant Ancestors for @I46464@: []
# Most Distant Ancestors for @I46465@: []
# Most Distant Ancestors for @I46466@: []
# Most Distant Ancestors for @I46467@: []
# Most Distant Ancestors for @I46468@: []
# Most Distant Ancestors for @I46469@: []
# Most Distant Ancestors for @I46470@: []
# Most Distant Ancestors for @I46471@: []
# Most Distant Ancestors for @I46472@: []
# Most Distant Ancestors for @I46473@: []
# Most Distant Ancestors for @I46474@: []
# Most Distant Ancestors for @I46475@: []
# Most Distant Ancestors for @I46476@: []
# Most Distant Ancestors for @I46477@: []
# Most Distant Ancestors for @I46478@: []
# Most Distant Ancestors for @I46479@: []
# Most Distant Ancestors for @I46480@: []
# Most Distant Ancestors for @I46481@: []
# Most Distant Ancestors for @I46482@: []
# Most Distant Ancestors for @I46483@: []
# Most Distant Ancestors for @I46484@: []
# Most Distant Ancestors for @I46485@: []
# Most Distant Ancestors for @I46486@: []
# Most Distant Ancestors for @I46487@: []
# Most Distant Ancestors for @I46488@: []
# Most Distant Ancestors for @I46489@: []
# Most Distant Ancestors for @I46490@: []
# Most Distant Ancestors for @I46491@: []
# Most Distant Ancestors for @I46492@: []
# Most Distant Ancestors for @I46493@: []
# Most Distant Ancestors for @I46494@: []
# Most Distant Ancestors for @I46495@: []
# Most Distant Ancestors for @I46496@: []
# Most Distant Ancestors for @I46497@: []
# Most Distant Ancestors for @I46498@: []
# Most Distant Ancestors for @I46499@: []
# Most Distant Ancestors for @I46500@: []
# Most Distant Ancestors for @I46501@: []
# Most Distant Ancestors for @I46502@: []
# Most Distant Ancestors for @I46503@: []
# Most Distant Ancestors for @I46504@: []
# Most Distant Ancestors for @I46505@: []
# Most Distant Ancestors for @I46506@: []
# Most Distant Ancestors for @I46507@: []
# Most Distant Ancestors for @I46508@: []
# Most Distant Ancestors for @I46509@: []
# Most Distant Ancestors for @I46510@: []
# Most Distant Ancestors for @I46511@: []
# Most Distant Ancestors for @I46512@: []
# Most Distant Ancestors for @I46513@: []
# Most Distant Ancestors for @I46514@: []
# Most Distant Ancestors for @I46515@: []
# Most Distant Ancestors for @I46516@: []
# Most Distant Ancestors for @I46517@: []
# Most Distant Ancestors for @I46518@: []
# Most Distant Ancestors for @I46519@: []
# Most Distant Ancestors for @I46520@: []
# Most Distant Ancestors for @I46521@: []
# Most Distant Ancestors for @I46522@: []
# Most Distant Ancestors for @I46523@: []
# Most Distant Ancestors for @I46524@: []
# Most Distant Ancestors for @I46525@: []
# Most Distant Ancestors for @I46526@: []
# Most Distant Ancestors for @I46527@: []
# Most Distant Ancestors for @I46528@: []
# Most Distant Ancestors for @I46529@: []
# Most Distant Ancestors for @I46530@: []
# Most Distant Ancestors for @I46531@: []
# Most Distant Ancestors for @I46532@: []
# Most Distant Ancestors for @I46533@: []
# Most Distant Ancestors for @I46534@: []
# Most Distant Ancestors for @I46535@: []
# Most Distant Ancestors for @I46536@: []
# Most Distant Ancestors for @I46537@: []
# Most Distant Ancestors for @I46538@: []
# Most Distant Ancestors for @I46539@: []
# Most Distant Ancestors for @I46540@: []
# Most Distant Ancestors for @I46541@: []
# Most Distant Ancestors for @I46542@: []
# Most Distant Ancestors for @I46543@: []
# Most Distant Ancestors for @I46544@: []
# Most Distant Ancestors for @I46545@: []
# Most Distant Ancestors for @I46546@: []
# Most Distant Ancestors for @I46547@: []
# Most Distant Ancestors for @I46548@: []
# Most Distant Ancestors for @I46549@: []
# Most Distant Ancestors for @I46550@: []
# Most Distant Ancestors for @I46551@: []
# Most Distant Ancestors for @I46552@: []
# Most Distant Ancestors for @I46553@: []
# Most Distant Ancestors for @I46554@: []
# Most Distant Ancestors for @I46555@: []
# Most Distant Ancestors for @I46556@: []
# Most Distant Ancestors for @I46557@: []
# Most Distant Ancestors for @I46558@: []
# Most Distant Ancestors for @I46559@: []
# Most Distant Ancestors for @I46560@: []
# Most Distant Ancestors for @I46561@: []
# Most Distant Ancestors for @I46562@: []
# Most Distant Ancestors for @I46563@: []
# Most Distant Ancestors for @I46564@: []
# Most Distant Ancestors for @I46565@: []
# Most Distant Ancestors for @I46566@: []
# Most Distant Ancestors for @I46567@: []
# Most Distant Ancestors for @I46568@: []
# Most Distant Ancestors for @I46569@: []
# Most Distant Ancestors for @I46570@: []
# Most Distant Ancestors for @I46571@: []
# Most Distant Ancestors for @I46572@: []
# Most Distant Ancestors for @I46573@: []
# Most Distant Ancestors for @I46574@: []
# Most Distant Ancestors for @I46575@: []
# Most Distant Ancestors for @I46576@: []
# Most Distant Ancestors for @I46577@: []
# Most Distant Ancestors for @I46578@: []
# Most Distant Ancestors for @I46579@: []
# Most Distant Ancestors for @I46580@: []
# Most Distant Ancestors for @I46581@: []
# Most Distant Ancestors for @I46582@: []
# Most Distant Ancestors for @I46583@: []
# Most Distant Ancestors for @I46584@: []
# Most Distant Ancestors for @I46585@: []
# Most Distant Ancestors for @I46586@: []
# Most Distant Ancestors for @I46587@: []
# Most Distant Ancestors for @I46588@: []
# Most Distant Ancestors for @I46589@: []
# Most Distant Ancestors for @I46590@: []
# Most Distant Ancestors for @I46591@: []
# Most Distant Ancestors for @I46592@: []
# Most Distant Ancestors for @I46593@: []
# Most Distant Ancestors for @I46594@: []
# Most Distant Ancestors for @I46595@: []
# Most Distant Ancestors for @I46596@: []
# Most Distant Ancestors for @I46597@: []
# Most Distant Ancestors for @I46598@: []
# Most Distant Ancestors for @I46599@: []
# Most Distant Ancestors for @I46600@: []
# Most Distant Ancestors for @I46601@: []
# Most Distant Ancestors for @I46602@: []
# Most Distant Ancestors for @I46603@: []
# Most Distant Ancestors for @I46604@: []
# Most Distant Ancestors for @I46605@: []
# Most Distant Ancestors for @I46606@: []
# Most Distant Ancestors for @I46607@: []
# Most Distant Ancestors for @I46608@: []
# Most Distant Ancestors for @I46609@: []
# Most Distant Ancestors for @I46610@: []
# Most Distant Ancestors for @I46611@: []
# Most Distant Ancestors for @I46612@: []
# Most Distant Ancestors for @I46613@: []
# Most Distant Ancestors for @I46614@: []
# Most Distant Ancestors for @I46615@: []
# Most Distant Ancestors for @I46616@: []
# Most Distant Ancestors for @I46617@: []
# Most Distant Ancestors for @I46618@: []
# Most Distant Ancestors for @I46619@: []
# Most Distant Ancestors for @I46620@: []
# Most Distant Ancestors for @I46621@: []
# Most Distant Ancestors for @I46622@: []
# Most Distant Ancestors for @I46623@: []
# Most Distant Ancestors for @I46624@: []
# Most Distant Ancestors for @I46625@: []
# Most Distant Ancestors for @I46626@: []
# Most Distant Ancestors for @I46627@: []
# Most Distant Ancestors for @I46628@: []
# Most Distant Ancestors for @I46629@: []
# Most Distant Ancestors for @I46630@: []
# Most Distant Ancestors for @I46631@: []
# Most Distant Ancestors for @I46632@: []
# Most Distant Ancestors for @I46633@: []
# Most Distant Ancestors for @I46634@: []
# Most Distant Ancestors for @I46635@: []
# Most Distant Ancestors for @I46636@: []
# Most Distant Ancestors for @I46637@: []
# Most Distant Ancestors for @I46638@: []
# Most Distant Ancestors for @I46639@: []
# Most Distant Ancestors for @I46640@: []
# Most Distant Ancestors for @I46641@: []
# Most Distant Ancestors for @I46642@: []
# Most Distant Ancestors for @I46643@: []
# Most Distant Ancestors for @I46644@: []
# Most Distant Ancestors for @I46645@: []
# Most Distant Ancestors for @I46646@: []
# Most Distant Ancestors for @I46647@: []
# Most Distant Ancestors for @I46648@: []
# Most Distant Ancestors for @I46649@: []
# Most Distant Ancestors for @I46650@: []
# Most Distant Ancestors for @I46651@: []
# Most Distant Ancestors for @I46652@: []
# Most Distant Ancestors for @I46653@: []
# Most Distant Ancestors for @I46654@: []
# Most Distant Ancestors for @I46655@: []
# Most Distant Ancestors for @I46656@: []
# Most Distant Ancestors for @I46657@: []
# Most Distant Ancestors for @I46658@: []
# Most Distant Ancestors for @I46659@: []
# Most Distant Ancestors for @I46660@: []
# Most Distant Ancestors for @I46661@: []
# Most Distant Ancestors for @I46662@: []
# Most Distant Ancestors for @I46663@: []
# Most Distant Ancestors for @I46664@: []
# Most Distant Ancestors for @I46665@: []
# Most Distant Ancestors for @I46666@: []
# Most Distant Ancestors for @I46667@: []
# Most Distant Ancestors for @I46668@: []
# Most Distant Ancestors for @I46669@: []
# Most Distant Ancestors for @I46670@: []
# Most Distant Ancestors for @I46671@: []
# Most Distant Ancestors for @I46672@: []
# Most Distant Ancestors for @I46673@: []
# Most Distant Ancestors for @I46674@: []
# Most Distant Ancestors for @I46675@: []
# Most Distant Ancestors for @I46676@: []
# Most Distant Ancestors for @I46677@: []
# Most Distant Ancestors for @I46678@: []
# Most Distant Ancestors for @I46679@: []
# Most Distant Ancestors for @I46680@: []
# Most Distant Ancestors for @I46681@: []
# Most Distant Ancestors for @I46682@: []
# Most Distant Ancestors for @I46683@: []
# Most Distant Ancestors for @I46684@: []
# Most Distant Ancestors for @I46685@: []
# Most Distant Ancestors for @I46686@: []
# Most Distant Ancestors for @I46687@: []
# Most Distant Ancestors for @I46688@: []
# Most Distant Ancestors for @I46689@: []
# Most Distant Ancestors for @I46690@: []
# Most Distant Ancestors for @I46691@: []
# Most Distant Ancestors for @I46692@: []
# Most Distant Ancestors for @I46693@: []
# Most Distant Ancestors for @I46694@: []
# Most Distant Ancestors for @I46695@: []
# Most Distant Ancestors for @I46696@: []
# Most Distant Ancestors for @I46697@: []
# Most Distant Ancestors for @I46698@: []
# Most Distant Ancestors for @I46699@: []
# Most Distant Ancestors for @I46700@: []
# Most Distant Ancestors for @I46701@: []
# Most Distant Ancestors for @I46702@: []
# Most Distant Ancestors for @I46703@: []
# Most Distant Ancestors for @I46704@: []
# Most Distant Ancestors for @I46705@: []
# Most Distant Ancestors for @I46706@: []
# Most Distant Ancestors for @I46707@: []
# Most Distant Ancestors for @I46708@: []
# Most Distant Ancestors for @I46709@: []
# Most Distant Ancestors for @I46710@: []
# Most Distant Ancestors for @I46711@: []
# Most Distant Ancestors for @I46712@: []
# Most Distant Ancestors for @I46713@: []
# Most Distant Ancestors for @I46714@: []
# Most Distant Ancestors for @I46715@: []
# Most Distant Ancestors for @I46716@: []
# Most Distant Ancestors for @I46717@: []
# Most Distant Ancestors for @I46718@: []
# Most Distant Ancestors for @I46719@: []
# Most Distant Ancestors for @I46720@: []
# Most Distant Ancestors for @I46721@: []
# Most Distant Ancestors for @I46722@: []
# Most Distant Ancestors for @I46723@: []
# Most Distant Ancestors for @I46724@: []
# Most Distant Ancestors for @I46725@: []
# Most Distant Ancestors for @I46726@: []
# Most Distant Ancestors for @I46727@: []
# Most Distant Ancestors for @I46728@: []
# Most Distant Ancestors for @I46729@: []
# Most Distant Ancestors for @I46730@: []
# Most Distant Ancestors for @I46731@: []
# Most Distant Ancestors for @I46732@: []
# Most Distant Ancestors for @I46733@: []
# Most Distant Ancestors for @I46734@: []
# Most Distant Ancestors for @I46735@: []
# Most Distant Ancestors for @I46736@: []
# Most Distant Ancestors for @I46737@: []
# Most Distant Ancestors for @I46738@: []
# Most Distant Ancestors for @I46739@: []
# Most Distant Ancestors for @I46740@: []
# Most Distant Ancestors for @I46741@: []
# Most Distant Ancestors for @I46742@: []
# Most Distant Ancestors for @I46743@: []
# Most Distant Ancestors for @I46744@: []
# Most Distant Ancestors for @I46745@: []
# Most Distant Ancestors for @I46746@: []
# Most Distant Ancestors for @I46747@: []
# Most Distant Ancestors for @I46748@: []
# Most Distant Ancestors for @I46749@: []
# Most Distant Ancestors for @I46750@: []
# Most Distant Ancestors for @I46751@: []
# Most Distant Ancestors for @I46752@: []
# Most Distant Ancestors for @I46753@: []
# Most Distant Ancestors for @I46754@: []
# Most Distant Ancestors for @I46755@: []
# Most Distant Ancestors for @I46756@: []
# Most Distant Ancestors for @I46757@: []
# Most Distant Ancestors for @I46758@: []
# Most Distant Ancestors for @I46759@: []
# Most Distant Ancestors for @I46760@: []
# Most Distant Ancestors for @I46761@: []
# Most Distant Ancestors for @I46762@: []
# Most Distant Ancestors for @I46763@: []
# Most Distant Ancestors for @I46764@: []
# Most Distant Ancestors for @I46765@: []
# Most Distant Ancestors for @I46766@: []
# Most Distant Ancestors for @I46767@: []
# Most Distant Ancestors for @I46768@: []
# Most Distant Ancestors for @I46769@: []
# Most Distant Ancestors for @I46770@: []
# Most Distant Ancestors for @I46771@: []
# Most Distant Ancestors for @I46772@: []
# Most Distant Ancestors for @I46773@: []
# Most Distant Ancestors for @I46774@: []
# Most Distant Ancestors for @I46775@: []
# Most Distant Ancestors for @I46776@: []
# Most Distant Ancestors for @I46777@: []
# Most Distant Ancestors for @I46778@: []
# Most Distant Ancestors for @I46779@: []
# Most Distant Ancestors for @I46780@: []
# Most Distant Ancestors for @I46781@: []
# Most Distant Ancestors for @I46782@: []
# Most Distant Ancestors for @I46783@: []
# Most Distant Ancestors for @I46784@: []
# Most Distant Ancestors for @I46785@: []
# Most Distant Ancestors for @I46786@: []
# Most Distant Ancestors for @I46787@: []
# Most Distant Ancestors for @I46788@: []
# Most Distant Ancestors for @I46789@: []
# Most Distant Ancestors for @I46790@: []
# Most Distant Ancestors for @I46791@: []
# Most Distant Ancestors for @I46792@: []
# Most Distant Ancestors for @I46793@: []
# Most Distant Ancestors for @I46794@: []
# Most Distant Ancestors for @I46795@: []
# Most Distant Ancestors for @I46796@: []
# Most Distant Ancestors for @I46797@: []
# Most Distant Ancestors for @I46798@: []
# Most Distant Ancestors for @I46799@: []
# Most Distant Ancestors for @I46800@: []
# Most Distant Ancestors for @I46801@: []
# Most Distant Ancestors for @I46802@: []
# Most Distant Ancestors for @I46803@: []
# Most Distant Ancestors for @I46804@: []
# Most Distant Ancestors for @I46805@: []
# Most Distant Ancestors for @I46806@: []
# Most Distant Ancestors for @I46807@: []
# Most Distant Ancestors for @I46808@: []
# Most Distant Ancestors for @I46809@: []
# Most Distant Ancestors for @I46810@: []
# Most Distant Ancestors for @I46811@: []
# Most Distant Ancestors for @I46812@: []
# Most Distant Ancestors for @I46813@: []
# Most Distant Ancestors for @I46814@: []
# Most Distant Ancestors for @I46815@: []
# Most Distant Ancestors for @I46816@: []
# Most Distant Ancestors for @I46817@: []
# Most Distant Ancestors for @I46818@: []
# Most Distant Ancestors for @I46819@: []
# Most Distant Ancestors for @I46820@: []
# Most Distant Ancestors for @I46821@: []
# Most Distant Ancestors for @I46822@: []
# Most Distant Ancestors for @I46823@: []
# Most Distant Ancestors for @I46824@: []
# Most Distant Ancestors for @I46825@: []
# Most Distant Ancestors for @I46826@: []
# Most Distant Ancestors for @I46827@: []
# Most Distant Ancestors for @I46828@: []
# Most Distant Ancestors for @I46829@: []
# Most Distant Ancestors for @I46830@: []
# Most Distant Ancestors for @I46831@: []
# Most Distant Ancestors for @I46832@: []
# Most Distant Ancestors for @I46833@: []
# Most Distant Ancestors for @I46834@: []
# Most Distant Ancestors for @I46835@: []
# Most Distant Ancestors for @I46836@: []
# Most Distant Ancestors for @I46837@: []
# Most Distant Ancestors for @I46838@: []
# Most Distant Ancestors for @I46839@: []
# Most Distant Ancestors for @I46840@: []
# Most Distant Ancestors for @I46841@: []
# Most Distant Ancestors for @I46842@: []
# Most Distant Ancestors for @I46843@: []
# Most Distant Ancestors for @I46844@: []
# Most Distant Ancestors for @I46845@: []
# Most Distant Ancestors for @I46846@: []
# Most Distant Ancestors for @I46847@: []
# Most Distant Ancestors for @I46848@: []
# Most Distant Ancestors for @I46849@: []
# Most Distant Ancestors for @I46850@: []
# Most Distant Ancestors for @I46851@: []
# Most Distant Ancestors for @I46852@: []
# Most Distant Ancestors for @I46853@: []
# Most Distant Ancestors for @I46854@: []
# Most Distant Ancestors for @I46855@: []
# Most Distant Ancestors for @I46856@: []
# Most Distant Ancestors for @I46857@: []
# Most Distant Ancestors for @I46858@: []
# Most Distant Ancestors for @I46859@: []
# Most Distant Ancestors for @I46860@: []
# Most Distant Ancestors for @I46861@: []
# Most Distant Ancestors for @I46862@: []
# Most Distant Ancestors for @I46863@: []
# Most Distant Ancestors for @I46864@: []
# Most Distant Ancestors for @I46865@: []
# Most Distant Ancestors for @I46866@: []
# Most Distant Ancestors for @I46867@: []
# Most Distant Ancestors for @I46868@: []
# Most Distant Ancestors for @I46869@: []
# Most Distant Ancestors for @I46870@: []
# Most Distant Ancestors for @I46871@: []
# Most Distant Ancestors for @I46872@: []
# Most Distant Ancestors for @I46873@: []
# Most Distant Ancestors for @I46874@: []
# Most Distant Ancestors for @I46875@: []
# Most Distant Ancestors for @I46876@: []
# Most Distant Ancestors for @I46877@: []
# Most Distant Ancestors for @I46878@: []
# Most Distant Ancestors for @I46879@: []
# Most Distant Ancestors for @I46880@: []
# Most Distant Ancestors for @I46881@: []
# Most Distant Ancestors for @I46882@: []
# Most Distant Ancestors for @I46883@: []
# Most Distant Ancestors for @I46884@: []
# Most Distant Ancestors for @I46885@: []
# Most Distant Ancestors for @I46886@: []
# Most Distant Ancestors for @I46887@: []
# Most Distant Ancestors for @I46888@: []
# Most Distant Ancestors for @I46889@: []
# Most Distant Ancestors for @I46890@: []
# Most Distant Ancestors for @I46891@: []
# Most Distant Ancestors for @I46892@: []
# Most Distant Ancestors for @I46893@: []
# Most Distant Ancestors for @I46894@: []
# Most Distant Ancestors for @I46895@: []
# Most Distant Ancestors for @I46896@: []
# Most Distant Ancestors for @I46897@: []
# Most Distant Ancestors for @I46898@: []
# Most Distant Ancestors for @I46899@: []
# Most Distant Ancestors for @I46900@: []
# Most Distant Ancestors for @I46901@: []
# Most Distant Ancestors for @I46902@: []
# Most Distant Ancestors for @I46903@: []
# Most Distant Ancestors for @I46904@: []
# Most Distant Ancestors for @I46905@: []
# Most Distant Ancestors for @I46906@: []
# Most Distant Ancestors for @I46907@: []
# Most Distant Ancestors for @I46908@: []
# Most Distant Ancestors for @I46909@: []
# Most Distant Ancestors for @I46910@: []
# Most Distant Ancestors for @I46911@: []
# Most Distant Ancestors for @I46912@: []
# Most Distant Ancestors for @I46913@: []
# Most Distant Ancestors for @I46914@: []
# Most Distant Ancestors for @I46915@: []
# Most Distant Ancestors for @I46916@: []
# Most Distant Ancestors for @I46917@: []
# Most Distant Ancestors for @I46918@: []
# Most Distant Ancestors for @I46919@: []
# Most Distant Ancestors for @I46920@: []
# Most Distant Ancestors for @I46921@: []
# Most Distant Ancestors for @I46922@: []
# Most Distant Ancestors for @I46923@: []
# Most Distant Ancestors for @I46924@: []
# Most Distant Ancestors for @I46925@: []
# Most Distant Ancestors for @I46926@: []
# Most Distant Ancestors for @I46927@: []
# Most Distant Ancestors for @I46928@: []
# Most Distant Ancestors for @I46929@: []
# Most Distant Ancestors for @I46930@: []
# Most Distant Ancestors for @I46931@: []
# Most Distant Ancestors for @I46932@: []
# Most Distant Ancestors for @I46933@: []
# Most Distant Ancestors for @I46934@: []
# Most Distant Ancestors for @I46935@: []
# Most Distant Ancestors for @I46936@: []
# Most Distant Ancestors for @I46937@: []
# Most Distant Ancestors for @I46938@: []
# Most Distant Ancestors for @I46939@: []
# Most Distant Ancestors for @I46940@: []
# Most Distant Ancestors for @I46941@: []
# Most Distant Ancestors for @I46942@: []
# Most Distant Ancestors for @I46943@: []
# Most Distant Ancestors for @I46944@: []
# Most Distant Ancestors for @I46945@: []
# Most Distant Ancestors for @I46946@: []
# Most Distant Ancestors for @I46947@: []
# Most Distant Ancestors for @I46948@: []
# Most Distant Ancestors for @I46949@: []
# Most Distant Ancestors for @I46950@: []
# Most Distant Ancestors for @I46951@: []
# Most Distant Ancestors for @I46952@: []
# Most Distant Ancestors for @I46953@: []
# Most Distant Ancestors for @I46954@: []
# Most Distant Ancestors for @I46955@: []
# Most Distant Ancestors for @I46956@: []
# Most Distant Ancestors for @I46957@: []
# Most Distant Ancestors for @I46958@: []
# Most Distant Ancestors for @I46959@: []
# Most Distant Ancestors for @I46960@: []
# Most Distant Ancestors for @I46961@: []
# Most Distant Ancestors for @I46962@: []
# Most Distant Ancestors for @I46963@: []
# Most Distant Ancestors for @I46964@: []
# Most Distant Ancestors for @I46965@: []
# Most Distant Ancestors for @I46966@: []
# Most Distant Ancestors for @I46967@: []
# Most Distant Ancestors for @I46968@: []
# Most Distant Ancestors for @I46969@: []
# Most Distant Ancestors for @I46970@: []
# Most Distant Ancestors for @I46971@: []
# Most Distant Ancestors for @I46972@: []
# Most Distant Ancestors for @I46973@: []
# Most Distant Ancestors for @I46974@: []
# ...
# Most Distant Ancestors for @I50391@: []
# Most Distant Ancestors for @I50392@: []
# Most Distant Ancestors for @I50393@: []
# Most Distant Ancestors for @I50394@: []
# Most Distant Ancestors for @I50395@: []
# Most Distant Ancestors for @I50396@: []
# Most Distant Ancestors for @I50397@: []
# Most Distant Ancestors for @I50398@: []
# Most Distant Ancestors for @I50399@: []
# Most Distant Ancestors for @I50400@: []
# Most Distant Ancestors for @I50401@: []
# Most Distant Ancestors for @I50402@: []
# Most Distant Ancestors for @I50403@: []
# Most Distant Ancestors for @I50404@: []
# Most Distant Ancestors for @I50405@: []
# Most Distant Ancestors for @I50406@: []
# Most Distant Ancestors for @I50407@: []
# Most Distant Ancestors for @I50408@: []
# Most Distant Ancestors for @I50409@: []
# Most Distant Ancestors for @I50410@: []
# Most Distant Ancestors for @I50411@: []
# Most Distant Ancestors for @I50412@: []
# Most Distant Ancestors for @I50413@: []
# Most Distant Ancestors for @I50414@: []
# Most Distant Ancestors for @I50415@: []
# Most Distant Ancestors for @I50416@: []
# Most Distant Ancestors for @I50417@: []
# Most Distant Ancestors for @I50418@: []
# Most Distant Ancestors for @I50419@: []
# Most Distant Ancestors for @I50420@: []
# Most Distant Ancestors for @I50421@: []
# Most Distant Ancestors for @I50422@: []
# Most Distant Ancestors for @I50423@: []
# Most Distant Ancestors for @I50424@: []
# Most Distant Ancestors for @I50425@: []
# Most Distant Ancestors for @I50426@: []
# Most Distant Ancestors for @I50427@: []
# Most Distant Ancestors for @I50428@: []
# Most Distant Ancestors for @I50429@: []
# Most Distant Ancestors for @I50430@: []
# Most Distant Ancestors for @I50431@: []
# Most Distant Ancestors for @I50432@: []
# Most Distant Ancestors for @I50433@: []
# Most Distant Ancestors for @I50434@: []
# Most Distant Ancestors for @I50435@: []
# Most Distant Ancestors for @I50436@: []
# Most Distant Ancestors for @I50437@: []
# Most Distant Ancestors for @I50438@: []
# Most Distant Ancestors for @I50439@: []
# Most Distant Ancestors for @I50440@: []
# Most Distant Ancestors for @I50441@: []
# Most Distant Ancestors for @I50442@: []
# Most Distant Ancestors for @I50443@: []
# Most Distant Ancestors for @I50444@: []
# Most Distant Ancestors for @I50445@: []
# Most Distant Ancestors for @I50446@: []
# Most Distant Ancestors for @I50447@: []
# Most Distant Ancestors for @I50448@: []
# Most Distant Ancestors for @I50449@: []
# Most Distant Ancestors for @I50450@: []
# Most Distant Ancestors for @I50451@: []
# Most Distant Ancestors for @I50452@: []
# Most Distant Ancestors for @I50453@: []
# Most Distant Ancestors for @I50454@: []
# Most Distant Ancestors for @I50455@: []
# Most Distant Ancestors for @I50456@: []
# Most Distant Ancestors for @I50457@: []
# Most Distant Ancestors for @I50458@: []
# Most Distant Ancestors for @I50459@: []
# Most Distant Ancestors for @I50460@: []
# Most Distant Ancestors for @I50461@: []
# Most Distant Ancestors for @I50462@: []
# Most Distant Ancestors for @I50463@: []
# Most Distant Ancestors for @I50464@: []
# Most Distant Ancestors for @I50465@: []
# Most Distant Ancestors for @I50466@: []
# Most Distant Ancestors for @I50467@: []
# Most Distant Ancestors for @I50468@: []
# Most Distant Ancestors for @I50469@: []
# Most Distant Ancestors for @I50470@: []
# Most Distant Ancestors for @I50471@: []
# Most Distant Ancestors for @I50472@: []
# Most Distant Ancestors for @I50473@: []
# Most Distant Ancestors for @I50474@: []
# Most Distant Ancestors for @I50475@: []
# Most Distant Ancestors for @I50476@: []
# Most Distant Ancestors for @I50477@: []
# Most Distant Ancestors for @I50478@: []
# Most Distant Ancestors for @I50479@: []
# Most Distant Ancestors for @I50480@: []
# Most Distant Ancestors for @I50481@: []
# Most Distant Ancestors for @I50482@: []
# Most Distant Ancestors for @I50483@: []
# Most Distant Ancestors for @I50484@: []
# Most Distant Ancestors for @I50485@: []
# Most Distant Ancestors for @I50486@: []
# Most Distant Ancestors for @I50487@: []
# Most Distant Ancestors for @I50488@: []
# Most Distant Ancestors for @I50489@: []
# Most Distant Ancestors for @I50490@: []
# Most Distant Ancestors for @I50491@: []
# Most Distant Ancestors for @I50492@: []
# Most Distant Ancestors for @I50493@: []
# Most Distant Ancestors for @I50494@: []
# Most Distant Ancestors for @I50495@: []
# Most Distant Ancestors for @I50496@: []
# Most Distant Ancestors for @I50497@: []
# Most Distant Ancestors for @I50498@: []
# Most Distant Ancestors for @I50499@: []
# Most Distant Ancestors for @I50500@: []
# Most Distant Ancestors for @I50501@: []
# Most Distant Ancestors for @I50502@: []
# Most Distant Ancestors for @I50503@: []
# Most Distant Ancestors for @I50504@: []
# Most Distant Ancestors for @I50505@: []
# Most Distant Ancestors for @I50506@: []
# Most Distant Ancestors for @I50507@: []
# Most Distant Ancestors for @I50508@: []
# Most Distant Ancestors for @I50509@: []
# Most Distant Ancestors for @I50510@: []
# Most Distant Ancestors for @I50511@: []
# Most Distant Ancestors for @I50512@: []
# Most Distant Ancestors for @I50513@: []
# Most Distant Ancestors for @I50514@: []
# Most Distant Ancestors for @I50515@: []
# Most Distant Ancestors for @I50516@: []
# Most Distant Ancestors for @I50517@: []
# Most Distant Ancestors for @I50518@: []
# Most Distant Ancestors for @I50519@: []
# Most Distant Ancestors for @I50520@: []
# Most Distant Ancestors for @I50521@: []
# Most Distant Ancestors for @I50522@: []
# Most Distant Ancestors for @I50523@: []
# Most Distant Ancestors for @I50524@: []
# Most Distant Ancestors for @I50525@: []
# Most Distant Ancestors for @I50526@: []
# Most Distant Ancestors for @I50527@: []
# Most Distant Ancestors for @I50528@: []
# Most Distant Ancestors for @I50529@: []
# Most Distant Ancestors for @I50530@: []
# Most Distant Ancestors for @I50531@: []
# Most Distant Ancestors for @I50532@: []
# Most Distant Ancestors for @I50533@: []
# Most Distant Ancestors for @I50534@: []
# Most Distant Ancestors for @I50535@: []
# Most Distant Ancestors for @I50536@: []
# Most Distant Ancestors for @I50537@: []
# Most Distant Ancestors for @I50538@: []
# Most Distant Ancestors for @I50539@: []
# Most Distant Ancestors for @I50540@: []
# Most Distant Ancestors for @I50541@: []
# Most Distant Ancestors for @I50542@: []
# Most Distant Ancestors for @I50543@: []
# Most Distant Ancestors for @I50544@: []
# Most Distant Ancestors for @I50545@: []
# Most Distant Ancestors for @I50546@: []
# Most Distant Ancestors for @I50547@: []
# Most Distant Ancestors for @I50548@: []
# Most Distant Ancestors for @I50549@: []
# Most Distant Ancestors for @I50550@: []
# Most Distant Ancestors for @I50551@: []
# Most Distant Ancestors for @I50552@: []
# Most Distant Ancestors for @I50553@: []
# Most Distant Ancestors for @I50554@: []
# Most Distant Ancestors for @I50555@: []
# Most Distant Ancestors for @I50556@: []
# Most Distant Ancestors for @I50557@: []
# Most Distant Ancestors for @I50558@: []
# Most Distant Ancestors for @I50559@: []
# Most Distant Ancestors for @I50560@: []
# Most Distant Ancestors for @I50561@: []
# Most Distant Ancestors for @I50562@: []
# Most Distant Ancestors for @I50563@: []
# Most Distant Ancestors for @I50564@: []
# Most Distant Ancestors for @I50565@: []
# Most Distant Ancestors for @I50566@: []
# Most Distant Ancestors for @I50567@: []
# Most Distant Ancestors for @I50568@: []
# Most Distant Ancestors for @I50569@: []
# Most Distant Ancestors for @I50570@: []
# Most Distant Ancestors for @I50571@: []
# Most Distant Ancestors for @I50572@: []
# Most Distant Ancestors for @I50573@: []
# Most Distant Ancestors for @I50574@: []
# Most Distant Ancestors for @I50575@: []
# Most Distant Ancestors for @I50576@: []
# Most Distant Ancestors for @I50577@: []
# Most Distant Ancestors for @I50578@: []
# Most Distant Ancestors for @I50579@: []
# Most Distant Ancestors for @I50580@: []
# Most Distant Ancestors for @I50581@: []
# Most Distant Ancestors for @I50582@: []
# Most Distant Ancestors for @I50583@: []
# Most Distant Ancestors for @I50584@: []
# Most Distant Ancestors for @I50585@: []
# Most Distant Ancestors for @I50586@: []
# Most Distant Ancestors for @I50587@: []
# Most Distant Ancestors for @I50588@: []
# Most Distant Ancestors for @I50589@: []
# Most Distant Ancestors for @I50590@: []
# Most Distant Ancestors for @I50591@: []
# Most Distant Ancestors for @I50592@: []
# Most Distant Ancestors for @I50593@: []
# Most Distant Ancestors for @I50594@: []
# Most Distant Ancestors for @I50595@: []
# Most Distant Ancestors for @I50596@: []
# Most Distant Ancestors for @I50597@: []
# Most Distant Ancestors for @I50598@: []
# Most Distant Ancestors for @I50599@: []
# Most Distant Ancestors for @I50600@: []
# Most Distant Ancestors for @I50601@: []
# Most Distant Ancestors for @I50602@: []
# Most Distant Ancestors for @I50603@: []
# Most Distant Ancestors for @I50604@: []
# Most Distant Ancestors for @I50605@: []
# Most Distant Ancestors for @I50606@: []
# Most Distant Ancestors for @I50607@: []
# Most Distant Ancestors for @I50608@: []
# Most Distant Ancestors for @I50609@: []
# Most Distant Ancestors for @I50610@: []
# Most Distant Ancestors for @I50611@: []
# Most Distant Ancestors for @I50612@: []
# Most Distant Ancestors for @I50613@: []
# Most Distant Ancestors for @I50614@: []
# Most Distant Ancestors for @I50615@: []
# Most Distant Ancestors for @I50616@: []
# Most Distant Ancestors for @I50617@: []
# Most Distant Ancestors for @I50618@: []
# Most Distant Ancestors for @I50619@: []
# Most Distant Ancestors for @I50620@: []
# Most Distant Ancestors for @I50621@: []
# Most Distant Ancestors for @I50622@: []
# Most Distant Ancestors for @I50623@: []
# Most Distant Ancestors for @I50624@: []
# Most Distant Ancestors for @I50625@: []
# Most Distant Ancestors for @I50626@: []
# Most Distant Ancestors for @I50627@: []
# Most Distant Ancestors for @I50628@: []
# Most Distant Ancestors for @I50629@: []
# Most Distant Ancestors for @I50630@: []
# Most Distant Ancestors for @I50631@: []
# Most Distant Ancestors for @I50632@: []
# Most Distant Ancestors for @I50633@: []
# Most Distant Ancestors for @I50634@: []
# Most Distant Ancestors for @I50635@: []
# Most Distant Ancestors for @I50636@: []
# Most Distant Ancestors for @I50637@: []
# Most Distant Ancestors for @I50638@: []
# Most Distant Ancestors for @I50639@: []
# Most Distant Ancestors for @I50640@: []
# Most Distant Ancestors for @I50641@: []
# Most Distant Ancestors for @I50642@: []
# Most Distant Ancestors for @I50643@: []
# Most Distant Ancestors for @I50644@: []
# Most Distant Ancestors for @I50645@: []
# Most Distant Ancestors for @I50646@: []
# Most Distant Ancestors for @I50647@: []
# Most Distant Ancestors for @I50648@: []
# Most Distant Ancestors for @I50649@: []
# Most Distant Ancestors for @I50650@: []
# Most Distant Ancestors for @I50651@: []
# Most Distant Ancestors for @I50652@: []
# Most Distant Ancestors for @I50653@: []
# Most Distant Ancestors for @I50654@: []
# Most Distant Ancestors for @I50655@: []
# Most Distant Ancestors for @I50656@: []
# Most Distant Ancestors for @I50657@: []
# Most Distant Ancestors for @I50658@: []
# Most Distant Ancestors for @I50659@: []
# Most Distant Ancestors for @I50660@: []
# Most Distant Ancestors for @I50661@: []
# Most Distant Ancestors for @I50662@: []
# Most Distant Ancestors for @I50663@: []
# Most Distant Ancestors for @I50664@: []
# Most Distant Ancestors for @I50665@: []
# Most Distant Ancestors for @I50666@: []
# Most Distant Ancestors for @I50667@: []
# Most Distant Ancestors for @I50668@: []
# Most Distant Ancestors for @I50669@: []
# Most Distant Ancestors for @I50670@: []
# Most Distant Ancestors for @I50671@: []
# Most Distant Ancestors for @I50672@: []
# Most Distant Ancestors for @I50673@: []
# Most Distant Ancestors for @I50674@: []
# Most Distant Ancestors for @I50675@: []
# Most Distant Ancestors for @I50676@: []
# Most Distant Ancestors for @I50677@: []
# Most Distant Ancestors for @I50678@: []
# Most Distant Ancestors for @I50679@: []
# Most Distant Ancestors for @I50680@: []
# Most Distant Ancestors for @I50681@: []
# Most Distant Ancestors for @I50682@: []
# Most Distant Ancestors for @I50683@: []
# Most Distant Ancestors for @I50684@: []
# Most Distant Ancestors for @I50685@: []
# Most Distant Ancestors for @I50686@: []
# Most Distant Ancestors for @I50687@: []
# Most Distant Ancestors for @I50688@: []
# Most Distant Ancestors for @I50689@: []
# Most Distant Ancestors for @I50690@: []
# Most Distant Ancestors for @I50691@: []
# Most Distant Ancestors for @I50692@: []
# Most Distant Ancestors for @I50693@: []
# Most Distant Ancestors for @I50694@: []
# Most Distant Ancestors for @I50695@: []
# Most Distant Ancestors for @I50696@: []
# Most Distant Ancestors for @I50697@: []
# Most Distant Ancestors for @I50698@: []
# Most Distant Ancestors for @I50699@: []
# Most Distant Ancestors for @I50700@: []
# Most Distant Ancestors for @I50701@: []
# Most Distant Ancestors for @I50702@: []
# Most Distant Ancestors for @I50703@: []
# Most Distant Ancestors for @I50704@: []
# Most Distant Ancestors for @I50705@: []
# Most Distant Ancestors for @I50706@: []
# Most Distant Ancestors for @I50707@: []
# Most Distant Ancestors for @I50708@: []
# Most Distant Ancestors for @I50709@: []
# Most Distant Ancestors for @I50710@: []
# Most Distant Ancestors for @I50711@: []
# Most Distant Ancestors for @I50712@: []
# Most Distant Ancestors for @I50713@: []
# Most Distant Ancestors for @I50714@: []
# Most Distant Ancestors for @I50715@: []
# Most Distant Ancestors for @I50716@: []
# Most Distant Ancestors for @I50717@: []
# Most Distant Ancestors for @I50718@: []
# Most Distant Ancestors for @I50719@: []
# Most Distant Ancestors for @I50720@: []
# Most Distant Ancestors for @I50721@: []
# Most Distant Ancestors for @I50722@: []
# Most Distant Ancestors for @I50723@: []
# Most Distant Ancestors for @I50724@: []
# Most Distant Ancestors for @I50725@: []
# Most Distant Ancestors for @I50726@: []
# Most Distant Ancestors for @I50727@: []
# Most Distant Ancestors for @I50728@: []
# Most Distant Ancestors for @I50729@: []
# Most Distant Ancestors for @I50730@: []
# Most Distant Ancestors for @I50731@: []
# Most Distant Ancestors for @I50732@: []
# Most Distant Ancestors for @I50733@: []
# Most Distant Ancestors for @I50734@: []
# Most Distant Ancestors for @I50735@: []
# Most Distant Ancestors for @I50736@: []
# Most Distant Ancestors for @I50737@: []
# Most Distant Ancestors for @I50738@: []
# Most Distant Ancestors for @I50739@: []
# Most Distant Ancestors for @I50740@: []
# Most Distant Ancestors for @I50741@: []
# Most Distant Ancestors for @I50742@: []
# Most Distant Ancestors for @I50743@: []
# Most Distant Ancestors for @I50744@: []
# Most Distant Ancestors for @I50745@: []
# Most Distant Ancestors for @I50746@: []
# Most Distant Ancestors for @I50747@: []
# Most Distant Ancestors for @I50748@: []
# Most Distant Ancestors for @I50749@: []
# Most Distant Ancestors for @I50750@: []
# Most Distant Ancestors for @I50751@: []
# Most Distant Ancestors for @I50752@: []
# Most Distant Ancestors for @I50753@: []
# Most Distant Ancestors for @I50754@: []
# Most Distant Ancestors for @I50755@: []
# Most Distant Ancestors for @I50756@: []
# Most Distant Ancestors for @I50757@: []
# Most Distant Ancestors for @I50758@: []
# Most Distant Ancestors for @I50759@: []
# Most Distant Ancestors for @I50760@: []
# Most Distant Ancestors for @I50761@: []
# Most Distant Ancestors for @I50762@: []
# Most Distant Ancestors for @I50763@: []
# Most Distant Ancestors for @I50764@: []
# Most Distant Ancestors for @I50765@: []
# Most Distant Ancestors for @I50766@: []
# Most Distant Ancestors for @I50767@: []
# Most Distant Ancestors for @I50768@: []
# Most Distant Ancestors for @I50769@: []
# Most Distant Ancestors for @I50770@: []
# Most Distant Ancestors for @I50771@: []
# Most Distant Ancestors for @I50772@: []
# Most Distant Ancestors for @I50773@: []
# Most Distant Ancestors for @I50774@: []
# Most Distant Ancestors for @I50775@: []
# Most Distant Ancestors for @I50776@: []
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2771504f7811> in <cell line: 400>()
#     398
#     399 # Combine names and spouses in your specified format
# --> 400 formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)]
#     401
#     402 final_output = "|".join(formatted_names)# Join all the formatted names with '|'
#
# NameError: name 'winning_path_names' is not defined

# %%
# !pip install pandas
# !pip install python-gedcom
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting python-gedcom
#   Downloading python_gedcom-1.0.0-py2.py3-none-any.whl (35 kB)
# Installing collected packages: python-gedcom
# Successfully installed python-gedcom-1.0.0
