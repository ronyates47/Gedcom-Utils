# %% [markdown]
# <a href="https://colab.research.google.com/github/ronyates47/Gedcom-Utils/blob/main/A_version_13_with_mission_success_2023_1620_1252.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import glob
from gedcom.element.individual import IndividualElement
from gedcom.parser import Parser
import pandas as pd

class GedcomDataset:
    def __init__(self, gen_person):
        self.gen_person = gen_person
        self.extractable_detail = {}

    def add_extractable_detail(self, key, value):
        self.extractable_detail[key] = value

    def get_gen_person(self):
        name = self.extractable_detail.get('NAME', '')
        first_name, last_name = name.split('/', 1)
        first_name = first_name.split(' ')[0]
        last_name = last_name.rstrip('/')
        self.anchor_gen1 = last_name.replace(" ", "") + first_name.replace(" ", "")
        return self.gen_person.strip('@')

    def get_anchor_gen1(self):
        return self.anchor_gen1

    def get_extractable_NPFX(self):
        return self.extractable_detail.get('NPFX', '')

    def get_extractable_cm(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            cm_value = npfx_value.split('&')[0].strip()
        else:
            cm_value = npfx_value.strip()
        try:
            int(cm_value)
            return cm_value
        except ValueError:
            return 'error'

    def get_extractable_sort(self):
        npfx_value = self.extractable_detail.get('NPFX', '')
        if '&' in npfx_value:
            sort_value = npfx_value.split('&')[1].strip()
            return sort_value
        else:
            return ''

    def get_extractable_FAMC(self):
        return self.extractable_detail.get('FAMC', '').strip('@')

# Function definitions
def extract_id(record):
    id_start = record.find('@') + 1
    id_end = record.find('@', id_start)
    return record[id_start:id_end]

def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10] # Use slicing syntax to extract the first 10 characters of the first_name variable
    last_name = last_name[:10].rstrip('/') # Use slicing syntax to extract the first 10 characters of the last_name variable
    return last_name.replace(" ", "") + first_name.replace(" ", "")

class Gedcom:
    def __init__(self, file_name):
        self.file_name = file_name
        self.gedcom_datasets = []
        self.filter_pool = []

    @staticmethod
    def get_standard_name(file_path):
        file_name = file_path.split('/')[-1]
        if '.' in file_name:
            file_name = file_name.rsplit('.', 1)[0]
        standard_name = file_name.replace(' ', '_').lower()
        return standard_name

    def parse_gedcom(self):  # Note the correct indentation here
        with open(self.file_name, 'r', encoding='utf-8-sig') as f:
            gedcom_lines = f.readlines()
        current_dataset = None
        npfx_count = 0
        total_count = 0
        for line in gedcom_lines:
            parts = line.strip().split(' ', 2)
            level = int(parts[0])
            tag = parts[1]
            value = parts[2] if len(parts) > 2 else None

            if level == 0 and tag.startswith('@') and tag.endswith('@') and value == 'INDI':
                total_count += 1
                current_dataset = GedcomDataset(tag)
                self.gedcom_datasets.append(current_dataset)
#                print(f"New individual dataset created with tag {tag}")
            elif current_dataset is not None:
                if level == 1 and tag in ['NAME', 'FAMC']:
                    current_key = tag
                    current_dataset.add_extractable_detail(current_key, value)
#                    print(f"Added detail: {current_key} = {value}")
                elif level == 2 and tag == 'NPFX':
                    npfx_count += 1
                    current_dataset.add_extractable_detail(tag, value)
#                    print(f"Added NPFX: {value}")

#        print(f'GEDCOM contained {total_count} total records')
        print(f'Records tagged and filtered by NPFX: {npfx_count}')

        # First level of filtering: Filter those with NPFX
        for dataset in self.gedcom_datasets:
            if dataset.get_extractable_NPFX():
                self.filter_pool.append(dataset)

        # Check if manual filtering should be applied
        manual_filter_activated = True  # or False depending on your situation

        # Second level of filtering: Apply manual filter from Excel sheet
        if manual_filter_activated:
            import pandas as pd  # Assuming you haven't imported it yet
            try:
                df = pd.read_excel('filtered_ids.xlsx')
            except FileNotFoundError:
                print("filtered_ids.xlsx not found. Skipping second-level manual filter.")
            else:
                manual_filtered_ids = set(df['ID'])
                print(f"Manual filter IDs loaded: {len(manual_filtered_ids) - 1}")

                self.filter_pool = [dataset for dataset in self.filter_pool if dataset.get_gen_person() in manual_filtered_ids]
                print(f"After manual filter, total records: {len(self.filter_pool)}")



def input_prime_surname(last_prime_surname=None):
    if last_prime_surname:
        last_name = input(f"Enter prime_surname (default: {last_prime_surname}): ")
        if not last_name:
            last_name = last_prime_surname
    else:
        last_name = input("Enter prime_surname: ")
    return last_name

def select_gedcom_file():
    gedcom_files = glob.glob('*.ged')
    if not gedcom_files:
        print("No GEDCOM files found.")
        return None

    print("Automatically selecting the first GEDCOM file.")
    return gedcom_files[0]

    while True:
        try:
            selected_num = int(input("Enter the number of the GEDCOM file you want to use: "))
            if 1 <= selected_num <= len(gedcom_files):
                return gedcom_files[selected_num - 1]
            else:
                print("Invalid number. Please enter a valid number from the list.")
        except ValueError:
            print("Invalid input. Please enter a valid number.")

gedcom_file_path = select_gedcom_file() # Call the function to let the user select the GEDCOM file
if gedcom_file_path:
    # Use the selected GEDCOM file path to create an instance of the Gedcom class
    gedcom_instance = Gedcom(gedcom_file_path)
    gedcom_instance.parse_gedcom()

    individuals = []  # Initialize the list of individuals

    for dataset in gedcom_instance.filter_pool:    # Iterate over the filter_pool list,add each last name and ID to list
        individual_id = dataset.get_gen_person()
        last_name = dataset.get_anchor_gen1()
        individuals.append((last_name, individual_id))

#    print(f'Records tagged and filtered by NPFX: {len(individuals)}')

    with open(gedcom_file_path, 'r') as file:    # Read the GEDCOM file and split it into individual and family records
        data = file.read()
    data = data.split('\n0 ')
    records = {extract_id(record): record for record in data}

def has_both_parents(records, mother_id, father_id):
    return mother_id in records and father_id in records

def find_parents(individual_id, generation, records):
    if individual_id not in records:
        return
    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]
    if famc_id not in records:
        return

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if mother_id and mother_id in records:
        mother_record = records[mother_id]
        mother_name = extract_name(mother_record)
    else:
        mother_name = None

    if father_id and father_id in records:
        father_record = records[father_id]
        father_name = extract_name(father_record)
    else:
        father_name = None

    if mother_name is not None and father_name is not None:
        parent_pair = father_name + "&" + mother_name
        if parent_pair not in visited_pairs:
            visited_pairs.add(parent_pair)
            if has_both_parents(records, mother_id, father_id):
                generation_table.loc[len(generation_table)] = [generation, parent_pair]

    if mother_id:
        find_parents(mother_id, generation + 1, records)

    if father_id:
        find_parents(father_id, generation + 1, records)

def extract_name(record):
    name_start = record.find('1 NAME ') + 6
    name_end = record.find('\n', name_start)
    name = record[name_start:name_end]
    first_name, last_name = name.split('/', 1)
    first_name = first_name[:10]
    last_name = last_name[:10].rstrip('/')
    return last_name.replace(" ", "") + first_name.replace(" ", "")

def find_distant_ancestors(individual_id, records, path=None):
    if path is None:
        path = [individual_id]
    else:
        path.append(individual_id)

    if individual_id not in records:
        return []

    record = records[individual_id]
    famc_start = record.find('1 FAMC @') + 8
    famc_end = record.find('@', famc_start)
    famc_id = record[famc_start:famc_end]

    if famc_id not in records:
        return [path]

    fam_record = records[famc_id]
    wife_start = fam_record.find('1 WIFE @') + 8
    wife_end = fam_record.find('@', wife_start)
    mother_id = fam_record[wife_start:wife_end]

    husb_start = fam_record.find('1 HUSB @') + 8
    husb_end = fam_record.find('@', husb_start)
    father_id = fam_record[husb_start:husb_end]

    if father_id is None and mother_id is None:
        return [path]

    paths = []
    if father_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(father_id, records, new_path))

    if mother_id:
        new_path = list(path)
        paths.extend(find_distant_ancestors(mother_id, records, new_path))

    return paths
filtered_datasets = gedcom_instance.filter_pool


# Start your main loop
for dataset in filtered_datasets:
    individual_id = dataset.get_gen_person()
    distant_ancestors_paths = find_distant_ancestors(individual_id, records)

    # Calculate score
    winning_path_score, winning_path_names = calculate_score(distant_ancestors_paths, records)

    # For debugging: print or log the winning_path_score
    print(f"Winning Path Score for individual {individual_id}: {winning_path_score}")

    # Translate IDs to Names
    name_paths = []
    for path in distant_ancestors_paths:
        name_path = [extract_name(records.get(id, '')) for id in path]
        name_paths.append(name_path)

    # Reverse the names for output formatting
    winning_path_names.reverse()

    # After score calculation, you do your output formatting
    spouse_names = ['unknown'] * len(winning_path_names)
    formatted_names = [f"{name}&{spouse}" for name, spouse in zip(winning_path_names, spouse_names)]
    final_output = "|".join(formatted_names)

    # For debugging: print or log the final_output
    print(f"352-Selected DNA Branch for individual {individual_id}: {final_output}")

# Additional Function to isolate score calculation logic
def calculate_score(distant_ancestors_paths, records):
    name_paths = []
    for path in distant_ancestors_paths:
        name_path = [extract_name(records.get(id, '')) for id in path]
        name_paths.append(name_path)

    path_scores = {}
    for idx, name_path in enumerate(name_paths):
        score = 0
        for generation, name in enumerate(name_path):
            if 'Yates' in name:
                score += 1 * (generation + 1)
        path_scores[idx] = score

    if path_scores:
        winning_path_index = max(path_scores, key=path_scores.get)
        winning_path_score = path_scores[winning_path_index]
        winning_path_names = name_paths[winning_path_index]
    else:
        winning_path_index = None
        winning_path_score = 0
        winning_path_names = []

    return winning_path_score, winning_path_names


#visited_pairs = set()

# Inside your existing process_individual function
def process_individual(individual_id, gedcom_instance, records):
    global generation_table
    global visited_pairs

    # Resetting the variables for each individual
    generation_table = pd.DataFrame(columns=['Generation', 'Parent Pair'])
    visited_pairs = set()

    # No recursive call here; simply proceed with the rest of the function
    find_parents(individual_id, 1, records)
    distant_ancestors_paths = find_distant_ancestors(individual_id, records)

    # Call the isolated score calculation function
    winning_path_score, winning_path_names = calculate_score(distant_ancestors_paths, records)

    for dataset in records:  # Use passed-in records instead of gedcom_instance.filter_pool
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    # Call the isolated score calculation function
    winning_path_score, winning_path_names = calculate_score(distant_ancestors_paths, records)

    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            anchor_gen1 = dataset.get_anchor_gen1()
            generation_table.loc[0] = [1, anchor_gen1]
            break

    generation_table = generation_table.sort_values('Generation', ascending=False).reset_index(drop=True)

    individual_data = {}
    for dataset in gedcom_instance.filter_pool:
        if dataset.get_gen_person() == individual_id:
            individual_data['cM'] = dataset.get_extractable_cm()
            individual_data['Sort'] = dataset.get_extractable_sort()
            break  # Update for multiple records. The score and filtered line do not come from here...

    filtered_parent_pairs = [row['Parent Pair'] for index, row in generation_table.iterrows() if any(parent in final_output for parent in row['Parent Pair'].split())]

    selected_dna_branch_parents = set(parent.split('&')[0] for parent in final_output.split('|'))

    filtered_parent_pairs = {}
    for index, row in generation_table.iterrows():
        generation = row['Generation']
        parent_pair = row['Parent Pair']
        for parent in parent_pair.split('&'):
            if parent in selected_dna_branch_parents:
                filtered_parent_pairs[generation] = parent_pair
                break

    # Convert filtered_parent_pairs to a string format, omitting generation numbers
    filtered_parent_pairs_str = '|'.join(filtered_parent_pairs.values())

    individual_data['Filtered Ancestral Line'] = filtered_parent_pairs_str    # Add it to individual_data

    return individual_data

#********************************************************
#print(generation_table)
#print(final_output)
#filtered_parent_pairs = [row['370-Parent Pair'] for index, row in generation_table.iterrows() if any(parent in final_output for parent in row['Parent Pair'].split())]
#print(filtered_parent_pairs)
#for index, row in generation_table.iterrows():
#    print("373-Parent Pair in generation_table:", row['Parent Pair'].split())
#    print("374-Parent in final_output:", [parent for parent in row['Parent Pair'].split() if parent in final_output])
#********************************************************
import pandas as pd

# Global variables
generation_table = None
visited_pairs = set()

# Assuming gedcom_instance and path_scores variables are already defined
filtered_individuals = [(dataset.get_anchor_gen1(), dataset.get_gen_person()) for dataset in gedcom_instance.filter_pool]

combined_df_rows = []  # Initialize your empty combined_df_rows list

# Start your main loop
# Start your main loop
for dataset in filtered_datasets:
    individual_id = dataset.get_gen_person()
    distant_ancestors_paths = find_distant_ancestors(individual_id, records)

    # Calculate score
    winning_path_score, winning_path_names = calculate_score(distant_ancestors_paths, records)

    # Debugging prints
    print(f"Winning Path Score for individual {individual_id}: {winning_path_score}")

    # Debugging prints
    print(f"Winning Path Score for individual {individual_id}: {winning_path_score}")
    # Append to combined_df_rows
    individual_data = process_individual(individual_id, gedcom_instance, gedcom_instance.filter_pool)
    cm = individual_data['cM']
    sort = individual_data['Sort']
    filtered_parent_pairs_str = individual_data['Filtered Ancestral Line']
    combined_df_rows.append([individual_id, sort, cm, winning_path_score, filtered_parent_pairs_str])

# Create the DataFrame
combined_df = pd.DataFrame(combined_df_rows, columns=['ID#', 'Match to', 'cM', 'Score', 'Filtered Ancestral Line'])

# Print the DataFrame
print(combined_df)

# Export to Excel
combined_df.to_excel('/content/output.xlsx', index=False)

#def create_hotlink(row):  # Function to create hotlinks
#    url_base = "https://yates.one-name.net/tng/verticalchart.php?personID="
#    person_id = row['ID#']
#    hotlink = f'{person_id}'
#    return hotlink
# Create hotlinks
#combined_df['LUN#'] = combined_df.apply(lambda row: create_hotlink(row), axis=1)

#******************************************************************(KEEP!!!!!!!!!!!!!!!!!)

# Initialize an empty dictionary to hold the filtered parent pairs
#filtered_parent_pairs = {}

# Assuming that selected_dna_branch_parents is a set containing individual parent names from 'Selected DNA Branch'
# Create the set from your actual 'Selected DNA Branch' string
#selected_dna_branch_parents = set(parent.split('&')[0] for parent in final_output.split('|'))

# Loop through the DataFrame to filter parent pairs
#for index, row in generation_table.iterrows():
#    generation = row['Generation']
#    parent_pair = row['Parent Pair']
#    for parent in parent_pair.split('&'):
#        if parent in selected_dna_branch_parents:
#            filtered_parent_pairs[generation] = parent_pair
#            break  # Once a match is found, no need to continue looking in this pair

# Display the filtered parent pairs
#print(filtered_parent_pairs)
#*****************************************************************************************KEEP!!!!!!!!!!!
# Out:
# Automatically selecting the first GEDCOM file.
# Records tagged and filtered by NPFX: 375
# filtered_ids.xlsx not found. Skipping second-level manual filter.
# Winning Path Score for individual I13817: 10
# 352-Selected DNA Branch for individual I13817: YatesJohnJ.&unknown|YatesWilliamW&unknown|YatesSamAnder&unknown|YatesWilliamH&unknown
# Winning Path Score for individual I21743: 165
# 352-Selected DNA Branch for individual I21743: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesMartin&unknown|YatesMartin&unknown|YatesMartin&unknown|YatesWilliam&unknown|YatesWilliamH&unknown|YatesHaydenMa&unknown|YatesRobertNo&unknown|YatesAnnieMae&unknown|WathenHelenVir&unknown|HuntRobertMu&unknown|HuntKelseyA&unknown
# Winning Path Score for individual I23678: 92
# 352-Selected DNA Branch for individual I23678: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesElizabeth&unknown|WildmanJoseph&unknown|WildmanJoseph&unknown|WildmanMartha&unknown|MoserBenjamin&unknown|MoserGrace&unknown|JohnsonNormanOr&unknown|JohnsonDonaldBr&unknown
# Winning Path Score for individual I26925: 7
# 352-Selected DNA Branch for individual I26925: YatesSarahAnn&unknown|RoperJamesC.&unknown|RoperElijah&unknown|RoperDavidAsb&unknown|RoperJohnBynu&unknown|RoperMyrtleRo&unknown|HudsonJL&unknown
# Winning Path Score for individual I31861: 130
# 352-Selected DNA Branch for individual I31861: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesHughDobi&unknown|YatesAllen&unknown|YatesMiloRebe&unknown|ChurchClovisWi&unknown|ChurchWilliamA&unknown|ChurchDebraSue&unknown
# Winning Path Score for individual I40190: 147
# 352-Selected DNA Branch for individual I40190: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorgeWa&unknown|YatesGeorgeWa&unknown|YatesMaryMoll&unknown|OdomGeorgeHe&unknown|OdomMildredM&unknown|DikeBethAnn&unknown
# Winning Path Score for individual I42478: 8
# 352-Selected DNA Branch for individual I42478: YatesSarahAnn&unknown|RoperJamesC.&unknown|RoperElijah&unknown|RoperDavidAsb&unknown|RoperKelly&unknown|RoperFloydSpe&unknown|RoperGaryScot&unknown|RoperHollyNic&unknown
# Winning Path Score for individual I44570: 180
# 352-Selected DNA Branch for individual I44570: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesBenjamin&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesRobert&unknown|YatesJoseph&unknown|YatesRachelAl&unknown|PollittClarence&unknown|PollittKennethL&unknown|PollittDebra&unknown|HepburnMarkAlle&unknown
# Winning Path Score for individual I44883: 28
# 352-Selected DNA Branch for individual I44883: YatesWilliam&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnEdwa&unknown|YatesMeredith&unknown|YatesDwaneMer&unknown|YatesRobertW&unknown
# Winning Path Score for individual I44894: 28
# 352-Selected DNA Branch for individual I44894: YatesWilliam&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnEdwa&unknown|YatesMeredith&unknown|YatesDwaneMer&unknown|YatesCraigMyr&unknown
# Winning Path Score for individual I44935: 132
# 352-Selected DNA Branch for individual I44935: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesEllender&unknown|FreemanMaryAnn&unknown|BeckRebeccaA&unknown|JacksonLewisCas&unknown|JacksonClaraEve&unknown|PugsleyHaroldLe&unknown|PugsleyHaroldLe&unknown
# Winning Path Score for individual I45040: 180
# 352-Selected DNA Branch for individual I45040: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesBenjamin&unknown|YatesBenjamin&unknown|YatesEnglishL&unknown|YatesWesleyHa&unknown|YatesAdaOdell&unknown|PruittAnnaEliz&unknown|MashburnLauraMae&unknown|Keeth&unknown|KeethLaura&unknown
# Winning Path Score for individual I45059: 108
# 352-Selected DNA Branch for individual I45059: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesElizabeth&unknown|PlummerElizabeth&unknown|IiamsThomas&unknown|IiamsJohn&unknown|IiamsWilliam&unknown|IiamsIsaac&unknown|IiamsMargaret&unknown|BarrCharlesF&unknown|BarrJoanneEv&unknown|OstergaardDaleFred&unknown
# Winning Path Score for individual I45072: 133
# 352-Selected DNA Branch for individual I45072: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJames&unknown|YatesJamesVal&unknown|YatesJames&unknown|YatesLorenzoD&unknown|YatesCynthia&unknown|JacksonArthurOl&unknown|JacksonVirginia&unknown
# Winning Path Score for individual I45084: 143
# 352-Selected DNA Branch for individual I45084: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesMichael&unknown|YatesMarthaL.&unknown|EstesMaryAnn&unknown|BraggElizabeth&unknown|SlinkerMarthaEl&unknown|BastinEmmaAdel&unknown|RootClarence&unknown|RootMinaMarr&unknown|AndrewsMarvinEu&unknown
# Winning Path Score for individual I45104: 143
# 352-Selected DNA Branch for individual I45104: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesEllender&unknown|FreemanWilliam&unknown|FreemanThomas&unknown|FreemanLewisTho&unknown|FreemanTalramB&unknown|FreemanArethaVi&unknown|JohnsonCarolynF&unknown|DaleJulettaL&unknown
# Winning Path Score for individual I45119: 125
# 352-Selected DNA Branch for individual I45119: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesSarah&unknown|FranklinOwen&unknown|FranklinThomasGo&unknown|FranklinGreenBer&unknown|FranklinDonnieRe&unknown|LoweryJosieLee&unknown|WeldonSadieLuc&unknown|KearleyCharles&unknown
# Winning Path Score for individual I45133: 7
# 352-Selected DNA Branch for individual I45133: YatesRebbecca&unknown|ShawIsraelTo&unknown|ShawMaryEmma&unknown|MurphyRalphShe&unknown|MurphyRalphShe&unknown|MurphyLinda&unknown|LichtensteEric&unknown
# Winning Path Score for individual I45149: 143
# 352-Selected DNA Branch for individual I45149: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesMartha&unknown|HandMercy&unknown|ReevesDavid&unknown|ReevesMaryRhod&unknown|CresseWilliamR&unknown|CresseRobertHa&unknown|CresseRobertCl&unknown|CresseBarbaraC&unknown
# Winning Path Score for individual I45150: 112
# 352-Selected DNA Branch for individual I45150: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesSarahAnn&unknown|MeadowsThomas&unknown|MeadowsJohnM&unknown|MeadowsJonas&unknown|MeadowsJosiah&unknown|MeadowsFrancis&unknown|MeadowsAnthony&unknown|MeadowsMadisonM&unknown|MeadowsJamesT&unknown|MeadowsRussellL&unknown|MeadowsNightieD&unknown|MeadowsDanaLee&unknown|MeadowsDanaMari&unknown
# Winning Path Score for individual I45201: 112
# 352-Selected DNA Branch for individual I45201: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesJohanna&unknown|HorneThomas&unknown|HorneWilliam&unknown|HorneWilliamH&unknown|HorneMoses&unknown|HorneAbishai&unknown|HorneJoab&unknown|HorneJosiah&unknown|HorneJosiah&unknown|HorneRebeccaF&unknown|MathersDorethaP&unknown|WaltersRoyAlvin&unknown|WaltersBeckyChr&unknown
# Winning Path Score for individual I45394: 138
# 352-Selected DNA Branch for individual I45394: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesCharlesL&unknown|YatesCatherine&unknown|AyersJoshua&unknown|AyersLorenzoD&unknown|AyersDockPark&unknown|AyersSaintElm&unknown|AyersDiannaSu&unknown
# Winning Path Score for individual I45417: 21
# 352-Selected DNA Branch for individual I45417: YatesJames&unknown|YatesJamesWal&unknown|YatesElizabeth&unknown|SwettJohn&unknown|SwettLabertha&unknown|AntillJohnWill&unknown|AntillGeorgeWi&unknown|AntillMargaret&unknown
# Winning Path Score for individual I45439: 30
# 352-Selected DNA Branch for individual I45439: YatesThomas&unknown|YatesGeorge&unknown|YatesWilliamH&unknown|YatesRobertJa&unknown|YatesPearl&unknown|HayterWilliamD&unknown|HayterJamieSue&unknown|CombsMeganLau&unknown
# Winning Path Score for individual I45462: 121
# 352-Selected DNA Branch for individual I45462: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesRebecca&unknown|IsbellThomasBe&unknown|IsbellJohnWesl&unknown|IsbellMargaret&unknown|BenbrookRuthMarg&unknown|BolesDavidWes&unknown
# Winning Path Score for individual I45467: 20
# 352-Selected DNA Branch for individual I45467: YatesDavid&unknown|YatesEdwardSa&unknown|YatesAlonzoWi&unknown|YatesAlonzoWi&unknown|YatesDonnaJea&unknown|CopelandDean&unknown
# Winning Path Score for individual I45499: 27
# 352-Selected DNA Branch for individual I45499: YatesAnn&unknown|YatesElijah&unknown|YatesJane&unknown|KirkhamThomas&unknown|KirkhamEli&unknown|KirkhamJane&unknown|BriggsCaroline&unknown|SchofieldChloe&unknown|PotterSharonLy&unknown|FitchJeanee&unknown
# Winning Path Score for individual I45520: 162
# 352-Selected DNA Branch for individual I45520: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesSamuel&unknown|YatesJoshua&unknown|YatesJoshua&unknown|YatesSarah&unknown|RatcliffNancyAli&unknown|MagillTheodore&unknown|MagillGeorgiaA&unknown|MartinGlendora&unknown|ClodfelterJohnAlva&unknown|ClodfelterDavidMax&unknown|ClodfelterGrace&unknown
# Winning Path Score for individual I45534: 34
# 352-Selected DNA Branch for individual I45534: YatesWilliam&unknown|YatesBartholom&unknown|YatesRobert&unknown|YatesCatharine&unknown|WellfordHorace&unknown|WellfordFannieEl&unknown|JonesWilliamF&unknown|JonesSallieMc&unknown|RobinsonAlbert&unknown|RobinsonDianeLyo&unknown
# Winning Path Score for individual I45552: 115
# 352-Selected DNA Branch for individual I45552: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesAnne&unknown|PratherWilliamN&unknown|PratherWilliamN&unknown|PratherAnnYates&unknown|SwailsRobertGo&unknown|SwailsRobertGo&unknown|SwailsIraFoste&unknown|SwailsIraFoste&unknown|SwailsLindaJea&unknown|DavisSaraLynn&unknown
# Winning Path Score for individual I45591: 168
# 352-Selected DNA Branch for individual I45591: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesRobert&unknown|YatesJonathan&unknown|YatesJoelWilk&unknown|YatesJamesRil&unknown|YatesWilliamO&unknown|YatesJaniceMa&unknown|Sauls&unknown|ErkmannMegan&unknown
# Winning Path Score for individual I45612: 22
# 352-Selected DNA Branch for individual I45612: YatesJohnPryo&unknown|YatesGabrielS&unknown|YatesJohnPryo&unknown|YatesZaylonA&unknown|SowellWillieRe&unknown|SegrestPhillipH&unknown|SegrestMichaelP&unknown
# Winning Path Score for individual I45632: 143
# 352-Selected DNA Branch for individual I45632: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesSamuel&unknown|YatesSamuelBe&unknown|YatesNathaniel&unknown|YatesSamuel&unknown|YatesMaryMarg&unknown|WoodMelissaA&unknown|WilsonHomerCyr&unknown|WilsonWilliamA&unknown|WilsonValorieJ&unknown
# Winning Path Score for individual I45636: 143
# 352-Selected DNA Branch for individual I45636: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesCatherine&unknown|DobbsLemuelLe&unknown|DobbsSamuelAr&unknown|DobbsJessieNa&unknown|KelleyWalterDo&unknown
# Winning Path Score for individual I45665: 143
# 352-Selected DNA Branch for individual I45665: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWarner&unknown|Yates&unknown|YatesMary&unknown|ShakeCharlesH&unknown|ShakeJamesMer&unknown|ShakeDonaldRa&unknown|ShakeNancyJo&unknown
# Winning Path Score for individual I45670: 136
# 352-Selected DNA Branch for individual I45670: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJamesHen&unknown|YatesJames&unknown|YatesJoelPinc&unknown|YatesJosephEm&unknown|YatesComerBro&unknown|YatesClintonH&unknown|YatesClintonH&unknown
# Winning Path Score for individual I45672: 156
# 352-Selected DNA Branch for individual I45672: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJames&unknown|YatesIsaac&unknown|YatesHinson&unknown|YatesSarahRac&unknown|LawsonEffieOre&unknown|LewisAdaLeota&unknown|McDonaldEvaLena&unknown|Bearce&unknown|BearceKara&unknown
# Winning Path Score for individual I45690: 35
# 352-Selected DNA Branch for individual I45690: YatesJohn&unknown|YatesThomasCh&unknown|YatesArthur&unknown|YatesWillis&unknown|YatesMahalaFr&unknown|BennettJosephLe&unknown|BennettWiltonH&unknown|BennettJoeDeway&unknown|BennettKarryB&unknown
# Winning Path Score for individual I45700: 132
# 352-Selected DNA Branch for individual I45700: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesRebecca&unknown|IsbellTrustenT&unknown|IsbellWilliamN&unknown|IsbellZilphaBe&unknown|BennettHubertOs&unknown|BennettJudithEm&unknown|HarveyBrittany&unknown
# Winning Path Score for individual I45722: 69
# 352-Selected DNA Branch for individual I45722: YatesWilliam&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJames&unknown|YatesAmariah&unknown|YatesTabitha&unknown|BarneyCynthia&unknown|BillsPaul&unknown|BillsLenaBell&unknown|BlairIsabella&unknown|MoyerGeraldine&unknown|DotyDannyLee&unknown|DotyJeffLee&unknown|DotyNathaniel&unknown
# Winning Path Score for individual I45741: 56
# 352-Selected DNA Branch for individual I45741: YatesMartin&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesIgnatius&unknown|YatesIgnatius&unknown|YatesCharlesT&unknown|YatesElizaJan&unknown|BarbierMaryAppo&unknown|FavierLaunietta&unknown|AllenLoisJean&unknown|KramerRichardE&unknown
# Winning Path Score for individual I45809: 18
# 352-Selected DNA Branch for individual I45809: YatesJohn&unknown|YatesLukeBarf&unknown|YatesWinifred&unknown|PowellMaryEmel&unknown|BaldwinMaryEmal&unknown|FormyduvalLetha&unknown|YoungJ&unknown
# Winning Path Score for individual I45823: 132
# 352-Selected DNA Branch for individual I45823: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesWilliam&unknown|YatesNancyAnn&unknown|WrightAlfred&unknown|WrightWilliamS&unknown|WrightEdwinLut&unknown|WrightBeulahCo&unknown|FordEdnaJane&unknown|EstepEllenDal&unknown
# Winning Path Score for individual I45833: 156
# 352-Selected DNA Branch for individual I45833: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesAnnBradl&unknown|YatesKerutahA&unknown|WillisWinslowB&unknown|WillisEdithLuc&unknown|CarpenterJaniceLy&unknown|TurnerReneeLyn&unknown|ShepardG&unknown
# Winning Path Score for individual I45864: 27
# 352-Selected DNA Branch for individual I45864: YatesJames&unknown|YatesJamesWal&unknown|YatesElizabeth&unknown|SwettJonathan&unknown|SwettIsaacW&unknown|SwettElizabeth&unknown|SmithLucy&unknown|GillettMyrtleLu&unknown|ConeJudyK&unknown|WilliamsRonaldLe&unknown
# Winning Path Score for individual I45897: 24
# 352-Selected DNA Branch for individual I45897: YatesWilliam&unknown|YatesBartholom&unknown|YatesAnneFran&unknown|ReadeSarah&unknown|RootesPhilipRe&unknown|RootesWilliam&unknown|RootesMaryEliz&unknown|GravesHarryWoo&unknown|GravesGeneL&unknown
# Winning Path Score for individual I45907: 150
# 352-Selected DNA Branch for individual I45907: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesDavid&unknown|YatesSarahAnn&unknown|BunkerPatrickH&unknown|BunkerDeliaLee&unknown|ShoemakerOrville&unknown|Shoemaker&unknown|Hall&unknown|HallBryanCad&unknown
# Winning Path Score for individual I45932: 49
# 352-Selected DNA Branch for individual I45932: YatesWilliam&unknown|YatesWilliam&unknown|YatesElias&unknown|YatesJonathan&unknown|YatesBurgess&unknown|YatesJohn&unknown|YatesLenoraLe&unknown|NewtonElmerNor&unknown|NewtonJaneGay&unknown|DayMary&unknown
# Winning Path Score for individual I45937: 100
# 352-Selected DNA Branch for individual I45937: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesIsabelle&unknown|IliffMary&unknown|BrownFrancisA&unknown|BrownWilliamM&unknown|BrownAlice&unknown|JohnsonSenaEliz&unknown|DulinBessie&unknown|DuttonCharles&unknown|DuttonReginaSu&unknown
# Winning Path Score for individual I45949: 143
# 352-Selected DNA Branch for individual I45949: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesMargaret&unknown|UpchurchAbel&unknown|UpchurchAdeline&unknown|MaynardNancyAnn&unknown|CastleburyVera&unknown|CastleburyMelbaChr&unknown|MurrayLindaMar&unknown|HerndonKathrynL&unknown
# Winning Path Score for individual I45980: 13
# 352-Selected DNA Branch for individual I45980: YatesWilliam&unknown|YatesMaryF&unknown|ParrishMaryEsth&unknown|WillisLillianR&unknown|CooperJohnJaco&unknown|CooperJohnRich&unknown|CooperJamesP&unknown
# Winning Path Score for individual I46008: 116
# 352-Selected DNA Branch for individual I46008: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesRichard&unknown|YatesElizabeth&unknown|EtheridgeRichard&unknown|EtheridgeSampson&unknown|EtheridgeSamuel&unknown|EtheridgeHenry&unknown|EtheridgeSarahAnn&unknown|CorleyJohnMadi&unknown|CorleyElizabeth&unknown|TurmanMyrtleDe&unknown|WhitenerLorraine&unknown|SmithRoyWalte&unknown
# Winning Path Score for individual I46034: 150
# 352-Selected DNA Branch for individual I46034: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWarner&unknown|YatesMaryEliz&unknown|WhitlowElizabeth&unknown|PedigoLauraAli&unknown|PiercyAugustus&unknown|PiercyLeonardL&unknown|PiercyRavenalJ&unknown|LaDuctScottAll&unknown
# Winning Path Score for individual I46054: 9
# 352-Selected DNA Branch for individual I46054: YatesWilliam&unknown|YatesSarahEli&unknown|GentryStephenA&unknown|GentryStephenM&unknown|GentrySharonIr&unknown
# Winning Path Score for individual I46068: 165
# 352-Selected DNA Branch for individual I46068: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesWilliam&unknown|YatesJonathon&unknown|YatesJohnJaco&unknown|YatesJacob&unknown|YatesNewtonBi&unknown|YatesLaraVann&unknown|RobinsonOla&unknown|CrabtreeMarlaRay&unknown|RoseCynthiaD&unknown
# Winning Path Score for individual I46085: 135
# 352-Selected DNA Branch for individual I46085: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesLucySara&unknown|WinninghamLucyDeli&unknown|DespainSolomon&unknown|DespainJamesHar&unknown|DespainSolomonJ&unknown|DespainHyrumSmi&unknown|DespainIdaAnn&unknown|LyonsAlbertEu&unknown|LyonsMichaelD&unknown
# Winning Path Score for individual I46102: 117
# 352-Selected DNA Branch for individual I46102: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesRebecca&unknown|StiversWilliamY&unknown|StiversEdward&unknown|StiversRichardC&unknown|StiversBartlett&unknown|StiversEugeneEl&unknown|BakerThomasCl&unknown|BakerMargieLe&unknown|OdlePeggyJea&unknown
# Winning Path Score for individual I46119: 100
# 352-Selected DNA Branch for individual I46119: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesRichard&unknown|YatesMary&unknown|SoperJohn&unknown|SoperSusannah&unknown|DarnellRaleigh&unknown|DarnellAdamPatt&unknown|DarnellAmandaCa&unknown|RameyWilliamC&unknown|RameyJamesWor&unknown|RameyMyrtleMa&unknown
# Winning Path Score for individual I46129: 6
# 352-Selected DNA Branch for individual I46129: YatesNancy&unknown|ColliverJesseB&unknown|ColliverRichardT&unknown|ColliverJohnB&unknown|ColliverBeulahKa&unknown|JonesMaryKath&unknown
# Winning Path Score for individual I46144: 143
# 352-Selected DNA Branch for individual I46144: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJames&unknown|YatesElizabeth&unknown|McCraryNellie&unknown|PeeryMaryAnn&unknown|HooverAndoniaB&unknown|HillEthel&unknown|MooreCharlesA&unknown|MooreMarilynB&unknown|RiddleAllison&unknown
# Winning Path Score for individual I46154: 126
# 352-Selected DNA Branch for individual I46154: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJamesHen&unknown|YatesJoel&unknown|YatesSarah&unknown|SmithLydiaFra&unknown|BurranRobertEd&unknown|BurranWilliamC&unknown|BurranEdwardM&unknown
# Winning Path Score for individual I46168: 162
# 352-Selected DNA Branch for individual I46168: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesElizabeth&unknown|TaylorLavinia&unknown|BurkettEllenCar&unknown|ThomasMaryElle&unknown|MeltonViola&unknown|McCorquodaSarahEll&unknown|LawsonGaryLee&unknown|LawsonGaryLee&unknown
# Winning Path Score for individual I46175: 35
# 352-Selected DNA Branch for individual I46175: YatesWilliam&unknown|YatesWilliam&unknown|YatesJohn&unknown|YatesJames&unknown|YatesCatherine&unknown|CoffmanMaryEmma&unknown|HarperJamesWea&unknown|HarperLucyMay&unknown|SheroanJamesCha&unknown
# Winning Path Score for individual I46186: 150
# 352-Selected DNA Branch for individual I46186: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesMargaret&unknown|StewartEleanor&unknown|HicksMatilda&unknown|HoltJohnJ&unknown|HoltFrankJoh&unknown|HoltElizabeth&unknown|FishbackCarolAnn&unknown
# Winning Path Score for individual I46197: 152
# 352-Selected DNA Branch for individual I46197: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesTillman&unknown|YatesJohnDavi&unknown|YatesGeorgeRe&unknown|YatesCharlesW&unknown|YatesErnestKi&unknown|YatesBarbaraJ&unknown|YoutherRobertAl&unknown
# Winning Path Score for individual I46207: 161
# 352-Selected DNA Branch for individual I46207: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesStephen&unknown|YatesJamesTar&unknown|YatesJoseph&unknown|YatesJosephH&unknown|YatesMaryE&unknown|MorrowMaryNaom&unknown|KempVEdmon&unknown|KempJudyV&unknown|WhiteToddMorr&unknown
# Winning Path Score for individual I46214: 22
# 352-Selected DNA Branch for individual I46214: YatesWilliam&unknown|YatesPatrick&unknown|YatesSolomon&unknown|YatesIdaAlice&unknown|HillLelahFer&unknown|BoneyMarjorie&unknown|RayburnStevenAl&unknown
# Winning Path Score for individual I46231: 165
# 352-Selected DNA Branch for individual I46231: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJamesHen&unknown|YatesWilliam&unknown|YatesJoel&unknown|YatesJohnWesl&unknown|YatesEarlRaym&unknown|YatesEvaMarie&unknown|DenbowDanielLe&unknown|DenbowBethLynn&unknown|DenbowKimberly&unknown
# Winning Path Score for individual I46243: 100
# 352-Selected DNA Branch for individual I46243: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesIsabelle&unknown|IliffJohnYate&unknown|IliffJames&unknown|IliffMary&unknown|BellesAnnaCord&unknown|HedgesMaryE&unknown|ChapmanElizabeth&unknown|RolandWilliamE&unknown|RolandLeeAnn&unknown
# Winning Path Score for individual I46269: 116
# 352-Selected DNA Branch for individual I46269: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesAnne&unknown|PratherWilliamN&unknown|PratherJohnJosi&unknown|PratherBasilPit&unknown|PratherArchelus&unknown|PratherJohnJess&unknown|PratherObedience&unknown|StewartWilliamM&unknown|StewartThomasJa&unknown|StewartThomasJa&unknown|StewartThomasJa&unknown
# Winning Path Score for individual I46285: 108
# 352-Selected DNA Branch for individual I46285: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesHannah&unknown|KinseyJosephBr&unknown|KinseySeleta&unknown|DicksonJuliaAnn&unknown|WalkerFrancesS&unknown|WallaceAnnieMae&unknown|RileyWallaceS&unknown|RileyWilliamN&unknown
# Winning Path Score for individual I46303: 108
# 352-Selected DNA Branch for individual I46303: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesSarahWeb&unknown|AshburneJohnYate&unknown|AshburneHannah&unknown|BeakesWilliam&unknown|BeakesJonathan&unknown|BeakesWilliam&unknown|BeakesMaryAnna&unknown|BeersFrederick&unknown|BeersElsieTer&unknown|PetersonTerryLyn&unknown
# Winning Path Score for individual I46317: 26
# 352-Selected DNA Branch for individual I46317: YatesJoseph&unknown|YatesJoseph&unknown|YatesWilliamB&unknown|YatesAgnesIsa&unknown|StevensJennie&unknown|WescottMaryViol&unknown|WilkinsonJeanCorn&unknown|SmithDeborahW&unknown
# Winning Path Score for individual I46330: 150
# 352-Selected DNA Branch for individual I46330: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesMartin&unknown|YatesMartin&unknown|YatesEdward&unknown|YatesZachariah&unknown|YatesNancy&unknown|JarboeBenedict&unknown|JarboeLetitia&unknown|WeedmanMarkDomi&unknown|WeedmanHeywoodB&unknown|WeedmanTomD&unknown|WeedmanAngelaMi&unknown
# Winning Path Score for individual I46346: 98
# 352-Selected DNA Branch for individual I46346: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesJane-Joan&unknown|JonesMary&unknown|PennWilliamJ&unknown|PennJames&unknown|PennWilliam&unknown|PennHester&unknown|MiskellyWilliam&unknown|MiskellyMaryS&unknown|MurphineMaryEliz&unknown|SchenckWilliamJ&unknown|SchenckLarryD&unknown
# Winning Path Score for individual I46370: 18
# 352-Selected DNA Branch for individual I46370: YatesWilliamP&unknown|YatesJamesMcK&unknown|YatesWilliamP&unknown|YatesHelenFra&unknown|PerkinsLarry&unknown|PerkinsTeresaG&unknown
# Winning Path Score for individual I46390: 98
# 352-Selected DNA Branch for individual I46390: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesMary&unknown|WillisRichard&unknown|WillisSamuel&unknown|WillisJoseph&unknown|WillisThomas&unknown|WillisMerrillE&unknown|WillisMargaret&unknown|BurnsJamesEdw&unknown|BurnsElijahRo&unknown|BurnsRex&unknown|BurnsCaroleYv&unknown
# Winning Path Score for individual I46402: 143
# 352-Selected DNA Branch for individual I46402: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesCharlesL&unknown|YatesWarnerMi&unknown|YatesSarahGoo&unknown|MitchellKateSaun&unknown|EstesSaraEliz&unknown|GuyClareEli&unknown|MartinRobertLe&unknown
# Winning Path Score for individual I46403: 156
# 352-Selected DNA Branch for individual I46403: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesCharlesL&unknown|YatesWarnerMi&unknown|YatesSarahGoo&unknown|MitchellKateSaun&unknown|EstesSaraEliz&unknown|GuyClareEli&unknown|MartinRobertLe&unknown|MartinTroy&unknown
# Winning Path Score for individual I46415: 100
# 352-Selected DNA Branch for individual I46415: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesElizabeth&unknown|WildmanGrace&unknown|WaltersConrad&unknown|WaltersElizaMal&unknown|EnlowThomasWa&unknown|EnlowNannieBe&unknown|PearmanLillianM&unknown|WhitlowGladysAl&unknown|HarrisMaryFrei&unknown
# Winning Path Score for individual I46423: 133
# 352-Selected DNA Branch for individual I46423: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJames&unknown|YatesJamesVal&unknown|YatesJames&unknown|YatesLorenzoD&unknown|YatesVerna&unknown|MillerThelmaMa&unknown|HilburnTeresaDi&unknown
# Winning Path Score for individual I46430: 184
# 352-Selected DNA Branch for individual I46430: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesFrancisG&unknown|YatesMilford&unknown|YatesWilliamM&unknown|YatesAnthonyW&unknown|YatesThelmaRa&unknown|HuddlestonCarolynR&unknown|MolesworthAnitaFay&unknown|MolesworthBrandi&unknown
# Winning Path Score for individual I46448: 35
# 352-Selected DNA Branch for individual I46448: YatesJohn&unknown|YatesThomasCh&unknown|YatesArthur&unknown|YatesWillis&unknown|YatesMahalaFr&unknown|BennettLucyMabl&unknown|AlmandMableLuc&unknown|Walden-JacLarryJoe&unknown|Walden-JacMargo&unknown
# Winning Path Score for individual I46457: 135
# 352-Selected DNA Branch for individual I46457: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesLeviJosh&unknown|YatesLeviJosh&unknown|YatesJohnAlbe&unknown|YatesClark&unknown|YatesRilla&unknown|HartLeonardM&unknown
# Winning Path Score for individual I46470: 117
# 352-Selected DNA Branch for individual I46470: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesHannahEv&unknown|SheltonWilliamJ&unknown|SheltonElijahFr&unknown|SheltonBenjamin&unknown|SheltonAmosMans&unknown|SheltonLeeArtis&unknown|SheltonMarcella&unknown|SchiffDixieLee&unknown|PriceCherylDe&unknown
# Winning Path Score for individual I46495: 117
# 352-Selected DNA Branch for individual I46495: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesRobert&unknown|YatesCharles&unknown|YatesAnnEliza&unknown|GwinnAnn&unknown|HarrisThomasG&unknown|HarrisRichard&unknown|HarrisRebeccaA&unknown|WilhelmRebeccaA&unknown|GillSusieReb&unknown|ReterNancy&unknown|StocksdaleTammyLyn&unknown
# Winning Path Score for individual I46502: 26
# 352-Selected DNA Branch for individual I46502: YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesAmy&unknown|LooneyJohnDani&unknown|LooneyChesterA&unknown|LooneyArthurLe&unknown|LooneyCathi&unknown
# Winning Path Score for individual I46508: 12
# 352-Selected DNA Branch for individual I46508: YatesSamuelPo&unknown|YatesEliza&unknown|BaileyYatesDan&unknown|BaileyWinonaLu&unknown|OsterholmDebraEli&unknown
# Winning Path Score for individual I46516: 14
# 352-Selected DNA Branch for individual I46516: YatesJames&unknown|YatesEdwinJos&unknown|YatesEdwin&unknown|YatesHelenJ&unknown|ArfmannSusanAnn&unknown
# Winning Path Score for individual I46528: 33
# 352-Selected DNA Branch for individual I46528: YatesWilliam&unknown|YatesBartholom&unknown|YatesAnneFran&unknown|ReadeSarah&unknown|RootesPhilipRe&unknown|RootesElivira&unknown|BowlesCorilla&unknown|SullivanWillieLe&unknown|DeenerAnnieMae&unknown|WayneBarbaraJ&unknown|JohnsonGaryL&unknown|JohnsonJeremiah&unknown
# Winning Path Score for individual I46538: 13
# 352-Selected DNA Branch for individual I46538: YatesJamesMcD&unknown|YatesMarthaTa&unknown|PepperDavidGad&unknown|PepperSudieMar&unknown|AtteberryDathaKat&unknown|LockwoodLindaKay&unknown|WadeCoreyErv&unknown
# Winning Path Score for individual I46550: 143
# 352-Selected DNA Branch for individual I46550: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesFrances&unknown|ShirleyJohnWarf&unknown|ShirleyMaryAnn&unknown|WalkerAnnaMary&unknown|GoodsonNannieA&unknown|JonesJohnPaul&unknown|JonesDonaldPa&unknown|JonesDonaldPa&unknown
# Winning Path Score for individual I46562: 108
# 352-Selected DNA Branch for individual I46562: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesHannahEv&unknown|SheltonGeorgeWa&unknown|SheltonGideonFa&unknown|SheltonMarthaEl&unknown|SteeleJettyPea&unknown|SharpeVernaKat&unknown|NewcombPatsyRut&unknown|BooneDavidRan&unknown
# Winning Path Score for individual I46572: 13
# 352-Selected DNA Branch for individual I46572: YatesJoshuaHa&unknown|YatesHannahPa&unknown|BalchThomasWa&unknown|BalchCatherine&unknown|ClemmerJohnWesl&unknown|ClemmerTommyRay&unknown|ClemmerJulianaG&unknown
# Winning Path Score for individual I46584: 136
# 352-Selected DNA Branch for individual I46584: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJames&unknown|YatesJamesVal&unknown|YatesJames&unknown|YatesGarlandH&unknown|YatesJamesJef&unknown|YatesRobertAu&unknown|YatesMaryElly&unknown
# Winning Path Score for individual I46593: 39
# 352-Selected DNA Branch for individual I46593: YatesGeorge&unknown|YatesJohn&unknown|YatesRichard&unknown|YatesJohnRich&unknown|YatesRichard&unknown|YatesFloraEdn&unknown|CollinsRobertEr&unknown|CollinsRobertOd&unknown|CollinsChristoph&unknown
# Winning Path Score for individual I46603: 156
# 352-Selected DNA Branch for individual I46603: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesMichael&unknown|YatesAbner&unknown|YatesHenry&unknown|YatesMartha&unknown|ScottJohnWinf&unknown|ScottGraceW&unknown|ClarkKarlEdwa&unknown|ClarkNancy&unknown|WilesAaronDea&unknown
# Winning Path Score for individual I46628: 138
# 352-Selected DNA Branch for individual I46628: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesLeviJosh&unknown|YatesCeliaAnn&unknown|ColeWilliamH&unknown|ColeHannahEl&unknown|BlackWilliamK&unknown|BlackClaytonK&unknown|BlackAnneMari&unknown
# Winning Path Score for individual I46641: 147
# 352-Selected DNA Branch for individual I46641: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesAlexander&unknown|YatesChesley&unknown|YatesMatthew&unknown|YatesCallieVi&unknown|HammondsWilliamE&unknown|HammondsGuidanaL&unknown|MapesPatricia&unknown
# Winning Path Score for individual I46655: 161
# 352-Selected DNA Branch for individual I46655: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJamesHen&unknown|YatesJames&unknown|YatesCharles&unknown|YatesJamesMon&unknown|YatesSarahEli&unknown|RutledgeLoisVirg&unknown|StephensNina&unknown|SandersTeresaLo&unknown|KaiserSamantha&unknown
# Winning Path Score for individual I46667: 156
# 352-Selected DNA Branch for individual I46667: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesEliC&unknown|YatesJohnPete&unknown|YatesMatildaC&unknown|GuynesWilliamP&unknown|GuynesNorvalMa&unknown|GuynesOpal&unknown|BrownPatsyJoa&unknown|EddyJoniLynn&unknown
# Winning Path Score for individual I46681: 135
# 352-Selected DNA Branch for individual I46681: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesSamuel&unknown|YatesMaryAnn&unknown|MoneyKeziah&unknown|TunnellStephen&unknown|TunnellStephenM&unknown|TunnellJamesTho&unknown|TunnellDavidAlm&unknown|TunnellJosephHe&unknown|TunnellLaVayAnn&unknown|LauterLarraine&unknown
# Winning Path Score for individual I46706: 161
# 352-Selected DNA Branch for individual I46706: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesStephen&unknown|YatesStephen&unknown|YatesThomas&unknown|YatesGeorgeWa&unknown|YatesMaryJane&unknown|SmithJohnMorg&unknown|SmithGeorgeWi&unknown|SmithEdithD&unknown|WessnerTraceyE&unknown
# Winning Path Score for individual I46721: 30
# 352-Selected DNA Branch for individual I46721: YatesWilliam&unknown|YatesBartholom&unknown|YatesSarah&unknown|RobinsonAnn&unknown|GreenJael&unknown|MercerLevi&unknown|MercerLouisa&unknown|SpearsThomasL&unknown|SpearsEnnieOde&unknown|BryantMaryO&unknown|CurtisMarjorie&unknown
# Winning Path Score for individual I46750: 138
# 352-Selected DNA Branch for individual I46750: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesJames&unknown|YatesJamesVal&unknown|YatesCharlotte&unknown|BootheJamesRil&unknown|BootheCharlotte&unknown|BowenLeona&unknown|PulleySadieMar&unknown|TurleyJacquelin&unknown
# Winning Path Score for individual I46764: 100
# 352-Selected DNA Branch for individual I46764: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesIsabelle&unknown|IliffJohnYate&unknown|IliffBenjamin&unknown|IliffValentine&unknown|IliffJamesMas&unknown|IliffBenjamin&unknown|LeVeirFrank&unknown|LeVeirEdithLou&unknown|FiskWalterFr&unknown
# Winning Path Score for individual I46792: 15
# 352-Selected DNA Branch for individual I46792: YatesWilliamP&unknown|YatesJamesMcK&unknown|YatesMyrtleAl&unknown|KuntzJamesHar&unknown|KuntzShirleyJ&unknown|LeavertonMelissaA&unknown
# Winning Path Score for individual I46811: 116
# 352-Selected DNA Branch for individual I46811: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJohnThom&unknown|YatesJohn&unknown|YatesRichard&unknown|YatesMary&unknown|SoperSamuel&unknown|SoperSamuel&unknown|SoperSamuel&unknown|SoperRobert&unknown|SoperSamuel&unknown|SoperMarthaJa&unknown|DargerBrighamD&unknown|DargerEldren&unknown|DargerCarol&unknown|NielsenSusanLyn&unknown
# Winning Path Score for individual I46826: 154
# 352-Selected DNA Branch for individual I46826: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesMichael&unknown|YatesMarthaL.&unknown|EstesNancy&unknown|BraggMarthaPa&unknown|MikelNoah&unknown|MikelMaryFran&unknown|ClemRay&unknown|ClemJeraldEb&unknown|ClemCharlesR&unknown|ClemLissaM&unknown
# Winning Path Score for individual I46836: 138
# 352-Selected DNA Branch for individual I46836: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesHughDobi&unknown|YatesJemima&unknown|PhillipsMarthaA&unknown|BlackburnSarahCam&unknown|BeshearsHegarson&unknown|BeshearsEdwardHe&unknown|BeshearsJamesFar&unknown
# Winning Path Score for individual I46847: 143
# 352-Selected DNA Branch for individual I46847: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesJasperGe&unknown|YatesJasper&unknown|YatesJohn&unknown|YatesJasper&unknown|YatesJohn&unknown|YatesJoseph&unknown|YatesFrancesE&unknown|BowersWilliamH&unknown|BowersClaraLor&unknown|WilsonSandraLy&unknown|FredrickAmandaL&unknown
# Winning Path Score for individual I46861: 152
# 352-Selected DNA Branch for individual I46861: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesWilliamT&unknown|YatesGeorge&unknown|YatesJames&unknown|YatesGeorgeHa&unknown|YatesJamesEar&unknown|YatesIvyEstel&unknown|RobertsonArch&unknown
# Winning Path Score for individual I46872: 138
# 352-Selected DNA Branch for individual I46872: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesStephen&unknown|YatesSamuel&unknown|YatesLetitia&unknown|ParsonsThomasJe&unknown|ParsonsGeorgeGr&unknown|ParsonsNoraMae&unknown|LeCompteColmanNe&unknown|LeCompteNinaFay&unknown
# Winning Path Score for individual I46881: 30
# 352-Selected DNA Branch for individual I46881: YatesWilliam&unknown|YatesWilliam&unknown|YatesElias&unknown|YatesSarahE.&unknown|ArmstrongWilliamF&unknown|ArmstrongJohnThom&unknown|ArmstrongNoraLee&unknown|SlagelFrancesM&unknown|SmockEldon&unknown
# Winning Path Score for individual I46894: 143
# 352-Selected DNA Branch for individual I46894: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesEllender&unknown|FreemanElizabeth&unknown|WardElizabeth&unknown|LeeMarthaAn&unknown|LeeWillieMa&unknown|StewartMarionEv&unknown|StewartMarionEv&unknown|StewartPatricia&unknown
# Winning Path Score for individual I46903: 138
# 352-Selected DNA Branch for individual I46903: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesSamuel&unknown|YatesJoshua&unknown|YatesWilliam&unknown|YatesMaryJane&unknown|TewellJohnR.&unknown|TewellJamesBuc&unknown|TewellRoyCleve&unknown|TewellRoyElber&unknown|TewellPhyllisE&unknown
# Winning Path Score for individual I46917: 132
# 352-Selected DNA Branch for individual I46917: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesJohn&unknown|YatesSally&unknown|GibsonHarrietM&unknown|BoyceFranklin&unknown|BoyceAlfredLl&unknown|BoyceJamesAlf&unknown|BoyceHardyShe&unknown|BoyceJamesShe&unknown
# Winning Path Score for individual I46924: 165
# 352-Selected DNA Branch for individual I46924: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesThomas&unknown|YatesJames&unknown|YatesJosephWe&unknown|YatesWilliam&unknown|YatesWilliam&unknown|YatesLeviJosh&unknown|YatesLeviJosh&unknown|YatesJohnAlbe&unknown|YatesClark&unknown|YatesFlorence&unknown|PriceHaskellL&unknown|Price&unknown|ParkinsonAmberChr&unknown
# Winning Path Score for individual I46934: 156
# 352-Selected DNA Branch for individual I46934: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesJamesLew&unknown|YatesGerardMa&unknown|YatesLucyJane&unknown|MaddenJohnWill&unknown|MaddenMaryEliz&unknown|KidwellMaryEliz&unknown|NearingJamesLer&unknown|NearingMaryFran&unknown
# Winning Path Score for individual I46945: 161
# 352-Selected DNA Branch for individual I46945: YatesRichard&unknown|YatesJohn&unknown|YatesThomas&unknown|YatesFrancis&unknown|YatesThomas&unknown|YatesJohn&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesGeorge&unknown|YatesWilliam&unknown|YatesBenjamin&unknown|YatesJohn&unknown|YatesLevi&unknown|YatesMaryElle&unknown|PinionAndrewEp&unknown|PinionAndrewEl&unknown|PinionVenevaFa&unknown|MassieKimberly&unknown
# Winning Path Score for individual I46954: 125
# ...
# Winning Path Score for individual I48430: 143
# Winning Path Score for individual I48438: 143
# Winning Path Score for individual I48438: 143
# Winning Path Score for individual I48452: 132
# Winning Path Score for individual I48452: 132
# Winning Path Score for individual I48471: 98
# Winning Path Score for individual I48471: 98
# Winning Path Score for individual I48481: 143
# Winning Path Score for individual I48481: 143
# Winning Path Score for individual I48489: 120
# Winning Path Score for individual I48489: 120
# Winning Path Score for individual I48503: 135
# Winning Path Score for individual I48503: 135
# Winning Path Score for individual I48516: 108
# Winning Path Score for individual I48516: 108
# Winning Path Score for individual I48525: 147
# Winning Path Score for individual I48525: 147
# Winning Path Score for individual I48538: 92
# Winning Path Score for individual I48538: 92
# Winning Path Score for individual I48552: 99
# Winning Path Score for individual I48552: 99
# Winning Path Score for individual I48560: 165
# Winning Path Score for individual I48560: 165
# Winning Path Score for individual I48573: 143
# Winning Path Score for individual I48573: 143
# Winning Path Score for individual I48581: 150
# Winning Path Score for individual I48581: 150
# Winning Path Score for individual I48593: 84
# Winning Path Score for individual I48593: 84
# Winning Path Score for individual I48605: 143
# Winning Path Score for individual I48605: 143
# Winning Path Score for individual I48614: 69
# Winning Path Score for individual I48614: 69
# Winning Path Score for individual I48627: 117
# Winning Path Score for individual I48627: 117
# Winning Path Score for individual I48628: 20
# Winning Path Score for individual I48628: 20
# Winning Path Score for individual I48642: 108
# Winning Path Score for individual I48642: 108
# Winning Path Score for individual I48652: 27
# Winning Path Score for individual I48652: 27
# Winning Path Score for individual I48664: 21
# Winning Path Score for individual I48664: 21
# Winning Path Score for individual I48670: 170
# Winning Path Score for individual I48670: 170
# Winning Path Score for individual I48674: 36
# Winning Path Score for individual I48674: 36
# Winning Path Score for individual I48686: 132
# Winning Path Score for individual I48686: 132
# Winning Path Score for individual I48697: 30
# Winning Path Score for individual I48697: 30
# Winning Path Score for individual I48706: 161
# Winning Path Score for individual I48706: 161
# Winning Path Score for individual I48710: 165
# Winning Path Score for individual I48710: 165
# Winning Path Score for individual I48721: 40
# Winning Path Score for individual I48721: 40
# Winning Path Score for individual I48728: 20
# Winning Path Score for individual I48728: 20
# Winning Path Score for individual I48737: 130
# Winning Path Score for individual I48737: 130
# Winning Path Score for individual I48744: 117
# Winning Path Score for individual I48744: 117
# Winning Path Score for individual I48752: 121
# Winning Path Score for individual I48752: 121
# Winning Path Score for individual I48765: 150
# Winning Path Score for individual I48765: 150
# Winning Path Score for individual I48767: 33
# Winning Path Score for individual I48767: 33
# Winning Path Score for individual I48784: 33
# Winning Path Score for individual I48784: 33
# Winning Path Score for individual I48792: 130
# Winning Path Score for individual I48792: 130
# Winning Path Score for individual I48799: 180
# Winning Path Score for individual I48799: 180
# Winning Path Score for individual I48812: 169
# Winning Path Score for individual I48812: 169
# Winning Path Score for individual I48821: 132
# Winning Path Score for individual I48821: 132
# Winning Path Score for individual I48830: 18
# Winning Path Score for individual I48830: 18
# Winning Path Score for individual I48837: 49
# Winning Path Score for individual I48837: 49
# Winning Path Score for individual I48843: 39
# Winning Path Score for individual I48843: 39
# Winning Path Score for individual I48857: 108
# Winning Path Score for individual I48857: 108
# Winning Path Score for individual I48868: 150
# Winning Path Score for individual I48868: 150
# Winning Path Score for individual I48887: 115
# Winning Path Score for individual I48887: 115
# Winning Path Score for individual I48898: 21
# Winning Path Score for individual I48898: 21
# Winning Path Score for individual I48901: 42
# Winning Path Score for individual I48901: 42
# Winning Path Score for individual I48919: 7
# Winning Path Score for individual I48919: 7
# Winning Path Score for individual I48935: 174
# Winning Path Score for individual I48935: 174
# Winning Path Score for individual I48945: 8
# Winning Path Score for individual I48945: 8
# Winning Path Score for individual I48954: 115
# Winning Path Score for individual I48954: 115
# Winning Path Score for individual I48965: 110
# Winning Path Score for individual I48965: 110
# Winning Path Score for individual I48970: 22
# Winning Path Score for individual I48970: 22
# Winning Path Score for individual I48983: 165
# Winning Path Score for individual I48983: 165
# Winning Path Score for individual I48998: 117
# Winning Path Score for individual I48998: 117
# Winning Path Score for individual I49006: 147
# Winning Path Score for individual I49006: 147
# Winning Path Score for individual I49020: 115
# Winning Path Score for individual I49020: 115
# Winning Path Score for individual I49027: 133
# Winning Path Score for individual I49027: 133
# Winning Path Score for individual I49039: 150
# Winning Path Score for individual I49039: 150
# Winning Path Score for individual I49061: 182
# Winning Path Score for individual I49061: 182
# Winning Path Score for individual I49076: 153
# Winning Path Score for individual I49076: 153
# Winning Path Score for individual I49085: 24
# Winning Path Score for individual I49085: 24
# Winning Path Score for individual I49095: 161
# Winning Path Score for individual I49095: 161
# Winning Path Score for individual I49101: 33
# Winning Path Score for individual I49101: 33
# Winning Path Score for individual I49115: 165
# Winning Path Score for individual I49115: 165
# Winning Path Score for individual I49132: 108
# Winning Path Score for individual I49132: 108
# Winning Path Score for individual I49140: 161
# Winning Path Score for individual I49140: 161
# Winning Path Score for individual I49152: 135
# Winning Path Score for individual I49152: 135
# Winning Path Score for individual I49165: 30
# Winning Path Score for individual I49165: 30
# Winning Path Score for individual I49178: 121
# Winning Path Score for individual I49178: 121
# Winning Path Score for individual I49189: 132
# Winning Path Score for individual I49189: 132
# Winning Path Score for individual I49197: 133
# Winning Path Score for individual I49197: 133
# Winning Path Score for individual I49206: 138
# Winning Path Score for individual I49206: 138
# Winning Path Score for individual I49220: 126
# Winning Path Score for individual I49220: 126
# Winning Path Score for individual I49230: 143
# Winning Path Score for individual I49230: 143
# Winning Path Score for individual I49240: 170
# Winning Path Score for individual I49240: 170
# Winning Path Score for individual I49250: 153
# Winning Path Score for individual I49250: 153
# Winning Path Score for individual I49276: 145
# Winning Path Score for individual I49276: 145
# Winning Path Score for individual I49289: 45
# Winning Path Score for individual I49289: 45
# Winning Path Score for individual I49316: 45
# Winning Path Score for individual I49316: 45
# Winning Path Score for individual I49326: 150
# Winning Path Score for individual I49326: 150
# Winning Path Score for individual I49337: 30
# Winning Path Score for individual I49337: 30
# Winning Path Score for individual I49369: 91
# Winning Path Score for individual I49369: 91
# Winning Path Score for individual I49380: 147
# Winning Path Score for individual I49380: 147
# Winning Path Score for individual I49396: 138
# Winning Path Score for individual I49396: 138
# Winning Path Score for individual I49402: 114
# Winning Path Score for individual I49402: 114
# Winning Path Score for individual I49409: 156
# Winning Path Score for individual I49409: 156
# Winning Path Score for individual I49427: 135
# Winning Path Score for individual I49427: 135
# Winning Path Score for individual I49442: 143
# Winning Path Score for individual I49442: 143
# Winning Path Score for individual I49444: 175
# Winning Path Score for individual I49444: 175
# Winning Path Score for individual I49459: 39
# Winning Path Score for individual I49459: 39
# Winning Path Score for individual I49465: 150
# Winning Path Score for individual I49465: 150
# Winning Path Score for individual I49471: 39
# Winning Path Score for individual I49471: 39
# Winning Path Score for individual I49476: 33
# Winning Path Score for individual I49476: 33
# Winning Path Score for individual I49491: 130
# Winning Path Score for individual I49491: 130
# Winning Path Score for individual I49502: 132
# Winning Path Score for individual I49502: 132
# Winning Path Score for individual I49511: 125
# Winning Path Score for individual I49511: 125
# Winning Path Score for individual I49520: 138
# Winning Path Score for individual I49520: 138
# Winning Path Score for individual I49565: 161
# Winning Path Score for individual I49565: 161
# Winning Path Score for individual I49570: 150
# Winning Path Score for individual I49570: 150
# Winning Path Score for individual I49580: 138
# Winning Path Score for individual I49580: 138
# Winning Path Score for individual I49593: 57
# Winning Path Score for individual I49593: 57
# Winning Path Score for individual I49607: 135
# Winning Path Score for individual I49607: 135
# Winning Path Score for individual I49615: 136
# Winning Path Score for individual I49615: 136
# Winning Path Score for individual I49636: 116
# Winning Path Score for individual I49636: 116
# Winning Path Score for individual I49652: 150
# Winning Path Score for individual I49652: 150
# Winning Path Score for individual I49657: 133
# Winning Path Score for individual I49657: 133
# Winning Path Score for individual I49673: 110
# Winning Path Score for individual I49673: 110
# Winning Path Score for individual I49682: 138
# Winning Path Score for individual I49682: 138
# Winning Path Score for individual I49693: 108
# Winning Path Score for individual I49693: 108
# Winning Path Score for individual I49699: 138
# Winning Path Score for individual I49699: 138
# Winning Path Score for individual I49708: 136
# Winning Path Score for individual I49708: 136
# Winning Path Score for individual I49717: 165
# Winning Path Score for individual I49717: 165
# Winning Path Score for individual I49730: 156
# Winning Path Score for individual I49730: 156
# Winning Path Score for individual I49755: 169
# Winning Path Score for individual I49755: 169
# Winning Path Score for individual I49784: 99
# Winning Path Score for individual I49784: 99
# Winning Path Score for individual I49799: 126
# Winning Path Score for individual I49799: 126
# Winning Path Score for individual I49813: 108
# Winning Path Score for individual I49813: 108
# Winning Path Score for individual I49833: 143
# Winning Path Score for individual I49833: 143
# Winning Path Score for individual I49847: 162
# Winning Path Score for individual I49847: 162
# Winning Path Score for individual I49862: 115
# Winning Path Score for individual I49862: 115
# Winning Path Score for individual I49876: 180
# Winning Path Score for individual I49876: 180
# Winning Path Score for individual I49896: 98
# Winning Path Score for individual I49896: 98
# Winning Path Score for individual I49905: 54
# Winning Path Score for individual I49905: 54
# Winning Path Score for individual I49917: 161
# Winning Path Score for individual I49917: 161
# Winning Path Score for individual I49955: 156
# Winning Path Score for individual I49955: 156
# Winning Path Score for individual I49982: 162
# Winning Path Score for individual I49982: 162
# Winning Path Score for individual I49996: 169
# Winning Path Score for individual I49996: 169
# Winning Path Score for individual I50006: 150
# Winning Path Score for individual I50006: 150
# Winning Path Score for individual I50013: 136
# Winning Path Score for individual I50013: 136
# Winning Path Score for individual I50024: 143
# Winning Path Score for individual I50024: 143
# Winning Path Score for individual I50033: 138
# Winning Path Score for individual I50033: 138
# Winning Path Score for individual I50046: 135
# Winning Path Score for individual I50046: 135
# Winning Path Score for individual I50057: 0
# Winning Path Score for individual I50057: 0
# Winning Path Score for individual I50069: 0
# Winning Path Score for individual I50069: 0
# Winning Path Score for individual I50098: 0
# Winning Path Score for individual I50098: 0
# Winning Path Score for individual I50111: 0
# Winning Path Score for individual I50111: 0
# Winning Path Score for individual I50124: 0
# Winning Path Score for individual I50124: 0
# Winning Path Score for individual I50144: 0
# Winning Path Score for individual I50144: 0
# Winning Path Score for individual I50164: 0
# Winning Path Score for individual I50164: 0
# Winning Path Score for individual I50184: 0
# Winning Path Score for individual I50184: 0
# Winning Path Score for individual I50191: 0
# Winning Path Score for individual I50191: 0
# Winning Path Score for individual I50225: 0
# Winning Path Score for individual I50225: 0
# Winning Path Score for individual I50249: 0
# Winning Path Score for individual I50249: 0
# Winning Path Score for individual I50264: 0
# Winning Path Score for individual I50264: 0
# Winning Path Score for individual I50275: 0
# Winning Path Score for individual I50275: 0
# Winning Path Score for individual I50309: 136
# Winning Path Score for individual I50309: 136
# Winning Path Score for individual I50326: 38
# Winning Path Score for individual I50326: 38
# Winning Path Score for individual I50355: 154
# Winning Path Score for individual I50355: 154
# Winning Path Score for individual I50364: 169
# Winning Path Score for individual I50364: 169
# Winning Path Score for individual I50369: 20
# Winning Path Score for individual I50369: 20
# Winning Path Score for individual I50375: 35
# Winning Path Score for individual I50375: 35
# Winning Path Score for individual I50391: 108
# Winning Path Score for individual I50391: 108
# Winning Path Score for individual I50405: 50
# Winning Path Score for individual I50405: 50
# Winning Path Score for individual I50416: 21
# Winning Path Score for individual I50416: 21
# Winning Path Score for individual I50429: 138
# Winning Path Score for individual I50429: 138
# Winning Path Score for individual I50440: 150
# Winning Path Score for individual I50440: 150
# Winning Path Score for individual I50449: 99
# Winning Path Score for individual I50449: 99
# Winning Path Score for individual I50459: 121
# Winning Path Score for individual I50459: 121
# Winning Path Score for individual I50472: 143
# Winning Path Score for individual I50472: 143
# Winning Path Score for individual I50482: 60
# Winning Path Score for individual I50482: 60
# Winning Path Score for individual I50494: 133
# Winning Path Score for individual I50494: 133
# Winning Path Score for individual I50511: 135
# Winning Path Score for individual I50511: 135
# Winning Path Score for individual I50522: 175
# Winning Path Score for individual I50522: 175
# Winning Path Score for individual I50535: 162
# Winning Path Score for individual I50535: 162
# Winning Path Score for individual I50551: 169
# Winning Path Score for individual I50551: 169
#         ID#         Match to  cM  Score Filtered Ancestral Line
# 0    I13817      yates,johnh  11     10            YatesWilliam
# 1    I21743    yates,robertd  15    165
# 2    I23678    yates,andreal  53     92
# 3    I26925    yates,andreal  27      7
# 4    I31861  yates,patricial  19    130
# ..      ...              ...  ..    ...                     ...
# 370  I50494     yates,ronald  16    133
# 371  I50511      yatesronald  14    135
# 372  I50522      yatesronald  17    175
# 373  I50535     yates,ronald  14    162
# 374  I50551     yates,ronald   8    169
#
# [375 rows x 5 columns]

# %%
# !pip install pandas
# !pip install python-gedcom
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: python-gedcom in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
